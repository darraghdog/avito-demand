# %%
import gc
import pandas as pd
import numpy as np
from sklearn import metrics#, linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from lightgbm import LGBMRegressor
import sys
import warnings
import itertools

if not sys.warnoptions:
    warnings.simplefilter("ignore")

path = "/home/darragh/avito/data/"
#path = '/Users/dhanley2/Documents/avito/data/'
#path = '/home/ubuntu/avito/data/'
#data_path = 'data/'

# %%
#lgb25 = pd.read_csv('../lgCV_2505.csv.gz', compression='gzip')
lgb02A = pd.read_csv(path+'../sub/lgCV_0206A.csv.gz', compression='gzip')
lgb09 = pd.read_csv(path+'../sub/lgCV_0906.csv.gz', compression='gzip')
lgb10 = pd.read_csv(path+'../sub/lgCV_1006.csv.gz', compression='gzip')
lgb11A= pd.read_csv(path+'../sub/lgCV_1106A.csv.gz', compression='gzip')
lgb11D= pd.read_csv(path+'../sub/lgCV_1106D.csv.gz', compression='gzip')
lgb14= pd.read_csv(path+'../sub/lgCV_1406.csv.gz', compression='gzip')
lgb14A= pd.read_csv(path+'../sub/lgCV_1406A.csv.gz', compression='gzip')
lgb27 = pd.read_csv(path+'../sub/lgCV_2705B.csv.gz', compression='gzip')
lgb31 = pd.read_csv(path+'../sub/lgCV_3105.csv.gz', compression='gzip')
lgb02 = pd.read_csv(path+'../sub/lgCV_0206.csv.gz', compression='gzip')
lgb17 = pd.read_csv(path+'../sub/lgCV_1706.csv.gz', compression='gzip')
lgb19 = pd.read_csv(path+'../sub/lgCV_1906.csv.gz', compression='gzip')
lgb20 = pd.read_csv(path+'../sub/lgCV_2006.csv.gz', compression='gzip')
lgb20AA = pd.read_csv(path+'../sub/lgCV_2006AA.csv.gz', compression='gzip')
lgb19A= pd.read_csv(path+'../sub/lgCV_1906A.csv.gz', compression='gzip')
rnn =   pd.read_csv(path+'../sub/rnnCV_2805.csv.gz', compression='gzip')
rnn27 = pd.read_csv(path+'../sub/rnnCV_2705A.csv.gz', compression='gzip')
rnn12 = pd.read_csv(path+'../sub/rnnCV_1206.csv.gz', compression='gzip')
mlp =   pd.read_csv(path+'../sub/mlpCV_2505.csv.gz', compression='gzip')
rdgv19 =   pd.read_csv(path+'../sub/rdgv19CV_1606.csv.gz', compression='gzip')
truth = pd.read_csv(path+'train.csv.zip', compression='zip', parse_dates = ["activation_date"])
y =     truth['deal_probability'].values
truth.drop('deal_probability', 1)
test =  pd.read_csv(path+'test.csv.zip', compression='zip', parse_dates = ["activation_date"])
test['deal_probability']=float('NAN') 
truth = pd.concat([truth,test[truth.columns]],axis=0)

# %% [raw]
# lgb20trn = pd.read_csv(path+'../sub/lgbCV_2006AA_trn.csv', header = None)
# lgb20tst = pd.read_csv(path+'../sub/lgbCV_2006AA_tst.csv', header = None)
# lgb20 = pd.concat([lgb20trn, lgb20tst], axis = 0)
# lgb20.columns = ['item_id', 'deal_probability']
# lgb20.head()
# lgb20.to_csv(path+'../sub/lgCV_2006AA.csv.gz', index = False, compression='gzip')

# %%
lgb14['deal_probability'] =  ( lgb14['deal_probability'].values + lgb14A['deal_probability'].values)*0.5
lgb17['deal_probability'] =  ( lgb17['deal_probability'].values + lgb19['deal_probability'].values)*0.25
lgb20['deal_probability'] =  ( lgb20['deal_probability'].values) * 0.5

# %%
#img_cts = truth['image_top_1'].value_counts().reset_index()
#truth['image_top_big'] = 'lo_count'
#big_top_1 = img_cts[img_cts['image_top_1']>5000]['index'].tolist()
#idx = truth['image_top_1'].isin(big_top_1)
#truth['image_top_big'][idx] = truth['image_top_1'][idx].astype(str).values

def keep_big(df, col, cutoff):
    cts = df[col].value_counts().reset_index()
    df[col+'_big'] = 'lo_count'
    big = cts[cts[col]>cutoff]['index'].tolist()
    idx = df[col].isin(big)
    df[col+'_big'][idx] = df[col][idx].astype(str).values
    return df[col+'_big'].values
truth['image_top_1_big'] = keep_big(truth, 'image_top_1', 5000)
truth['param_1_big'] = keep_big(truth, 'param_1', 5000)
truth['param_2_big'] = keep_big(truth, 'param_2', 5000)
truth['param_3_big'] = keep_big(truth, 'param_3', 5000)
truth['city_big'] = keep_big(truth, 'city', 5000)

# %%
truth[[c for c in truth.columns if 'big' in c]].head()
# Out:
#   image_top_1_big                param_1_big param_2_big param_3_big  \
# 0        lo_count  Постельные принадлежности    lo_count    lo_count
# 1        lo_count                     Другое    lo_count    lo_count
# 2        lo_count                   lo_count    lo_count    lo_count
# 3           796.0       Автомобильные кресла    lo_count    lo_count
# 4          2264.0                 С пробегом  ВАЗ (LADA)    lo_count
#
#            city_big
# 0      Екатеринбург
# 1            Самара
# 2    Ростов-на-Дону
# 3  Набережные Челны
# 4         Волгоград

# %%
#lgb25.rename(columns={'deal_probability': 'lgb25_preds' }, inplace=True)
lgb31.rename(columns={'deal_probability': 'lgb31_preds' }, inplace=True)
lgb27.rename(columns={'deal_probability': 'lgb27_preds' }, inplace=True)
lgb02.rename(columns={'deal_probability': 'lgb02_preds' }, inplace=True)
lgb09.rename(columns={'deal_probability': 'lgb09_preds' }, inplace=True)
lgb10.rename(columns={'deal_probability': 'lgb10_preds' }, inplace=True)
lgb11D.rename(columns={'deal_probability': 'lgb11D_preds' }, inplace=True)
lgb11A.rename(columns={'deal_probability': 'lgb11A_preds' }, inplace=True)
lgb14.rename(columns={'deal_probability': 'lgb14_preds' }, inplace=True)
lgb17.rename(columns={'deal_probability': 'lgb17_preds' }, inplace=True)
lgb20.rename(columns={'deal_probability': 'lgb20_preds' }, inplace=True)
lgb20AA.rename(columns={'deal_probability': 'lgb20AA_preds' }, inplace=True)
lgb19A.rename(columns={'deal_probability': 'lgb19A_preds' }, inplace=True)
lgb02A.rename(columns={'deal_probability': 'lgb02A_preds' }, inplace=True)
rnn27.rename(columns={'deal_probability': 'rnn27_preds' }, inplace=True)
rnn12.rename(columns={'deal_probability': 'rnn12_preds' }, inplace=True)
rdgv19.rename(columns={'deal_probability': 'rdgv19_preds' }, inplace=True)
mlp.rename(columns={'deal_probability': 'mlp_preds' }, inplace=True)
preds_df = lgb27.merge(rnn, on='item_id')\
                .merge(mlp, on='item_id')\
                .merge(lgb31, on='item_id')\
                .merge(lgb02, on='item_id')\
                .merge(lgb09, on='item_id')\
                .merge(lgb10, on='item_id')\
                .merge(lgb11A, on='item_id')\
                .merge(lgb11D, on='item_id')\
                .merge(lgb14, on='item_id')\
                .merge(lgb17, on='item_id')\
                .merge(lgb20, on='item_id')\
                .merge(lgb20AA, on='item_id')\
                .merge(lgb19A, on='item_id')\
                .merge(lgb02A, on='item_id')\
                .merge(rnn27, on='item_id')\
                .merge(rnn12, on='item_id')\
                .merge(rdgv19, on='item_id')\
                .merge(truth, on='item_id',how='left')

# %%
pred_cols = [col for col in preds_df.columns if ('_preds' in col) \
             and ('lgb27' not in col) and ('lgb02_' not in col) and ('lgb11A_' not in col) \
             and ('rdgv19_' not in col) and ('lgb17_' not in col)]

preds_df['preds_sum'] = preds_df[pred_cols].sum(axis=1)
pred_cols
# Out:
# ['rnn_preds',
#  'mlp_preds',
#  'lgb31_preds',
#  'lgb09_preds',
#  'lgb10_preds',
#  'lgb11D_preds',
#  'lgb14_preds',
#  'lgb20_preds',
#  'lgb20AA_preds',
#  'lgb19A_preds',
#  'lgb02A_preds',
#  'rnn27_preds',
#  'rnn12_preds']

# %%
preds_df['price'].fillna(-1,inplace=True)
preds_df['max'] = np.max(np.array([preds_df[col] for col in pred_cols]),axis=0)
preds_df['min'] = np.min(np.array([preds_df[col] for col in pred_cols]),axis=0)
preds_df['avg'] = np.mean(np.array([preds_df[col] for col in pred_cols]),axis=0)
preds_df['med'] = np.median(np.array([preds_df[col] for col in pred_cols]),axis=0)
preds_df['std'] = np.std(np.array([preds_df[col] for col in pred_cols]),axis=0)

# %%
import itertools
for p1, p2 in itertools.combinations(pred_cols, 2):
    print('difference_%s__%s'%(p1,p2))
    preds_df['difference_%s__%s'%(p1,p2)] = preds_df[p2] - preds_df[p1]
    preds_df['sums_%s__%s'%(p1,p2)] = preds_df[p2] + preds_df[p1]
# Out:
# difference_rnn_preds__mlp_preds
# difference_rnn_preds__lgb31_preds
# difference_rnn_preds__lgb09_preds
# difference_rnn_preds__lgb10_preds
# difference_rnn_preds__lgb11D_preds
# difference_rnn_preds__lgb14_preds
# difference_rnn_preds__lgb20_preds
# difference_rnn_preds__lgb20AA_preds
# difference_rnn_preds__lgb19A_preds
# difference_rnn_preds__lgb02A_preds
# difference_rnn_preds__rnn27_preds
# difference_rnn_preds__rnn12_preds
# difference_mlp_preds__lgb31_preds
# difference_mlp_preds__lgb09_preds
# difference_mlp_preds__lgb10_preds
# difference_mlp_preds__lgb11D_preds
# difference_mlp_preds__lgb14_preds
# difference_mlp_preds__lgb20_preds
# difference_mlp_preds__lgb20AA_preds
# difference_mlp_preds__lgb19A_preds
# difference_mlp_preds__lgb02A_preds
# difference_mlp_preds__rnn27_preds
# difference_mlp_preds__rnn12_preds
# difference_lgb31_preds__lgb09_preds
# difference_lgb31_preds__lgb10_preds
# difference_lgb31_preds__lgb11D_preds
# difference_lgb31_preds__lgb14_preds
# difference_lgb31_preds__lgb20_preds
# difference_lgb31_preds__lgb20AA_preds
# difference_lgb31_preds__lgb19A_preds
# difference_lgb31_preds__lgb02A_preds
# difference_lgb31_preds__rnn27_preds
# difference_lgb31_preds__rnn12_preds
# difference_lgb09_preds__lgb10_preds
# difference_lgb09_preds__lgb11D_preds
# difference_lgb09_preds__lgb14_preds
# difference_lgb09_preds__lgb20_preds
# difference_lgb09_preds__lgb20AA_preds
# difference_lgb09_preds__lgb19A_preds
# difference_lgb09_preds__lgb02A_preds
# difference_lgb09_preds__rnn27_preds
# difference_lgb09_preds__rnn12_preds
# difference_lgb10_preds__lgb11D_preds
# difference_lgb10_preds__lgb14_preds
# difference_lgb10_preds__lgb20_preds
# difference_lgb10_preds__lgb20AA_preds
# difference_lgb10_preds__lgb19A_preds
# difference_lgb10_preds__lgb02A_preds
# difference_lgb10_preds__rnn27_preds
# difference_lgb10_preds__rnn12_preds
# difference_lgb11D_preds__lgb14_preds
# difference_lgb11D_preds__lgb20_preds
# difference_lgb11D_preds__lgb20AA_preds
# difference_lgb11D_preds__lgb19A_preds
# difference_lgb11D_preds__lgb02A_preds
# difference_lgb11D_preds__rnn27_preds
# difference_lgb11D_preds__rnn12_preds
# difference_lgb14_preds__lgb20_preds
# difference_lgb14_preds__lgb20AA_preds
# difference_lgb14_preds__lgb19A_preds
# difference_lgb14_preds__lgb02A_preds
# difference_lgb14_preds__rnn27_preds
# difference_lgb14_preds__rnn12_preds
# difference_lgb20_preds__lgb20AA_preds
# difference_lgb20_preds__lgb19A_preds
# difference_lgb20_preds__lgb02A_preds
# difference_lgb20_preds__rnn27_preds
# difference_lgb20_preds__rnn12_preds
# difference_lgb20AA_preds__lgb19A_preds
# difference_lgb20AA_preds__lgb02A_preds
# difference_lgb20AA_preds__rnn27_preds
# difference_lgb20AA_preds__rnn12_preds
# difference_lgb19A_preds__lgb02A_preds
# difference_lgb19A_preds__rnn27_preds
# difference_lgb19A_preds__rnn12_preds
# difference_lgb02A_preds__rnn27_preds
# difference_lgb02A_preds__rnn12_preds
# difference_rnn27_preds__rnn12_preds

# %%
gc.collect()
# Out:
# 192

# %%
preds_df.head()
# Out:
#         item_id  lgb27_preds  rnn_preds  mlp_preds  lgb31_preds  lgb02_preds  \
# 0  b912c3c6a6ad     0.091656   0.069891   0.091223     0.083219     0.090855
# 1  2dac0150717d     0.147801   0.075968   0.211844     0.157973     0.119609
# 2  ba83aefab5dc     0.186261   0.167167   0.236579     0.227048     0.258980
# 3  02996f1dd2ea     0.241699   0.260876   0.383699     0.231447     0.284130
# 4  7c90be56d2ab     0.407423   0.431520   0.420657     0.412563     0.430581
#
#    lgb09_preds  lgb10_preds  lgb11A_preds  lgb11D_preds  \
# 0     0.109624     0.107764      0.095101      0.092921
# 1     0.157466     0.161107      0.140269      0.144395
# 2     0.245236     0.219107      0.234076      0.222678
# 3     0.289101     0.255519      0.241802      0.271355
# 4     0.511145     0.511676      0.504849      0.503961
#
#                ...                difference_lgb19A_preds__rnn27_preds  \
# 0              ...                                           -0.017792
# 1              ...                                           -0.067602
# 2              ...                                           -0.061566
# 3              ...                                            0.044863
# 4              ...                                           -0.154635
#
#    sums_lgb19A_preds__rnn27_preds  difference_lgb19A_preds__rnn12_preds  \
# 0                        0.154454                             -0.009246
# 1                        0.208879                             -0.049681
# 2                        0.385415                             -0.075465
# 3                        0.512745                              0.014382
# 4                        0.855203                             -0.083575
#
#    sums_lgb19A_preds__rnn12_preds  difference_lgb02A_preds__rnn27_preds  \
# 0                        0.163000                             -0.041287
# 1                        0.226800                             -0.089406
# 2                        0.371516                             -0.079412
# 3                        0.482264                             -0.057652
# 4                        0.926263                             -0.071704
#
#    sums_lgb02A_preds__rnn27_preds  difference_lgb02A_preds__rnn12_preds  \
# 0                        0.177948                             -0.032740
# 1                        0.230683                             -0.071485
# 2                        0.403260                             -0.093311
# 3                        0.615259                             -0.088132
# 4                        0.772273                             -0.000645
#
#    sums_lgb02A_preds__rnn12_preds  difference_rnn27_preds__rnn12_preds  \
# 0                        0.186494                             0.008546
# 1                        0.248604                             0.017921
# 2                        0.389361                            -0.013899
# 3                        0.584779                            -0.030481
# 4                        0.843332                             0.071059
#
#    sums_rnn27_preds__rnn12_preds
# 0                       0.145208
# 1                       0.159198
# 2                       0.309950
# 3                       0.527127
# 4                       0.771628
#
# [5 rows x 204 columns]

# %% [markdown]
# ### Train scores

# %%
pred_cols = [col for col in preds_df.columns if ('preds' in col) 
             and ('difference' not in col) 
             and ('sum' not in col)]
pred_cols
# Out:
# ['lgb27_preds',
#  'rnn_preds',
#  'mlp_preds',
#  'lgb31_preds',
#  'lgb02_preds',
#  'lgb09_preds',
#  'lgb10_preds',
#  'lgb11A_preds',
#  'lgb11D_preds',
#  'lgb14_preds',
#  'lgb17_preds',
#  'lgb20_preds',
#  'lgb20AA_preds',
#  'lgb19A_preds',
#  'lgb02A_preds',
#  'rnn27_preds',
#  'rnn12_preds',
#  'rdgv19_preds']

# %%
idx = preds_df['deal_probability']==preds_df['deal_probability']
print(idx.value_counts())
for col in [c for c in preds_df.columns if ('_preds' in c) and ('difference' not in c) and ('sum' not in c)]:
    print('RMSE %s: '%(col), np.sqrt(metrics.mean_squared_error(preds_df['deal_probability'][idx].values, preds_df[col][idx].values)))
# Out:
# True     1503424
# False     508438
# Name: deal_probability, dtype: int64
# RMSE lgb27_preds:  0.21681527582821059
# RMSE rnn_preds:  0.21771476573780568
# RMSE mlp_preds:  0.2187544351068867
# RMSE lgb31_preds:  0.21681135578306754
# RMSE lgb02_preds:  0.21625386267187377
# RMSE lgb09_preds:  0.21581543265040168
# RMSE lgb10_preds:  0.21533498019117664
# RMSE lgb11A_preds:  0.21403812331071156
# RMSE lgb11D_preds:  0.21392147604708842
# RMSE lgb14_preds:  0.21329729304260686
# RMSE lgb17_preds:  0.21311496843894262
# RMSE lgb20_preds:  0.21300538173982395
# RMSE lgb20AA_preds:  0.21329931538907382
# RMSE lgb19A_preds:  0.21341739569735188
# RMSE lgb02A_preds:  0.21627136604335995
# RMSE rnn27_preds:  0.21698040871120608
# RMSE rnn12_preds:  0.2167114508342396
# RMSE rdgv19_preds:  0.24593955235646558

# %%
foldls = [["2017-03-15", "2017-03-16", "2017-03-17"], \
       ["2017-03-18", "2017-03-19", "2017-03-20"], \
       ["2017-03-21", "2017-03-22", "2017-03-23"], \
       ["2017-03-24", "2017-03-25", "2017-03-26"], \
        ["2017-03-27", "2017-03-28", "2017-03-29", \
            "2017-03-30", "2017-03-31", "2017-04-01", \
            "2017-04-02", "2017-04-03","2017-04-07"]]
foldls = [[pd.to_datetime(d) for d in f] for f in foldls]
preds_df['fold'] = -1
for t, fold in enumerate(foldls):
    preds_df['fold'][preds_df.activation_date.isin(fold)] = t

# %%
scores = []
for col in [c for c in preds_df.columns if ('_preds' in c) \
            and ('difference' not in c) \
            and ('sum' not in c)]:
    lstmp = [col]
    for i in range(5):
        idx = preds_df['fold']==i
        lstmp.append(np.sqrt(metrics.mean_squared_error(preds_df['deal_probability'][idx].values, \
                                                        preds_df[col][idx].values)))
    scores.append(lstmp)
pd.DataFrame(scores, columns = ['Model']+['Fold%s'%(i) for i in range(5)])
# Out:
#             Model     Fold0     Fold1     Fold2     Fold3     Fold4
# 0     lgb27_preds  0.216848  0.217096  0.217923  0.217597  0.213692
# 1       rnn_preds  0.218756  0.218966  0.215764  0.219554  0.214747
# 2       mlp_preds  0.219660  0.220088  0.216672  0.220347  0.216385
# 3     lgb31_preds  0.216537  0.216643  0.219230  0.217169  0.213430
# 4     lgb02_preds  0.216371  0.216447  0.217354  0.217032  0.213158
# 5     lgb09_preds  0.215514  0.215678  0.218418  0.216073  0.212293
# 6     lgb10_preds  0.215240  0.215533  0.217072  0.215802  0.212023
# 7    lgb11A_preds  0.215011  0.215205  0.211879  0.215771  0.211735
# 8    lgb11D_preds  0.214818  0.215074  0.211837  0.215720  0.211549
# 9     lgb14_preds  0.214204  0.214441  0.211074  0.215146  0.211051
# 10    lgb17_preds  0.214061  0.214275  0.210872  0.214884  0.210930
# 11    lgb20_preds  0.213929  0.214201  0.210747  0.214698  0.210926
# 12  lgb20AA_preds  0.214170  0.214483  0.211014  0.215037  0.211288
# 13   lgb19A_preds  0.214280  0.214530  0.211292  0.215184  0.211253
# 14   lgb02A_preds  0.216081  0.216051  0.218825  0.216562  0.212741
# 15    rnn27_preds  0.218097  0.218115  0.214982  0.218651  0.214379
# 16    rnn12_preds  0.217658  0.217913  0.214952  0.218472  0.213781
# 17   rdgv19_preds  0.246571  0.246399  0.244456  0.247503  0.244406

# %% [markdown]
# ### Correlations in test and train

# %%
# Test correlation
preds_df[~preds_df['deal_probability'].isnull()][[c for c in preds_df.columns if ('_preds' in c) \
                                                  and ('difference' not in c) and ('sum' not in c) ]].corr()
# Out:
#                lgb27_preds  rnn_preds  mlp_preds  lgb31_preds  lgb02_preds  \
# lgb27_preds       1.000000   0.915952   0.919171     0.990750     0.988682
# rnn_preds         0.915952   1.000000   0.929710     0.910602     0.913307
# mlp_preds         0.919171   0.929710   1.000000     0.914307     0.916343
# lgb31_preds       0.990750   0.910602   0.914307     1.000000     0.991984
# lgb02_preds       0.988682   0.913307   0.916343     0.991984     1.000000
# lgb09_preds       0.978331   0.908867   0.909521     0.981891     0.982596
# lgb10_preds       0.978298   0.913286   0.913883     0.981375     0.982052
# lgb11A_preds      0.966819   0.915655   0.915367     0.966656     0.970858
# lgb11D_preds      0.965873   0.913936   0.913018     0.965897     0.969933
# lgb14_preds       0.961540   0.912870   0.911656     0.961575     0.966325
# lgb17_preds       0.963754   0.915690   0.915252     0.963672     0.968201
# lgb20_preds       0.961191   0.913122   0.912500     0.961171     0.965676
# lgb20AA_preds     0.958141   0.910838   0.909956     0.958066     0.962551
# lgb19A_preds      0.957731   0.910086   0.908837     0.957796     0.962391
# lgb02A_preds      0.983143   0.911443   0.913600     0.986851     0.987434
# rnn27_preds       0.916804   0.985360   0.925010     0.914204     0.916726
# rnn12_preds       0.920576   0.978274   0.929518     0.916939     0.920105
# rdgv19_preds      0.568406   0.551100   0.577280     0.570034     0.567698
#
#                lgb09_preds  lgb10_preds  lgb11A_preds  lgb11D_preds  \
# lgb27_preds       0.978331     0.978298      0.966819      0.965873
# rnn_preds         0.908867     0.913286      0.915655      0.913936
# mlp_preds         0.909521     0.913883      0.915367      0.913018
# lgb31_preds       0.981891     0.981375      0.966656      0.965897
# lgb02_preds       0.982596     0.982052      0.970858      0.969933
# lgb09_preds       1.000000     0.990447      0.976755      0.976540
# lgb10_preds       0.990447     1.000000      0.982841      0.982033
# lgb11A_preds      0.976755     0.982841      1.000000      0.992400
# lgb11D_preds      0.976540     0.982033      0.992400      1.000000
# lgb14_preds       0.972392     0.977396      0.988703      0.989978
# lgb17_preds       0.972977     0.978691      0.989962      0.990876
# lgb20_preds       0.970851     0.976402      0.987555      0.988477
# lgb20AA_preds     0.966872     0.972605      0.983654      0.984497
# lgb19A_preds      0.968260     0.973449      0.984745      0.985921
# lgb02A_preds      0.988708     0.985858      0.971893      0.971846
# rnn27_preds       0.912375     0.916436      0.918727      0.917196
# rnn12_preds       0.915090     0.920034      0.923137      0.921322
# rdgv19_preds      0.560909     0.562639      0.558477      0.557072
#
#                lgb14_preds  lgb17_preds  lgb20_preds  lgb20AA_preds  \
# lgb27_preds       0.961540     0.963754     0.961191       0.958141
# rnn_preds         0.912870     0.915690     0.913122       0.910838
# mlp_preds         0.911656     0.915252     0.912500       0.909956
# lgb31_preds       0.961575     0.963672     0.961171       0.958066
# lgb02_preds       0.966325     0.968201     0.965676       0.962551
# lgb09_preds       0.972392     0.972977     0.970851       0.966872
# lgb10_preds       0.977396     0.978691     0.976402       0.972605
# lgb11A_preds      0.988703     0.989962     0.987555       0.983654
# lgb11D_preds      0.989978     0.990876     0.988477       0.984497
# lgb14_preds       1.000000     0.994906     0.991492       0.987318
# lgb17_preds       0.994906     1.000000     0.993216       0.989026
# lgb20_preds       0.991492     0.993216     1.000000       0.990462
# lgb20AA_preds     0.987318     0.989026     0.990462       1.000000
# lgb19A_preds      0.990040     0.990674     0.989451       0.985254
# lgb02A_preds      0.967560     0.968335     0.966075       0.962059
# rnn27_preds       0.916160     0.918859     0.916268       0.913909
# rnn12_preds       0.920547     0.923748     0.920873       0.918365
# rdgv19_preds      0.553930     0.558075     0.555115       0.553319
#
#                lgb19A_preds  lgb02A_preds  rnn27_preds  rnn12_preds  \
# lgb27_preds        0.957731      0.983143     0.916804     0.920576
# rnn_preds          0.910086      0.911443     0.985360     0.978274
# mlp_preds          0.908837      0.913600     0.925010     0.929518
# lgb31_preds        0.957796      0.986851     0.914204     0.916939
# lgb02_preds        0.962391      0.987434     0.916726     0.920105
# lgb09_preds        0.968260      0.988708     0.912375     0.915090
# lgb10_preds        0.973449      0.985858     0.916436     0.920034
# lgb11A_preds       0.984745      0.971893     0.918727     0.923137
# lgb11D_preds       0.985921      0.971846     0.917196     0.921322
# lgb14_preds        0.990040      0.967560     0.916160     0.920547
# lgb17_preds        0.990674      0.968335     0.918859     0.923748
# lgb20_preds        0.989451      0.966075     0.916268     0.920873
# lgb20AA_preds      0.985254      0.962059     0.913909     0.918365
# lgb19A_preds       1.000000      0.963496     0.913268     0.917690
# lgb02A_preds       0.963496      1.000000     0.914911     0.917453
# rnn27_preds        0.913268      0.914911     1.000000     0.979744
# rnn12_preds        0.917690      0.917453     0.979744     1.000000
# rdgv19_preds       0.552865      0.564071     0.558103     0.564928
#
#                rdgv19_preds
# lgb27_preds        0.568406
# rnn_preds          0.551100
# mlp_preds          0.577280
# lgb31_preds        0.570034
# lgb02_preds        0.567698
# lgb09_preds        0.560909
# lgb10_preds        0.562639
# lgb11A_preds       0.558477
# lgb11D_preds       0.557072
# lgb14_preds        0.553930
# lgb17_preds        0.558075
# lgb20_preds        0.555115
# lgb20AA_preds      0.553319
# lgb19A_preds       0.552865
# lgb02A_preds       0.564071
# rnn27_preds        0.558103
# rnn12_preds        0.564928
# rdgv19_preds       1.000000

# %%
# Train correlation
preds_df[preds_df['deal_probability'].isnull()][[c for c in preds_df.columns if ('_preds' in c)  \
                                                  and ('difference' not in c) and ('sum' not in c) ]].corr()
# Out:
#                lgb27_preds  rnn_preds  mlp_preds  lgb31_preds  lgb02_preds  \
# lgb27_preds       1.000000   0.930288   0.924283     0.991439     0.989502
# rnn_preds         0.930288   1.000000   0.939951     0.927835     0.927867
# mlp_preds         0.924283   0.939951   1.000000     0.922413     0.921927
# lgb31_preds       0.991439   0.927835   0.922413     1.000000     0.993168
# lgb02_preds       0.989502   0.927867   0.921927     0.993168     1.000000
# lgb09_preds       0.979729   0.926158   0.918064     0.982874     0.984427
# lgb10_preds       0.979341   0.928367   0.920496     0.982519     0.983525
# lgb11A_preds      0.975840   0.927119   0.919275     0.978877     0.980105
# lgb11D_preds      0.973725   0.925632   0.917496     0.976777     0.978173
# lgb14_preds       0.970062   0.924680   0.916323     0.973170     0.975031
# lgb17_preds       0.972503   0.926976   0.919199     0.975607     0.977087
# lgb20_preds       0.970167   0.925169   0.917325     0.973347     0.974891
# lgb20AA_preds     0.967953   0.923007   0.915276     0.970928     0.972462
# lgb19A_preds      0.967059   0.922491   0.914513     0.970094     0.971908
# lgb02A_preds      0.984742   0.928496   0.922121     0.988043     0.989577
# rnn27_preds       0.930692   0.988198   0.935069     0.931468     0.931447
# rnn12_preds       0.932951   0.984113   0.936609     0.932981     0.933333
# rdgv19_preds      0.571110   0.559376   0.561935     0.572757     0.570342
#
#                lgb09_preds  lgb10_preds  lgb11A_preds  lgb11D_preds  \
# lgb27_preds       0.979729     0.979341      0.975840      0.973725
# rnn_preds         0.926158     0.928367      0.927119      0.925632
# mlp_preds         0.918064     0.920496      0.919275      0.917496
# lgb31_preds       0.982874     0.982519      0.978877      0.976777
# lgb02_preds       0.984427     0.983525      0.980105      0.978173
# lgb09_preds       1.000000     0.991413      0.988267      0.986666
# lgb10_preds       0.991413     1.000000      0.992340      0.990473
# lgb11A_preds      0.988267     0.992340      1.000000      0.993474
# lgb11D_preds      0.986666     0.990473      0.993474      1.000000
# lgb14_preds       0.983504     0.986869      0.990047      0.991525
# lgb17_preds       0.984455     0.988382      0.991264      0.992446
# lgb20_preds       0.982575     0.986348      0.989291      0.990493
# lgb20AA_preds     0.979460     0.983340      0.986105      0.987158
# lgb19A_preds      0.980115     0.983483      0.986600      0.988002
# lgb02A_preds      0.989106     0.986654      0.983556      0.981933
# rnn27_preds       0.929748     0.931841      0.930518      0.929068
# rnn12_preds       0.931167     0.933902      0.932743      0.931133
# rdgv19_preds      0.565333     0.566736      0.563841      0.561824
#
#                lgb14_preds  lgb17_preds  lgb20_preds  lgb20AA_preds  \
# lgb27_preds       0.970062     0.972503     0.970167       0.967953
# rnn_preds         0.924680     0.926976     0.925169       0.923007
# mlp_preds         0.916323     0.919199     0.917325       0.915276
# lgb31_preds       0.973170     0.975607     0.973347       0.970928
# lgb02_preds       0.975031     0.977087     0.974891       0.972462
# lgb09_preds       0.983504     0.984455     0.982575       0.979460
# lgb10_preds       0.986869     0.988382     0.986348       0.983340
# lgb11A_preds      0.990047     0.991264     0.989291       0.986105
# lgb11D_preds      0.991525     0.992446     0.990493       0.987158
# lgb14_preds       1.000000     0.995582     0.992887       0.989161
# lgb17_preds       0.995582     1.000000     0.994361       0.990752
# lgb20_preds       0.992887     0.994361     1.000000       0.991763
# lgb20AA_preds     0.989161     0.990752     0.991763       1.000000
# lgb19A_preds      0.991390     0.991955     0.990813       0.987308
# lgb02A_preds      0.978724     0.979791     0.977889       0.974798
# rnn27_preds       0.928224     0.930381     0.928662       0.926462
# rnn12_preds       0.930421     0.932982     0.930992       0.928621
# rdgv19_preds      0.558673     0.561605     0.559851       0.558586
#
#                lgb19A_preds  lgb02A_preds  rnn27_preds  rnn12_preds  \
# lgb27_preds        0.967059      0.984742     0.930692     0.932951
# rnn_preds          0.922491      0.928496     0.988198     0.984113
# mlp_preds          0.914513      0.922121     0.935069     0.936609
# lgb31_preds        0.970094      0.988043     0.931468     0.932981
# lgb02_preds        0.971908      0.989577     0.931447     0.933333
# lgb09_preds        0.980115      0.989106     0.929748     0.931167
# lgb10_preds        0.983483      0.986654     0.931841     0.933902
# lgb11A_preds       0.986600      0.983556     0.930518     0.932743
# lgb11D_preds       0.988002      0.981933     0.929068     0.931133
# lgb14_preds        0.991390      0.978724     0.928224     0.930421
# lgb17_preds        0.991955      0.979791     0.930381     0.932982
# lgb20_preds        0.990813      0.977889     0.928662     0.930992
# lgb20AA_preds      0.987308      0.974798     0.926462     0.928621
# lgb19A_preds       1.000000      0.975407     0.925964     0.928202
# lgb02A_preds       0.975407      1.000000     0.932071     0.933267
# rnn27_preds        0.925964      0.932071     1.000000     0.987051
# rnn12_preds        0.928202      0.933267     0.987051     1.000000
# rdgv19_preds       0.557790      0.567816     0.562929     0.568866
#
#                rdgv19_preds
# lgb27_preds        0.571110
# rnn_preds          0.559376
# mlp_preds          0.561935
# lgb31_preds        0.572757
# lgb02_preds        0.570342
# lgb09_preds        0.565333
# lgb10_preds        0.566736
# lgb11A_preds       0.563841
# lgb11D_preds       0.561824
# lgb14_preds        0.558673
# lgb17_preds        0.561605
# lgb20_preds        0.559851
# lgb20AA_preds      0.558586
# lgb19A_preds       0.557790
# lgb02A_preds       0.567816
# rnn27_preds        0.562929
# rnn12_preds        0.568866
# rdgv19_preds       1.000000

# %%
cols = [c for c in preds_df.columns if '_preds' in c]
cols += [c for c in preds_df.columns if 'difference' in c]
cols += ['price', 'max', 'min', 'avg', 'std', 'med', 'item_seq_number']
categories = ['region', 'param_1_big', 'parent_category_name', 'category_name', \
              'param_2_big', 'param_3_big', 'city_big', 'user_type', 'image_top_1_big']#,
cols += categories
cols = list(set(cols))

# %%
for col in categories:
    preds_df[col] = LabelEncoder().fit_transform(preds_df[col].fillna("0"))

# %%
train_df = preds_df[~preds_df['deal_probability'].isnull()]
test_df = preds_df[preds_df['deal_probability'].isnull()]

# %%
n_estimators = 4000
train_X, valid_X, train_y, valid_y = train_test_split(train_df[cols], y, train_size=.8, random_state=12345)
eval_set = [(train_X,train_y),(valid_X,valid_y)]

# %%
len(train_X)
# Out:
# 1202739

# %%
# %%time
gc.collect()
clf = LGBMRegressor(n_estimators=n_estimators, 
                    max_depth=-1, 
                    feature_fraction= 0.4,
                    num_leaves=32, 
                    learning_rate=.01)#, device='gpu')
clf.fit(train_X, train_y, early_stopping_rounds=80, 
        eval_set=eval_set, eval_metric='rmse', verbose=100, 
        categorical_feature=categories)
# [2796]	training's rmse: 0.208275	valid_1's rmse: 0.212167
# [2500]	training's rmse: 0.208429	valid_1's rmse: 0.212098
# [2107]	training's rmse: 0.208771	valid_1's rmse: 0.212027

# [2754]	training's rmse: 0.207707	valid_1's rmse: 0.211824
# Out:
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.21902	valid_1's rmse: 0.219401
# [200]	training's rmse: 0.212565	valid_1's rmse: 0.213184
# [300]	training's rmse: 0.211427	valid_1's rmse: 0.212246
# [400]	training's rmse: 0.211063	valid_1's rmse: 0.212064
# [500]	training's rmse: 0.210831	valid_1's rmse: 0.211999
# [600]	training's rmse: 0.210636	valid_1's rmse: 0.21196
# [700]	training's rmse: 0.210465	valid_1's rmse: 0.211937
# [800]	training's rmse: 0.210309	valid_1's rmse: 0.211924
# [900]	training's rmse: 0.210162	valid_1's rmse: 0.211914
# [1000]	training's rmse: 0.210015	valid_1's rmse: 0.211905
# [1100]	training's rmse: 0.209872	valid_1's rmse: 0.2119
# [1200]	training's rmse: 0.209735	valid_1's rmse: 0.211895
# [1300]	training's rmse: 0.209601	valid_1's rmse: 0.211888
# [1400]	training's rmse: 0.209466	valid_1's rmse: 0.211882
# [1500]	training's rmse: 0.209329	valid_1's rmse: 0.211879
# [1600]	training's rmse: 0.209195	valid_1's rmse: 0.211875
# [1700]	training's rmse: 0.209064	valid_1's rmse: 0.21187
# [1800]	training's rmse: 0.208932	valid_1's rmse: 0.211868
# [1900]	training's rmse: 0.208801	valid_1's rmse: 0.211864
# [2000]	training's rmse: 0.20867	valid_1's rmse: 0.21186
# [2100]	training's rmse: 0.208542	valid_1's rmse: 0.211855
# [2200]	training's rmse: 0.208417	valid_1's rmse: 0.211852
# [2300]	training's rmse: 0.208291	valid_1's rmse: 0.211848
# [2400]	training's rmse: 0.208165	valid_1's rmse: 0.211847
# [2500]	training's rmse: 0.208042	valid_1's rmse: 0.211845
# [2600]	training's rmse: 0.207917	valid_1's rmse: 0.211843
# [2700]	training's rmse: 0.207793	valid_1's rmse: 0.211841
# [2800]	training's rmse: 0.207668	valid_1's rmse: 0.211839
# [2900]	training's rmse: 0.207544	valid_1's rmse: 0.211837
# [3000]	training's rmse: 0.20742	valid_1's rmse: 0.211837
# Early stopping, best iteration is:
# [2988]	training's rmse: 0.207435	valid_1's rmse: 0.211836
# CPU times: user 1h 7min 46s, sys: 16.8 s, total: 1h 8min 2s
# Wall time: 8min 54s

# %%
sorted(zip(clf.feature_importances_, train_X.columns ),key=lambda x: -x[0])
# Out:
# [(5377, 'city_big'),
#  (4350, 'param_1_big'),
#  (3310, 'category_name'),
#  (3188, 'region'),
#  (2211, 'image_top_1_big'),
#  (1337, 'rdgv19_preds'),
#  (1286, 'difference_rnn_preds__rnn27_preds'),
#  (1116, 'difference_rnn_preds__rnn12_preds'),
#  (1044, 'param_3_big'),
#  (908, 'difference_rnn27_preds__rnn12_preds'),
#  (907, 'item_seq_number'),
#  (907, 'difference_lgb11D_preds__lgb14_preds'),
#  (796, 'difference_lgb09_preds__lgb02A_preds'),
#  (783, 'price'),
#  (771, 'difference_lgb31_preds__lgb09_preds'),
#  (769, 'difference_lgb10_preds__lgb20_preds'),
#  (740, 'difference_lgb09_preds__lgb10_preds'),
#  (738, 'difference_lgb14_preds__lgb19A_preds'),
#  (737, 'difference_lgb20_preds__lgb20AA_preds'),
#  (736, 'difference_lgb14_preds__lgb20_preds'),
#  (731, 'difference_lgb20_preds__lgb19A_preds'),
#  (726, 'difference_lgb11D_preds__lgb20AA_preds'),
#  (721, 'difference_rnn_preds__mlp_preds'),
#  (715, 'difference_lgb11D_preds__lgb20_preds'),
#  (714, 'difference_mlp_preds__rnn27_preds'),
#  (686, 'difference_lgb31_preds__lgb20_preds'),
#  (669, 'difference_lgb20AA_preds__lgb19A_preds'),
#  (667, 'difference_lgb11D_preds__lgb19A_preds'),
#  (666, 'difference_lgb31_preds__lgb02A_preds'),
#  (663, 'difference_mlp_preds__lgb31_preds'),
#  (658, 'param_2_big'),
#  (656, 'difference_lgb10_preds__lgb02A_preds'),
#  (653, 'difference_lgb31_preds__lgb10_preds'),
#  (636, 'min'),
#  (633, 'difference_lgb09_preds__lgb20AA_preds'),
#  (628, 'difference_lgb10_preds__lgb20AA_preds'),
#  (627, 'difference_lgb14_preds__lgb20AA_preds'),
#  (622, 'difference_mlp_preds__rnn12_preds'),
#  (621, 'difference_lgb10_preds__lgb14_preds'),
#  (619, 'sums_lgb20_preds__rnn27_preds'),
#  (615, 'difference_lgb11D_preds__lgb02A_preds'),
#  (604, 'difference_lgb31_preds__lgb19A_preds'),
#  (601, 'difference_lgb09_preds__lgb19A_preds'),
#  (594, 'difference_lgb31_preds__lgb14_preds'),
#  (593, 'difference_lgb10_preds__lgb19A_preds'),
#  (589, 'difference_lgb19A_preds__lgb02A_preds'),
#  (588, 'difference_lgb31_preds__lgb20AA_preds'),
#  (587, 'difference_lgb10_preds__lgb11D_preds'),
#  (572, 'difference_lgb20_preds__lgb02A_preds'),
#  (571, 'difference_mlp_preds__lgb02A_preds'),
#  (569, 'difference_lgb20AA_preds__lgb02A_preds'),
#  (562, 'difference_mlp_preds__lgb11D_preds'),
#  (543, 'sums_mlp_preds__lgb20_preds'),
#  (540, 'mlp_preds'),
#  (538, 'difference_lgb09_preds__lgb20_preds'),
#  (535, 'difference_lgb09_preds__lgb14_preds'),
#  (535, 'difference_lgb09_preds__lgb11D_preds'),
#  (534, 'difference_lgb31_preds__rnn12_preds'),
#  (532, 'difference_lgb14_preds__lgb02A_preds'),
#  (520, 'sums_lgb20_preds__rnn12_preds'),
#  (515, 'difference_lgb31_preds__lgb11D_preds'),
#  (513, 'lgb17_preds'),
#  (503, 'difference_mlp_preds__lgb20AA_preds'),
#  (490, 'difference_lgb19A_preds__rnn12_preds'),
#  (480, 'difference_mlp_preds__lgb19A_preds'),
#  (479, 'difference_mlp_preds__lgb20_preds'),
#  (479, 'difference_mlp_preds__lgb10_preds'),
#  (477, 'difference_lgb02A_preds__rnn12_preds'),
#  (475, 'sums_lgb20_preds__lgb20AA_preds'),
#  (469, 'difference_lgb31_preds__rnn27_preds'),
#  (468, 'difference_mlp_preds__lgb14_preds'),
#  (467, 'difference_rnn_preds__lgb20AA_preds'),
#  (463, 'difference_lgb10_preds__rnn12_preds'),
#  (456, 'difference_lgb20AA_preds__rnn12_preds'),
#  (453, 'difference_rnn_preds__lgb19A_preds'),
#  (450, 'rnn27_preds'),
#  (447, 'difference_mlp_preds__lgb09_preds'),
#  (443, 'difference_lgb02A_preds__rnn27_preds'),
#  (437, 'difference_rnn_preds__lgb31_preds'),
#  (433, 'sums_lgb20AA_preds__rnn27_preds'),
#  (424, 'difference_lgb14_preds__rnn12_preds'),
#  (423, 'std'),
#  (423, 'difference_lgb09_preds__rnn27_preds'),
#  (415, 'difference_rnn_preds__lgb10_preds'),
#  (409, 'difference_rnn_preds__lgb20_preds'),
#  (406, 'difference_lgb20AA_preds__rnn27_preds'),
#  (400, 'difference_lgb14_preds__rnn27_preds'),
#  (393, 'difference_lgb19A_preds__rnn27_preds'),
#  (393, 'lgb27_preds'),
#  (393, 'sums_mlp_preds__lgb20AA_preds'),
#  (390, 'difference_lgb09_preds__rnn12_preds'),
#  (386, 'sums_lgb20AA_preds__rnn12_preds'),
#  (386, 'difference_lgb10_preds__rnn27_preds'),
#  (385, 'difference_rnn_preds__lgb02A_preds'),
#  (385, 'sums_mlp_preds__lgb19A_preds'),
#  (384, 'difference_lgb20_preds__rnn12_preds'),
#  (381, 'sums_lgb19A_preds__rnn12_preds'),
#  (378, 'lgb20_preds'),
#  (375, 'difference_rnn_preds__lgb14_preds'),
#  (373, 'difference_lgb11D_preds__rnn27_preds'),
#  (372, 'sums_lgb19A_preds__rnn27_preds'),
#  (371, 'sums_mlp_preds__rnn27_preds'),
#  (368, 'difference_rnn_preds__lgb11D_preds'),
#  (367, 'sums_mlp_preds__rnn12_preds'),
#  (366, 'difference_lgb11D_preds__rnn12_preds'),
#  (365, 'difference_rnn_preds__lgb09_preds'),
#  (360, 'difference_lgb20_preds__rnn27_preds'),
#  (357, 'sums_lgb20_preds__lgb19A_preds'),
#  (356, 'rnn12_preds'),
#  (328, 'sums_lgb20AA_preds__lgb19A_preds'),
#  (317, 'parent_category_name'),
#  (317, 'rnn_preds'),
#  (316, 'sums_rnn27_preds__rnn12_preds'),
#  (312, 'lgb20AA_preds'),
#  (305, 'sums_mlp_preds__lgb14_preds'),
#  (304, 'sums_lgb14_preds__rnn12_preds'),
#  (304, 'sums_rnn_preds__mlp_preds'),
#  (299, 'sums_lgb14_preds__rnn27_preds'),
#  (295, 'sums_lgb14_preds__lgb20_preds'),
#  (289, 'lgb11A_preds'),
#  (285, 'lgb02_preds'),
#  (277, 'sums_mlp_preds__lgb02A_preds'),
#  (267, 'sums_rnn_preds__rnn27_preds'),
#  (259, 'sums_lgb14_preds__lgb20AA_preds'),
#  (258, 'sums_mlp_preds__lgb31_preds'),
#  (253, 'lgb14_preds'),
#  (247, 'max'),
#  (227, 'sums_rnn_preds__rnn12_preds'),
#  (227, 'lgb31_preds'),
#  (225, 'sums_mlp_preds__lgb09_preds'),
#  (220, 'sums_lgb14_preds__lgb19A_preds'),
#  (219, 'lgb09_preds'),
#  (217, 'sums_mlp_preds__lgb11D_preds'),
#  (214, 'lgb02A_preds'),
#  (211, 'sums_lgb31_preds__rnn12_preds'),
#  (210, 'lgb19A_preds'),
#  (206, 'sums_lgb09_preds__rnn27_preds'),
#  (202, 'sums_mlp_preds__lgb10_preds'),
#  (200, 'sums_lgb31_preds__rnn27_preds'),
#  (198, 'sums_rnn_preds__lgb20AA_preds'),
#  (196, 'lgb11D_preds'),
#  (191, 'sums_lgb11D_preds__rnn12_preds'),
#  (185, 'sums_lgb31_preds__lgb02A_preds'),
#  (184, 'sums_lgb02A_preds__rnn27_preds'),
#  (183, 'sums_rnn_preds__lgb11D_preds'),
#  (179, 'sums_lgb10_preds__rnn27_preds'),
#  (177, 'sums_lgb02A_preds__rnn12_preds'),
#  (175, 'sums_rnn_preds__lgb09_preds'),
#  (174, 'sums_lgb09_preds__rnn12_preds'),
#  (173, 'sums_lgb10_preds__rnn12_preds'),
#  (172, 'sums_lgb19A_preds__lgb02A_preds'),
#  (170, 'lgb10_preds'),
#  (167, 'sums_rnn_preds__lgb20_preds'),
#  (167, 'sums_lgb11D_preds__rnn27_preds'),
#  (166, 'sums_rnn_preds__lgb19A_preds'),
#  (165, 'sums_rnn_preds__lgb10_preds'),
#  (164, 'sums_rnn_preds__lgb31_preds'),
#  (160, 'sums_lgb31_preds__lgb20AA_preds'),
#  (159, 'sums_lgb11D_preds__lgb20AA_preds'),
#  (153, 'sums_lgb31_preds__lgb09_preds'),
#  (152, 'sums_lgb09_preds__lgb02A_preds'),
#  (150, 'sums_lgb10_preds__lgb20AA_preds'),
#  (149, 'sums_lgb11D_preds__lgb20_preds'),
#  (148, 'sums_rnn_preds__lgb02A_preds'),
#  (148, 'sums_lgb11D_preds__lgb02A_preds'),
#  (147, 'sums_lgb31_preds__lgb14_preds'),
#  (145, 'sums_lgb10_preds__lgb14_preds'),
#  (143, 'sums_lgb09_preds__lgb20AA_preds'),
#  (143, 'sums_lgb11D_preds__lgb14_preds'),
#  (142, 'sums_lgb10_preds__lgb02A_preds'),
#  (141, 'sums_lgb20AA_preds__lgb02A_preds'),
#  (141, 'sums_lgb10_preds__lgb19A_preds'),
#  (141, 'sums_lgb09_preds__lgb19A_preds'),
#  (138, 'sums_lgb31_preds__lgb11D_preds'),
#  (136, 'sums_rnn_preds__lgb14_preds'),
#  (135, 'sums_lgb10_preds__lgb11D_preds'),
#  (134, 'sums_lgb11D_preds__lgb19A_preds'),
#  (133, 'sums_lgb09_preds__lgb10_preds'),
#  (133, 'sums_lgb31_preds__lgb10_preds'),
#  (132, 'sums_lgb31_preds__lgb19A_preds'),
#  (126, 'sums_lgb31_preds__lgb20_preds'),
#  (124, 'sums_lgb20_preds__lgb02A_preds'),
#  (123, 'avg'),
#  (119, 'sums_lgb14_preds__lgb02A_preds'),
#  (118, 'sums_lgb10_preds__lgb20_preds'),
#  (109, 'med'),
#  (106, 'sums_lgb09_preds__lgb14_preds'),
#  (105, 'sums_lgb09_preds__lgb11D_preds'),
#  (98, 'sums_lgb09_preds__lgb20_preds'),
#  (76, 'user_type')]

# %%
n_estimators = 2800
train_X = train_df[cols]
train_y = y
eval_set = [(train_X,train_y)]
len(train_X)
# Out:
# 1503424

# %%
# %%time
y_predls = []
for i in range(5):
    clf = LGBMRegressor(n_estimators=n_estimators, 
                    max_depth=-1, 
                    feature_fraction= 0.4,
                    num_leaves=32, 
                    seed = i, 
                    learning_rate=.01)#, device='gpu')
    clf.fit(train_X, train_y, early_stopping_rounds=80, 
        eval_set=eval_set, eval_metric='rmse', verbose=100, 
        categorical_feature=categories)
    y_predls.append(clf.predict(test_df[cols]))
# Out:
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.219108
# [200]	training's rmse: 0.212688
# [300]	training's rmse: 0.211588
# [400]	training's rmse: 0.211255
# [500]	training's rmse: 0.211051
# [600]	training's rmse: 0.210881
# [700]	training's rmse: 0.210733
# [800]	training's rmse: 0.210599
# [900]	training's rmse: 0.21047
# [1000]	training's rmse: 0.210346
# [1100]	training's rmse: 0.210226
# [1200]	training's rmse: 0.210109
# [1300]	training's rmse: 0.209995
# [1400]	training's rmse: 0.209883
# [1500]	training's rmse: 0.209771
# [1600]	training's rmse: 0.209662
# [1700]	training's rmse: 0.209553
# [1800]	training's rmse: 0.209445
# [1900]	training's rmse: 0.209337
# [2000]	training's rmse: 0.209231
# [2100]	training's rmse: 0.209123
# [2200]	training's rmse: 0.209016
# [2300]	training's rmse: 0.208912
# [2400]	training's rmse: 0.208809
# [2500]	training's rmse: 0.208705
# [2600]	training's rmse: 0.2086
# [2700]	training's rmse: 0.208496
# [2800]	training's rmse: 0.208393
# Did not meet early stopping. Best iteration is:
# [2800]	training's rmse: 0.208393
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.219108
# [200]	training's rmse: 0.212693
# [300]	training's rmse: 0.21159
# [400]	training's rmse: 0.211256
# [500]	training's rmse: 0.211049
# [600]	training's rmse: 0.210883
# [700]	training's rmse: 0.210734
# [800]	training's rmse: 0.210602
# [900]	training's rmse: 0.210476
# [1000]	training's rmse: 0.210348
# [1100]	training's rmse: 0.210227
# [1200]	training's rmse: 0.210107
# [1300]	training's rmse: 0.209991
# [1400]	training's rmse: 0.209877
# [1500]	training's rmse: 0.209765
# [1600]	training's rmse: 0.209655
# [1700]	training's rmse: 0.209544
# [1800]	training's rmse: 0.209435
# [1900]	training's rmse: 0.209327
# [2000]	training's rmse: 0.209217
# [2100]	training's rmse: 0.209111
# [2200]	training's rmse: 0.209006
# [2300]	training's rmse: 0.208902
# [2400]	training's rmse: 0.208795
# [2500]	training's rmse: 0.208692
# [2600]	training's rmse: 0.208587
# [2700]	training's rmse: 0.208482
# [2800]	training's rmse: 0.208379
# Did not meet early stopping. Best iteration is:
# [2800]	training's rmse: 0.208379
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.219105
# [200]	training's rmse: 0.212686
# [300]	training's rmse: 0.211586
# [400]	training's rmse: 0.211254
# [500]	training's rmse: 0.211052
# [600]	training's rmse: 0.210886
# [700]	training's rmse: 0.210738
# [800]	training's rmse: 0.210602
# [900]	training's rmse: 0.210475
# [1000]	training's rmse: 0.210352
# [1100]	training's rmse: 0.210236
# [1200]	training's rmse: 0.210118
# [1300]	training's rmse: 0.210003
# [1400]	training's rmse: 0.209892
# [1500]	training's rmse: 0.209781
# [1600]	training's rmse: 0.209669
# [1700]	training's rmse: 0.209562
# [1800]	training's rmse: 0.209451
# [1900]	training's rmse: 0.209344
# [2000]	training's rmse: 0.209236
# [2100]	training's rmse: 0.209128
# [2200]	training's rmse: 0.209023
# [2300]	training's rmse: 0.208917
# [2400]	training's rmse: 0.208811
# [2500]	training's rmse: 0.208707
# [2600]	training's rmse: 0.208602
# [2700]	training's rmse: 0.208497
# [2800]	training's rmse: 0.208393
# Did not meet early stopping. Best iteration is:
# [2800]	training's rmse: 0.208393
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.219109
# [200]	training's rmse: 0.212695
# [300]	training's rmse: 0.211591
# [400]	training's rmse: 0.211257
# [500]	training's rmse: 0.21105
# [600]	training's rmse: 0.210883
# [700]	training's rmse: 0.210735
# [800]	training's rmse: 0.2106
# [900]	training's rmse: 0.210473
# [1000]	training's rmse: 0.210348
# [1100]	training's rmse: 0.210227
# [1200]	training's rmse: 0.21011
# [1300]	training's rmse: 0.209997
# [1400]	training's rmse: 0.209885
# [1500]	training's rmse: 0.209775
# [1600]	training's rmse: 0.209664
# [1700]	training's rmse: 0.209555
# [1800]	training's rmse: 0.209446
# [1900]	training's rmse: 0.209337
# [2000]	training's rmse: 0.209231
# [2100]	training's rmse: 0.209122
# [2200]	training's rmse: 0.209015
# [2300]	training's rmse: 0.208909
# [2400]	training's rmse: 0.208805
# [2500]	training's rmse: 0.208701
# [2600]	training's rmse: 0.208597
# [2700]	training's rmse: 0.208493
# [2800]	training's rmse: 0.20839
# Did not meet early stopping. Best iteration is:
# [2800]	training's rmse: 0.20839
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.219106
# [200]	training's rmse: 0.212682
# [300]	training's rmse: 0.211581
# [400]	training's rmse: 0.211251
# [500]	training's rmse: 0.211046
# [600]	training's rmse: 0.210876
# [700]	training's rmse: 0.210725
# [800]	training's rmse: 0.210592
# [900]	training's rmse: 0.210465
# [1000]	training's rmse: 0.21034
# [1100]	training's rmse: 0.210222
# [1200]	training's rmse: 0.210107
# [1300]	training's rmse: 0.209993
# [1400]	training's rmse: 0.20988
# [1500]	training's rmse: 0.209769
# [1600]	training's rmse: 0.209657
# [1700]	training's rmse: 0.209549
# [1800]	training's rmse: 0.209441
# [1900]	training's rmse: 0.209333
# [2000]	training's rmse: 0.209226
# [2100]	training's rmse: 0.20912
# [2200]	training's rmse: 0.209012
# [2300]	training's rmse: 0.208909
# [2400]	training's rmse: 0.208802
# [2500]	training's rmse: 0.208696
# [2600]	training's rmse: 0.208588
# [2700]	training's rmse: 0.208485
# [2800]	training's rmse: 0.208381
# Did not meet early stopping. Best iteration is:
# [2800]	training's rmse: 0.208381
# CPU times: user 6h 57min 8s, sys: 1min 53s, total: 6h 59min 2s
# Wall time: 55min 18s

# %%
test_df['deal_probability'] = sum(y_predls)/len(y_predls)
test_df['deal_probability'] = np.clip(test_df['deal_probability'], .0001, .9999)
test_df[['item_id', 'deal_probability']].to_csv('../lgbbsub_2006AL2.csv.gz', compression='gzip', index=False, header=True)
test_df[['item_id', 'deal_probability']].head()
# Out:
#               item_id  deal_probability
# 1503424  6544e41a8817          0.469501
# 1503425  65b9484d670f          0.138727
# 1503426  8bab230b2ecd          0.153822
# 1503427  8e348601fefc          0.098113
# 1503428  8bd2fe400b89          0.162731
