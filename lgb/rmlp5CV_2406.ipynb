# %%
# https://www.kaggle.com/tunguz/bow-meta-text-and-dense-features-lgbm-clone?scriptVersionId=3540839

# Models Packages
from sklearn import metrics
from sklearn.metrics import mean_squared_error
import time, gc
import pandas as pd
import numpy as np
from sklearn import preprocessing
from nltk.corpus import stopwords 
from sklearn.pipeline import FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from scipy.sparse import hstack, csr_matrix
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import matplotlib.pyplot as plt
import pymorphy2
import nltk, re
from nltk.tokenize import ToktokTokenizer
from multiprocessing import cpu_count, Pool
from sklearn.linear_model import Ridge

# %%
#path = '../input/'
path = "/home/darragh/avito/data/"
#path = '/Users/dhanley2/Documents/avito/data/'
path = '/home/ubuntu/avito/data/'
start_time = time.time()
full = False

print('[{}] Load Train/Test'.format(time.time() - start_time))
traindf = pd.read_csv(path + 'train.csv.zip', index_col = "item_id", parse_dates = ["activation_date"], compression = 'zip')
traindex = traindf.index
testdf = pd.read_csv(path + 'test.csv.zip', index_col = "item_id", parse_dates = ["activation_date"])
testdex = testdf.index
y = traindf.deal_probability.copy()
traindf.drop("deal_probability",axis=1, inplace=True)
print('Train shape: {} Rows, {} Columns'.format(*traindf.shape))
print('Test shape: {} Rows, {} Columns'.format(*testdf.shape))
traindf['activation_date'].value_counts()

(traindf['image_top_1'] == traindf['image_top_1']).value_counts()
(testdf['image_top_1'] == testdf['image_top_1']).value_counts()
# Out:
# [6.723403930664062e-05] Load Train/Test
# Train shape: 1503424 Rows, 16 Columns
# Test shape: 508438 Rows, 16 Columns
# True     465829
# False     42609
# Name: image_top_1, dtype: int64

# %%
print('[{}] Create Validation Index'.format(time.time() - start_time))
if full:
    trnidx = (traindf.activation_date<=pd.to_datetime('2017-03-28')).values
    validx = (traindf.activation_date>=pd.to_datetime('2017-03-29')).values
else:
    trnidx = (traindf.activation_date<=pd.to_datetime('2017-03-26')).values
    validx = (traindf.activation_date>=pd.to_datetime('2017-03-27')).values

print('[{}] Combine Train and Test'.format(time.time() - start_time))
df = pd.concat([traindf,testdf],axis=0)
del traindf,testdf
gc.collect()
df['idx'] = range(df.shape[0])
print('\nAll Data shape: {} Rows, {} Columns'.format(*df.shape))

#print('[{}] Count NA row wise'.format(time.time() - start_time))
#df['NA_count_rows'] = df.isnull().sum(axis=1)
# Out:
# [27.567209720611572] Create Validation Index
# [27.574214935302734] Combine Train and Test
#
# All Data shape: 2011862 Rows, 17 Columns

# %%
print('[{}] Load meta image engineered features'.format(time.time() - start_time))
featimgmeta = pd.concat([pd.read_csv(path + '../features/img_features_%s.csv.gz'%(i)) for i in range(6)])
featimgmeta.rename(columns = {'name':'image'}, inplace = True)
featimgmeta['image'] = featimgmeta['image'].str.replace('.jpg', '')
df = df.reset_index('item_id').merge(featimgmeta, on = ['image'], how = 'left').set_index('item_id')
for col in featimgmeta.columns.values[1:]:
    df[col].fillna(-1, inplace = True)
    df[col].astype(np.float32, inplace = True)
    
print('[{}] Load translated image engineered features'.format(time.time() - start_time))
feattrlten = pd.concat([pd.read_csv(path + '../features/translate_trn_en.csv.gz', compression = 'gzip'),
                        pd.read_csv(path + '../features/translate_tst_en.csv.gz', compression = 'gzip')])
# feattrlten = pd.concat([pd.read_pickle(path + '../features/translate_trn_en.pkl'),
#                        pd.read_pickle(path + '../features/translate_tst_en.pkl')])
feattrlten.fillna('', inplace = True)
feattrlten['translation'] = feattrlten['title_translated'] + ' ' + feattrlten['param_1_translated'] + ' ' \
            + feattrlten['param_2_translated'] + ' ' + feattrlten['param_3_translated'] + ' '  \
            + feattrlten['category_name_translated'] + ' ' + feattrlten['parent_category_name_translated']
feattrlten = feattrlten.set_index('item_id')[['translation']]
feattrlten.head()
df = pd.merge(df, feattrlten, left_index=True, right_index=True, how='left')
del feattrlten
gc.collect()
# Out:
# [28.53509545326233] Load meta image engineered features
# [48.18177270889282] Load translated image engineered features
# 48

# %%
print('[{}] Load other engineered features'.format(time.time() - start_time))
featlatlon = pd.read_csv(path + '../features/avito_region_city_features.csv') # https://www.kaggle.com/frankherfert/region-and-city-details-with-lat-lon-and-clusters
featlatlon.drop(['city_region', 'city_region_id', 'region_id'], 1, inplace = True)
featpop    = pd.read_csv(path + '../features/city_population_wiki_v3.csv') # https://www.kaggle.com/stecasasso/russian-city-population-from-wikipedia/comments
featusrttl = pd.read_csv(path + '../features/user_agg.csv.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
featusrcat = pd.read_csv(path + '../features/usercat_agg.csv.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
featusrprd = pd.read_csv(path + '../features/user_activ_period_stats.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
featrdgtxt = pd.read_csv(path + '../features/ridgeText5CV.csv.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
#featrdgtxts = pd.read_csv(path + '../features/ridgeTextStr5CV.csv.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
featrdgimg = pd.read_csv(path + '../features/ridgeImg5CV.csv.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
#featrdgprc = pd.read_csv(path + '../features/price_category_ratios.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
featrdgprc = pd.read_csv(path + '../features/price_seq_category_ratios.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
featrdgprc.fillna(-1, inplace = True)
featrdgrnk = pd.read_csv(path + '../features/price_rank_ratios0906.gz', compression = 'gzip') # created with R script and stemmer
featrdgrnk.isnull().sum()
featnumf = pd.read_csv(path + '../features/numericFeats.gz', compression = 'gzip') 
featnumf.fillna(0, inplace = True)
#featencfst = pd.read_csv(path + '../features/alldf_bayes_fest_1206.gz', compression = 'gzip')
featprtfst = pd.read_csv(path + '../features/pratios_fest_1206.gz', compression = 'gzip')

#featprmenc = pd.read_csv(path + '../features/alldf_bayes_mean_param_1006.gz', compression = 'gzip') 
featprmtro = pd.read_csv(path + '../features/price_param_ratios1006.gz', compression = 'gzip') 
#featimgnet = pd.read_csv(path + '../features/imgnet_decode_feats.csv.gz', compression = 'gzip')
featldlag  = pd.read_csv(path + '../features/pseq_leadlag_festivities_1906.gz', compression = 'gzip')

featimgprc = pd.read_csv(path + '../features/price_imagetop1_ratios.gz', compression = 'gzip') # created with features/make/priceImgRatios2705.R
featenc = pd.read_csv(path + '../features/alldf_bayes_mean.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
featct  = pd.read_csv(path + '../features/alldf_count.gz', compression = 'gzip') # created with features/make/user_actagg_1705.py
featusrttl.rename(columns={'title': 'all_titles'}, inplace = True)
df = df.reset_index().merge(featpop, on = 'city', how = 'left')
df = df.merge(featlatlon, on = ['city', 'region'], how = 'left')
df['population'].fillna(-1, inplace = True)
df = df.set_index('item_id')
keep = ['user_id', 'all_titles', 'user_avg_price', 'user_ad_ct']
df = df.reset_index().merge(featusrttl[keep], on = 'user_id').set_index('item_id')
keep = ['user_id', 'parent_category_name', 'usercat_avg_price', 'usercat_ad_ct']
gc.collect()
df = df.reset_index().merge(featusrcat[keep], on = ['user_id', 'parent_category_name']).set_index('item_id')
keep = ['user_id', 'user_activ_sum', 'user_activ_mean', 'user_activ_var']
gc.collect()
df = df.reset_index().merge(featusrprd[keep], on = ['user_id'], how = 'left').set_index('item_id')
#df = df.reset_index().merge(featimgnet, on = ['item_id'], how = 'left').set_index('item_id')

print('\nAll Data shape: {} Rows, {} Columns'.format(*df.shape))
# Out:
# [76.77756810188293] Load other engineered features
#
# All Data shape: 2011862 Rows, 44 Columns

# %%
print('[{}] Resort data correctly'.format(time.time() - start_time))
df.sort_values('idx', inplace = True)
df.drop(['idx'], axis=1,inplace=True)
df.reset_index(inplace = True)
df.head()
df = pd.concat([df.reset_index(),featenc, featct, featrdgtxt, featrdgprc, featimgprc, featrdgrnk, featnumf, featprmtro, featprtfst, featldlag],axis=1)

print('[{}] Create folds'.format(time.time() - start_time))
foldls = [["2017-03-15", "2017-03-16", "2017-03-17"], \
       ["2017-03-18", "2017-03-19", "2017-03-20"], \
       ["2017-03-21", "2017-03-22", "2017-03-23"], \
       ["2017-03-24", "2017-03-25", "2017-03-26"], \
        ["2017-03-27", "2017-03-28", "2017-03-29", \
            "2017-03-30", "2017-03-31", "2017-04-01", \
            "2017-04-02", "2017-04-03","2017-04-07"]]
foldls = [[pd.to_datetime(d) for d in f] for f in foldls]
df['fold'] = -1
for t, fold in enumerate(foldls):
    df['fold'][df.activation_date.isin(fold)] = t
df['fold'].value_counts()
df.head()
# Out:
# [198.05890202522278] Resort data correctly
# [203.28921937942505] Create folds
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#    index       item_id       user_id                 region              city  \
# 0      0  b912c3c6a6ad  e00f8ff2eaf9   Свердловская область      Екатеринбург
# 1      1  2dac0150717d  39aeb48f0017      Самарская область            Самара
# 2      2  ba83aefab5dc  91e2f88dd6e3     Ростовская область    Ростов-на-Дону
# 3      3  02996f1dd2ea  bf5cccea572d              Татарстан  Набережные Челны
# 4      4  7c90be56d2ab  ef50846afc0b  Волгоградская область         Волгоград
#
#   parent_category_name               category_name  \
# 0          Личные вещи  Товары для детей и игрушки
# 1      Для дома и дачи           Мебель и интерьер
# 2  Бытовая электроника               Аудио и видео
# 3          Личные вещи  Товары для детей и игрушки
# 4            Транспорт                  Автомобили
#
#                        param_1     param_2 param_3  ...  seq_seqsort_lead  \
# 0    Постельные принадлежности         NaN     NaN  ...                -1
# 1                       Другое         NaN     NaN  ...                -1
# 2  Видео, DVD и Blu-ray плееры         NaN     NaN  ...                10
# 3         Автомобильные кресла         NaN     NaN  ...                -1
# 4                   С пробегом  ВАЗ (LADA)    2110  ...                -1
#
#   seq_seqsort_lag_diff  seq_seqsort_lead_diff  item_seq_repeat_postings  \
# 0                    1                   -999                         1
# 1                 -999                   -999                         1
# 2                    1                     -1                         1
# 3                    3                   -999                         1
# 4                 -999                   -999                         1
#
#   category_repeat_postings price_min_sequence price_min_sequence_diff  \
# 0                        3             4000.0                 -3600.0
# 1                        1             3000.0                     0.0
# 2                        1             2000.0                  2000.0
# 3                        7                0.0                  2200.0
# 4                        1            40000.0                     0.0
#
#    seq_min_sequence  seq_min_sequence_diff  fold
# 0                 1                      1     4
# 1                19                      0     3
# 2                 1                      8     1
# 3                20                    266     3
# 4                 3                      0     0
#
# [5 rows x 164 columns]

# %%
df['ridge_img'] = featrdgimg['ridge_img_preds'].values
df = df.set_index('item_id')
df.drop(['index'], axis=1,inplace=True)
df.columns
del featusrttl, featusrcat, featusrprd, featenc, featrdgprc, featimgprc, featnumf, featprmtro,  featprtfst, featldlag
# del featusrttl, featusrcat, featusrprd, featenc, featrdgtxts
gc.collect()
# Out:
# 190

# %%
print('[{}] Feature Engineering'.format(time.time() - start_time))
for col in df.columns:
    if 'price' in col:
        print(f'Fill {col}')
        df[col].fillna(-999,inplace=True)

for col in df.columns:
    if 'user_activ' in col:
        print(f'fill {col}')
        df[col].fillna(-9,inplace=True)
df["image_top_1"].fillna(-999,inplace=True)

del featct, featlatlon, featimgmeta, featpop, featrdgimg, featrdgtxt
gc.collect()

print('[{}] Manage Memory'.format(time.time() - start_time))
for col in df.columns:
    if np.float64 == df[col].dtype:
        df[col] = df[col].astype(np.float32)
    if np.int64 == df[col].dtype:
        df[col] = df[col].astype(np.int32)
    gc.collect()
df.dtypes
# Out:
# [212.0873899459839] Feature Engineering
# Fill price
# Fill user_avg_price
# Fill usercat_avg_price
# Fill pcat_price_rratio
# Fill cat_price_rratio
# Fill ttl_price_rratio
# Fill dscr_price_rratio
# Fill pcat_log_price_rratio
# Fill user_log_price_rratio
# Fill cat_price_iratio
# Fill reg_price_iratio
# Fill reg_price_gratio
# Fill cty_price_gratio
# Fill ttlst_price_rratio
# Fill ttlst_city_price_rratio
# Fill ttlst_prm_price_rratio
# Fill par1cty_price_prratio
# Fill par2cty_price_prratio
# Fill par1utyp_price_prratio
# Fill par2utyp_price_prratio
# Fill rmean_price_byseq3_1
# Fill rmean_price_byseq3_2
# Fill rmean_price_byseq3_3
# Fill rmean_price_byseq8_1
# Fill rmean_price_byseq8_2
# Fill rmean_price_byseq8_3
# Fill price_datesort_lag
# Fill price_datesort_lead
# Fill price_seqsort_lag
# Fill price_seqsort_lead
# Fill price_min_sequence
# Fill price_min_sequence_diff
# fill user_activ_sum
# fill user_activ_mean
# fill user_activ_var
# [212.31325244903564] Manage Memory
# user_id                                                                                        object
# region                                                                                         object
# city                                                                                           object
# parent_category_name                                                                           object
# category_name                                                                                  object
# param_1                                                                                        object
# param_2                                                                                        object
# param_3                                                                                        object
# title                                                                                          object
# description                                                                                    object
# price                                                                                         float32
# item_seq_number                                                                                 int32
# activation_date                                                                        datetime64[ns]
# user_type                                                                                      object
# image                                                                                          object
# image_top_1                                                                                   float32
# dullness                                                                                      float32
# whiteness                                                                                     float32
# dominant_red                                                                                  float32
# dominant_green                                                                                float32
# dominant_blue                                                                                 float32
# average_red                                                                                   float32
# average_green                                                                                 float32
# average_blue                                                                                  float32
# width                                                                                         float32
# height                                                                                        float32
# size                                                                                          float32
# blurness                                                                                      float32
# translation                                                                                    object
# population                                                                                    float32
#                                                                                             ...
# parent_category_name_category_name_param_1_param_2_param_3_region_user_type_fratio5           float32
# parent_category_name_category_name_param_1_param_2_param_3_region_user_type_count5              int32
# na_ratio_user                                                                                 float32
# zero_ratio_user                                                                               float32
# rmean_price_byseq3_1                                                                          float32
# rmean_price_byseq3_2                                                                          float32
# rmean_price_byseq3_3                                                                          float32
# rmean_price_byseq8_1                                                                          float32
# rmean_price_byseq8_2                                                                          float32
# rmean_price_byseq8_3                                                                          float32
# price_datesort_lag                                                                            float32
# seq_datesort_lag                                                                                int32
# price_datesort_lead                                                                           float32
# seq_datesort_lead                                                                               int32
# seq_datesort_lag_diff                                                                           int32
# seq_datesort_lead_diff                                                                          int32
# price_seqsort_lag                                                                             float32
# seq_seqsort_lag                                                                                 int32
# price_seqsort_lead                                                                            float32
# seq_seqsort_lead                                                                                int32
# seq_seqsort_lag_diff                                                                            int32
# seq_seqsort_lead_diff                                                                           int32
# item_seq_repeat_postings                                                                        int32
# category_repeat_postings                                                                        int32
# price_min_sequence                                                                            float32
# price_min_sequence_diff                                                                       float32
# seq_min_sequence                                                                                int32
# seq_min_sequence_diff                                                                           int32
# fold                                                                                            int32
# ridge_img                                                                                     float32
# Length: 163, dtype: object

# %%
print('[{}] Text Features'.format(time.time() - start_time))
df['text_feat'] = df.apply(lambda row: ' '.join([
    str(row['param_1']), 
    str(row['param_2']), 
    str(row['param_3'])]),axis=1) # Group Param Features
df.drop(["param_1","param_2","param_3"],axis=1,inplace=True)

print('[{}] Text Features'.format(time.time() - start_time))
df['description'].fillna('unknowndescription', inplace=True)
df['title'].fillna('unknowntitle', inplace=True)
df['text']      = (df['description'].fillna('') + ' ' + df['title'] + ' ' + 
  df['parent_category_name'].fillna('').astype(str) + ' ' + df['category_name'].fillna('').astype(str) )
# Out:
# [256.2147834300995] Text Features
# [544.9010486602783] Text Features

# %%
print('[{}] Create Time Variables'.format(time.time() - start_time))
df["Weekday"] = df['activation_date'].dt.weekday
df.drop(["activation_date","image"],axis=1,inplace=True)

print('[{}] Make Item Seq number as contiuous also'.format(time.time() - start_time))
df["item_seq_number_cont"] = df["item_seq_number"]
df['city'] = df['region'].fillna('').astype(str) + '_' + df['city'].fillna('').astype(str)
df.columns
print('[{}] Encode Variables'.format(time.time() - start_time))
df.drop(['user_id'], 1, inplace = True)
categorical = ["region","parent_category_name","user_type", 'city', 'category_name', "item_seq_number", 'image_top_1']
print("Encoding :",categorical)
# Encoder:
lbl = preprocessing.LabelEncoder()
for col in categorical:
    df[col] = lbl.fit_transform(df[col].astype(str))
# Out:
# [550.6073706150055] Create Time Variables
# [552.7413213253021] Make Item Seq number as contiuous also
# [553.9189920425415] Encode Variables
# Encoding : ['region', 'parent_category_name', 'user_type', 'city', 'category_name', 'item_seq_number', 'image_top_1']

# %%
print('[{}] Meta Text Features'.format(time.time() - start_time))
textfeats = ["description","text_feat", "title"]
for cols in textfeats:
    df[cols] = df[cols].astype(str) 
    df[cols] = df[cols].astype(str).fillna('nicapotato') # FILL NA
    df[cols] = df[cols].str.lower() # Lowercase all text, so that capitalized words dont get treated differently
    df[cols + '_num_chars'] = df[cols].apply(len) # Count number of Characters
    df[cols + '_num_words'] = df[cols].apply(lambda comment: len(comment.split())) # Count number of Words
    df[cols + '_num_unique_words'] = df[cols].apply(lambda comment: len(set(w for w in comment.split())))
    df[cols + '_words_vs_unique'] = df[cols+'_num_unique_words'] / df[cols+'_num_words'] * 100 # Count Unique Words
    gc.collect()
df.info()
for cols in ['translation']:
    df[cols] = df[cols].astype(str) 
    df[cols] = df[cols].astype(str).fillna('nicapotato') # FILL NA
    df[cols] = df[cols].str.lower() # Lowercase all text, so that capitalized words dont get treated differently
# Out:
# [586.5582447052002] Meta Text Features
# <class 'pandas.core.frame.DataFrame'>
# Index: 2011862 entries, b912c3c6a6ad to d374d332992f
# Columns: 173 entries, region to title_words_vs_unique
# dtypes: float32(89), float64(3), int32(58), int64(17), object(6)
# memory usage: 1.5+ GB

# %%
print('[{}] Manage Memory'.format(time.time() - start_time))
for col in df.columns:
    if np.float64 == df[col].dtype:
        df[col] = df[col].astype(np.float32)
    if np.int64 == df[col].dtype:
        df[col] = df[col].astype(np.int32)
    gc.collect()
df.info()
# Out:
# [635.4091246128082] Manage Memory
# <class 'pandas.core.frame.DataFrame'>
# Index: 2011862 entries, b912c3c6a6ad to d374d332992f
# Columns: 173 entries, region to title_words_vs_unique
# dtypes: float32(92), int32(75), object(6)
# memory usage: 1.4+ GB

# %%
print('[{}] Clean text and tokenize'.format(time.time() - start_time))
toktok = ToktokTokenizer()
tokSentMap = {}
morpher = pymorphy2.MorphAnalyzer()
def tokSent(sent):
    sent = sent.replace('/', ' ')
    return " ".join(morpher.parse(word)[0].normal_form for word in toktok.tokenize(rgx.sub(' ', sent)))
def tokCol(var):
    return [tokSent(s) for s in var.tolist()]
rgx = re.compile('[%s]' % '!"#%&()*,-./:;<=>?@[\\]^_`{|}~\t\n')   

partitions = 4 
def parallelize(data, func):
    data_split = np.array_split(data.values, partitions)
    pool = Pool(partitions)
    data = pd.concat([pd.Series(l) for l in pool.map(tokCol, data_split)]).values
    pool.close()
    pool.join()
    return data

load_text = True
text_cols = ['description', 'text', 'text_feat', 'title', 'translation']
if load_text:
    dftxt = pd.read_csv(path + '../features/text_features_morphed.csv.gz', compression = 'gzip')
    for col in text_cols:
        print(col + ' load tokenised [{}]'.format(time.time() - start_time))
        df[col] = dftxt[col].values
        df.fillna(' ', inplace = True)
    del dftxt
else:
    for col in text_cols:
        print(col + ' tokenise [{}]'.format(time.time() - start_time))
        df[col] = parallelize(df[col], tokCol)
    df[text_cols].to_csv(path + '../features/text_features_morphed.csv.gz', compression = 'gzip')
gc.collect()

print('[{}] Add some more test processing...'.format(time.time() - start_time))
from itertools import combinations
def create_bigrams(text):
    try:
        text = np.unique( [ w for w in text.split() ] )
        lst_bi = []
        for combo in combinations(text, 2):
            cb1=combo[0]+combo[1]
            cb2=combo[1]+combo[0]
            in_dict=False
            if cb1 in word_count_dict_one:
                new_word = cb1
                in_dict=True
            if cb2 in word_count_dict_one:
                new_word = cb2
                in_dict=True
            if not in_dict:
                new_word = combo[0]+'___'+combo[1]
            if len(cb1)>=0:
                lst_bi.append(new_word)
        return ' '.join( lst_bi )
    except:
        return ' '
    
def create_bigrams_df(df):
    return df.apply( create_bigrams )
def word_count(text, dc):
    text = set( text.split(' ') ) 
    for w in text:
        dc[w]+=1
def remove_low_freq(text, dc):
    return ' '.join( [w for w in text.split() if w in dc] )

def parallelize_dataframe(df, func, cores = 4):
    df_split = np.array_split(df, cores)
    pool = Pool(cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    return df
# Out:
# [643.9637570381165] Clean text and tokenize
# description load tokenised [679.4236042499542]
# text load tokenised [681.4867608547211]
# text_feat load tokenised [683.5818066596985]
# title load tokenised [685.4153831005096]
# translation load tokenised [687.3237187862396]
# [689.4930799007416] Add some more test processing...

# %%
print('[{}] [TF-IDF] Term Frequency Inverse Document Frequency Stage'.format(time.time() - start_time))
russian_stop = set(stopwords.words('russian'))
tfidf_para = {
    "stop_words": russian_stop,
    "token_pattern": r'\w{1,}',
    "sublinear_tf": True,
    "dtype": np.float32,
    "smooth_idf":False
}
countv_para = {
    #"stop_words": russian_stop,
    #"analyzer": 'word',
    #"token_pattern": r'\w{1,}',
    "lowercase": True,
    "min_df": 1 #False
}
def get_col(col_name): return lambda x: x[col_name]
vectorizer = FeatureUnion([
        ('text',TfidfVectorizer(
            ngram_range=(1),
            max_features=800000,
            **tfidf_para,
            preprocessor=get_col('text'))),
        ('title',TfidfVectorizer(
            ngram_range=(1, 2),
            max_features=50000,
            **tfidf_para,
            preprocessor=get_col('title'))),
        ('text_feat',CountVectorizer(
            **countv_para,
            preprocessor=get_col('text_feat'))),
    ])

# %%
df.loc[traindex,:].head().to_dict('records')
# Out:
# [{'Weekday': 1,
#   'all_titles': 'Кокоби(кокон для сна) Коляска 2 в 1 Tako jumperX Коляска 2 в 1 Tako jumperX',
#   'average_blue': 0.6123271584510803,
#   'average_green': 0.3197510838508606,
#   'average_red': 0.3604223430156708,
#   'blurness': 656.5001831054688,
#   'cat_itseq_rratio': 0.007451982703059912,
#   'cat_price_iratio': 0.1877954602241516,
#   'cat_price_rratio': 0.0063537778332829475,
#   'category_name': 42,
#   'category_name_ct': 135280,
#   'category_name_enc': 0.19382381439208984,
#   'category_repeat_postings': 3,
#   'city': 1313,
#   'city_ct': 85993,
#   'city_enc': 0.1260206699371338,
#   'cont_adultclothes_sizeb': 0.0,
#   'cont_adultclothes_sizel': 0.0,
#   'cont_adultclothes_sizev': 0.0,
#   'cont_appt_apFl': 0.0,
#   'cont_appt_rooms': 0.0,
#   'cont_appt_sqM': 0.0,
#   'cont_appt_totFl': 0.0,
#   'cont_car_year': 0,
#   'cont_kidsclothes_mthb': 0,
#   'cont_kidsclothes_nosz': 0,
#   'cont_kidsclothes_yrb': 0,
#   'cont_kidsclothes_yrsb': 0,
#   'cty_price_gratio': 0.11322347074747086,
#   'description': 'кокон для сон малыш пользоваться маленький месяц цвета серый',
#   'description_num_chars': 58,
#   'description_num_unique_words': 7,
#   'description_num_words': 7,
#   'description_words_vs_unique': 100.0,
#   'dominant_blue': 0.47058823704719543,
#   'dominant_green': 0.03921568766236305,
#   'dominant_red': 0.08235294371843338,
#   'dscr_price_rratio': 1.0,
#   'dullness': 96.70999908447266,
#   'fold': 4,
#   'height': 480.0,
#   'image_top_1': 13,
#   'image_top_1_ct': 680,
#   'image_top_1_enc': 0.09809794276952744,
#   'item_seq_number': 9108,
#   'item_seq_number_cont': 2,
#   'item_seq_number_ct': 78774,
#   'item_seq_number_enc': 0.18873918056488037,
#   'item_seq_repeat_postings': 1,
#   'lat_lon_hdbscan_cluster_05_03': 65,
#   'lat_lon_hdbscan_cluster_10_03': 38,
#   'lat_lon_hdbscan_cluster_20_03': 21,
#   'latitude': 56.838924407958984,
#   'longitude': 60.6057014465332,
#   'na_ratio_user': 0.008271179161965847,
#   'par1cty_price_prratio': 0.2998860776424408,
#   'par1utyp_price_prratio': 0.4143240749835968,
#   'par2cty_price_prratio': 0.2998860776424408,
#   'par2utyp_price_prratio': 0.4143240749835968,
#   'param_1_ct': 8634,
#   'param_1_enc': 0.09244567155838013,
#   'param_2_ct': 887771,
#   'param_2_enc': 0.17036408185958862,
#   'param_3_ct': 1168896,
#   'param_3_enc': 0.1750449687242508,
#   'parent_category_name': 4,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_count5': 6966,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_fratio5': 0.2998860776424408,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_count5': 4551,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_fratio5': 0.39248499274253845,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_count5': 9575,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_fratio5': 0.33321309089660645,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_count5': 6773,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_fratio5': 0.4143240749835968,
#   'parent_category_name_category_name_param_1_param_2_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_user_id_count5': 3,
#   'parent_category_name_category_name_user_id_fratio5': 0.888198733329773,
#   'parent_category_name_region_title_count5': 1,
#   'parent_category_name_region_title_fratio5': 1.0,
#   'pcat_itseq_rratio': 0.012931381352245808,
#   'pcat_log_itseq_rratio': 0.007109862752258778,
#   'pcat_log_price_rratio': 0.906419575214386,
#   'pcat_price_rratio': 0.021516818553209305,
#   'population': 1455904.0,
#   'price': 400.0,
#   'price_datesort_lag': 4000.0,
#   'price_datesort_lead': -1.0,
#   'price_min_sequence': 4000.0,
#   'price_min_sequence_diff': -3600.0,
#   'price_seqsort_lag': 4000.0,
#   'price_seqsort_lead': -1.0,
#   'rank_prm_asc': 1511,
#   'rank_prm_dsc': 5122,
#   'rank_ttl_asc': -1,
#   'rank_ttl_dsc': -1,
#   'rank_ttlst_asc': -1,
#   'rank_ttlst_dsc': -1,
#   'reg_price_gratio': 0.09561865031719208,
#   'reg_price_iratio': 0.42939913272857666,
#   'region': 19,
#   'region_ct': 127883,
#   'region_enc': 0.12424375861883163,
#   'ridge_img': -0.023148715496063232,
#   'ridge_preds': 0.11080347001552582,
#   'rmean_price_byseq3_1': -99999.0,
#   'rmean_price_byseq3_2': -99999.0,
#   'rmean_price_byseq3_3': -99999.0,
#   'rmean_price_byseq8_1': -99999.0,
#   'rmean_price_byseq8_2': -99999.0,
#   'rmean_price_byseq8_3': -99999.0,
#   'seq_datesort_lag': 1,
#   'seq_datesort_lag_diff': 1,
#   'seq_datesort_lead': -1,
#   'seq_datesort_lead_diff': -999,
#   'seq_min_sequence': 1,
#   'seq_min_sequence_diff': 1,
#   'seq_seqsort_lag': 1,
#   'seq_seqsort_lag_diff': 1,
#   'seq_seqsort_lead': -1,
#   'seq_seqsort_lead_diff': -999,
#   'size': 27039.0,
#   'text': 'кокон для сон малыш пользоваться маленький месяц цвета серый кокоби кокон для сон личный вещий товар для ребёнок и игрушка',
#   'text_feat': 'постельный принадлежность nan nan',
#   'text_feat_num_chars': 33,
#   'text_feat_num_unique_words': 3,
#   'text_feat_num_words': 4,
#   'text_feat_words_vs_unique': 75.0,
#   'title': 'кокоби кокон для сон',
#   'title_num_chars': 21,
#   'title_num_unique_words': 3,
#   'title_num_words': 3,
#   'title_words_vs_unique': 100.0,
#   'translation': 'кокоби кокон для сон постельный принадлежность товар для ребёнок и игрушка личный вещий',
#   'ttl_itseq_rratio': 1.0,
#   'ttl_price_rratio': 1.0,
#   'ttlst_cat_count': 1,
#   'ttlst_catpr_count': 1,
#   'ttlst_catprm_count': 1,
#   'ttlst_city_price_rratio': 1.0,
#   'ttlst_count': 1,
#   'ttlst_price_rratio': 1.0,
#   'ttlst_prm_price_rratio': 1.0,
#   'user_activ_mean': 4.0,
#   'user_activ_sum': 8.0,
#   'user_activ_var': 8.0,
#   'user_ad_ct': 3,
#   'user_avg_price': 2800.0,
#   'user_id_ct': 1,
#   'user_id_enc': 0.13936619460582733,
#   'user_log_price_rratio': 0.9064182639122009,
#   'user_type': 1,
#   'usercat_ad_ct': 3,
#   'usercat_avg_price': 2800.0,
#   'whiteness': 0.0,
#   'width': 358.0,
#   'zero_ratio_user': 0.008271179161965847},
#  {'Weekday': 6,
#   'all_titles': 'Стойка для Одежды',
#   'average_blue': 0.4217361807823181,
#   'average_green': 0.36612051725387573,
#   'average_red': 0.29691946506500244,
#   'blurness': 1108.5526123046875,
#   'cat_itseq_rratio': 0.06978671252727509,
#   'cat_price_iratio': 1.0025299787521362,
#   'cat_price_rratio': 0.3021359145641327,
#   'category_name': 22,
#   'category_name_ct': 87217,
#   'category_name_enc': 0.18037351965904236,
#   'category_repeat_postings': 1,
#   'city': 1233,
#   'city_ct': 57398,
#   'city_enc': 0.138361856341362,
#   'cont_adultclothes_sizeb': 0.0,
#   'cont_adultclothes_sizel': 0.0,
#   'cont_adultclothes_sizev': 0.0,
#   'cont_appt_apFl': 0.0,
#   'cont_appt_rooms': 0.0,
#   'cont_appt_sqM': 0.0,
#   'cont_appt_totFl': 0.0,
#   'cont_car_year': 0,
#   'cont_kidsclothes_mthb': 0,
#   'cont_kidsclothes_nosz': 0,
#   'cont_kidsclothes_yrb': 0,
#   'cont_kidsclothes_yrsb': 0,
#   'cty_price_gratio': 0.45486849546432495,
#   'description': 'стойка для одежда под вешалка с бутик',
#   'description_num_chars': 41,
#   'description_num_unique_words': 7,
#   'description_num_words': 7,
#   'description_words_vs_unique': 100.0,
#   'dominant_blue': 0.19607843458652496,
#   'dominant_green': 0.16078431904315948,
#   'dominant_red': 0.125490203499794,
#   'dscr_price_rratio': 1.0,
#   'dullness': 97.26499938964844,
#   'fold': 3,
#   'height': 480.0,
#   'image_top_1': 2723,
#   'image_top_1_ct': 691,
#   'image_top_1_enc': 0.1519174426794052,
#   'item_seq_number': 8389,
#   'item_seq_number_cont': 19,
#   'item_seq_number_ct': 23179,
#   'item_seq_number_enc': 0.14565415680408478,
#   'item_seq_repeat_postings': 1,
#   'lat_lon_hdbscan_cluster_05_03': 58,
#   'lat_lon_hdbscan_cluster_10_03': 36,
#   'lat_lon_hdbscan_cluster_20_03': 19,
#   'latitude': 53.24150466918945,
#   'longitude': 50.22124481201172,
#   'na_ratio_user': 0.01481659710407257,
#   'par1cty_price_prratio': 0.5666066408157349,
#   'par1utyp_price_prratio': 0.4889768064022064,
#   'par2cty_price_prratio': 0.5666066408157349,
#   'par2utyp_price_prratio': 0.4889768064022064,
#   'param_1_ct': 38156,
#   'param_1_enc': 0.12600058317184448,
#   'param_2_ct': 887771,
#   'param_2_enc': 0.16857415437698364,
#   'param_3_ct': 1168896,
#   'param_3_enc': 0.17372813820838928,
#   'parent_category_name': 2,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_count5': 2466,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_fratio5': 0.5666066408157349,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_count5': 1618,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_fratio5': 0.5817903280258179,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_count5': 4492,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_fratio5': 0.525278627872467,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_count5': 2982,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_fratio5': 0.4889768064022064,
#   'parent_category_name_category_name_param_1_param_2_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_user_id_count5': 1,
#   'parent_category_name_category_name_user_id_fratio5': 1.0,
#   'parent_category_name_region_title_count5': 1,
#   'parent_category_name_region_title_fratio5': 1.0,
#   'pcat_itseq_rratio': 0.0455334335565567,
#   'pcat_log_itseq_rratio': 0.007228395435959101,
#   'pcat_log_price_rratio': 1.1433614492416382,
#   'pcat_price_rratio': 0.046784259378910065,
#   'population': 1169719.0,
#   'price': 3000.0,
#   'price_datesort_lag': -1.0,
#   'price_datesort_lead': -1.0,
#   'price_min_sequence': 3000.0,
#   'price_min_sequence_diff': 0.0,
#   'price_seqsort_lag': -1.0,
#   'price_seqsort_lead': -1.0,
#   'rank_prm_asc': 1727,
#   'rank_prm_dsc': 647,
#   'rank_ttl_asc': -1,
#   'rank_ttl_dsc': -1,
#   'rank_ttlst_asc': -1,
#   'rank_ttlst_dsc': -1,
#   'reg_price_gratio': 0.5261960029602051,
#   'reg_price_iratio': 1.0372670888900757,
#   'region': 17,
#   'region_ct': 99914,
#   'region_enc': 0.1369272917509079,
#   'ridge_img': 0.22294600307941437,
#   'ridge_preds': 0.11605101078748703,
#   'rmean_price_byseq3_1': -99999.0,
#   'rmean_price_byseq3_2': -99999.0,
#   'rmean_price_byseq3_3': -99999.0,
#   'rmean_price_byseq8_1': -99999.0,
#   'rmean_price_byseq8_2': -99999.0,
#   'rmean_price_byseq8_3': -99999.0,
#   'seq_datesort_lag': -1,
#   'seq_datesort_lag_diff': -999,
#   'seq_datesort_lead': -1,
#   'seq_datesort_lead_diff': -999,
#   'seq_min_sequence': 19,
#   'seq_min_sequence_diff': 0,
#   'seq_seqsort_lag': -1,
#   'seq_seqsort_lag_diff': -999,
#   'seq_seqsort_lead': -1,
#   'seq_seqsort_lead_diff': -999,
#   'size': 30385.0,
#   'text': 'стойка для одежда под вешалка с бутик стойка для одежда для дом и дача мебель и интерьер',
#   'text_feat': 'другой nan nan',
#   'text_feat_num_chars': 14,
#   'text_feat_num_unique_words': 2,
#   'text_feat_num_words': 3,
#   'text_feat_words_vs_unique': 66.66666412353516,
#   'title': 'стойка для одежда',
#   'title_num_chars': 17,
#   'title_num_unique_words': 3,
#   'title_num_words': 3,
#   'title_words_vs_unique': 100.0,
#   'translation': 'стойка для одежда другой мебель и интерьер для дом и коттедж',
#   'ttl_itseq_rratio': 1.0,
#   'ttl_price_rratio': 1.0,
#   'ttlst_cat_count': 2,
#   'ttlst_catpr_count': 1,
#   'ttlst_catprm_count': 1,
#   'ttlst_city_price_rratio': 1.0,
#   'ttlst_count': 122,
#   'ttlst_price_rratio': 1.1471905708312988,
#   'ttlst_prm_price_rratio': 1.0,
#   'user_activ_mean': -9.0,
#   'user_activ_sum': -9.0,
#   'user_activ_var': -9.0,
#   'user_ad_ct': 1,
#   'user_avg_price': 3000.0,
#   'user_id_ct': 1,
#   'user_id_enc': 0.1389348953962326,
#   'user_log_price_rratio': 1.143369436264038,
#   'user_type': 1,
#   'usercat_ad_ct': 1,
#   'usercat_avg_price': 3000.0,
#   'whiteness': 0.0,
#   'width': 360.0,
#   'zero_ratio_user': 0.01481659710407257},
#  {'Weekday': 0,
#   'all_titles': 'Philips bluray DVD привод Жесткий диск SATA-II 750Gb Корпус Ddr3 2gb Core i3 2100 Gtx 550ti Блок питания 400вт Корпус Asrock h67',
#   'average_blue': 0.7035772204399109,
#   'average_green': 0.7035723924636841,
#   'average_red': 0.7033389806747437,
#   'blurness': 883.1677856445312,
#   'cat_itseq_rratio': 0.023261243477463722,
#   'cat_price_iratio': 0.4351836144924164,
#   'cat_price_rratio': 0.010113261640071869,
#   'category_name': 2,
#   'category_name_ct': 36014,
#   'category_name_enc': 0.16059140861034393,
#   'category_repeat_postings': 1,
#   'city': 1172,
#   'city_ct': 68019,
#   'city_enc': 0.1274128407239914,
#   'cont_adultclothes_sizeb': 0.0,
#   'cont_adultclothes_sizel': 0.0,
#   'cont_adultclothes_sizev': 0.0,
#   'cont_appt_apFl': 0.0,
#   'cont_appt_rooms': 0.0,
#   'cont_appt_sqM': 0.0,
#   'cont_appt_totFl': 0.0,
#   'cont_car_year': 0,
#   'cont_kidsclothes_mthb': 0,
#   'cont_kidsclothes_nosz': 0,
#   'cont_kidsclothes_yrb': 0,
#   'cont_kidsclothes_yrsb': 0,
#   'cty_price_gratio': 0.6802929043769836,
#   'description': 'в хороший состояние домашний кинотеатр с blu ray usb если настроить то работать смарт тв торг',
#   'description_num_chars': 99,
#   'description_num_unique_words': 17,
#   'description_num_words': 17,
#   'description_words_vs_unique': 100.0,
#   'dominant_blue': 0.9921568632125854,
#   'dominant_green': 0.9921568632125854,
#   'dominant_red': 0.9921568632125854,
#   'dscr_price_rratio': 1.0,
#   'dullness': 62.2400016784668,
#   'fold': 1,
#   'height': 360.0,
#   'image_top_1': 2260,
#   'image_top_1_ct': 1125,
#   'image_top_1_enc': 0.1900186389684677,
#   'item_seq_number': 32856,
#   'item_seq_number_cont': 9,
#   'item_seq_number_ct': 37731,
#   'item_seq_number_enc': 0.1606139987707138,
#   'item_seq_repeat_postings': 1,
#   'lat_lon_hdbscan_cluster_05_03': 46,
#   'lat_lon_hdbscan_cluster_10_03': 40,
#   'lat_lon_hdbscan_cluster_20_03': 9,
#   'latitude': 47.235713958740234,
#   'longitude': 39.70150375366211,
#   'na_ratio_user': 0.011757912114262581,
#   'par1cty_price_prratio': 1.4282761812210083,
#   'par1utyp_price_prratio': 1.887981653213501,
#   'par2cty_price_prratio': 1.4282761812210083,
#   'par2utyp_price_prratio': 1.887981653213501,
#   'param_1_ct': 2876,
#   'param_1_enc': 0.12452024966478348,
#   'param_2_ct': 887771,
#   'param_2_enc': 0.16870751976966858,
#   'param_3_ct': 1168896,
#   'param_3_enc': 0.17390763759613037,
#   'parent_category_name': 0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_count5': 1858,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_fratio5': 1.4282761812210083,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_count5': 1133,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_fratio5': 1.7659125328063965,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_count5': 3186,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_fratio5': 1.5741238594055176,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_count5': 1999,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_fratio5': 1.887981653213501,
#   'parent_category_name_category_name_param_1_param_2_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_user_id_count5': 1,
#   'parent_category_name_category_name_user_id_fratio5': 1.0,
#   'parent_category_name_region_title_count5': 1,
#   'parent_category_name_region_title_fratio5': 1.0,
#   'pcat_itseq_rratio': 0.012463942170143127,
#   'pcat_log_itseq_rratio': 0.0032369066029787064,
#   'pcat_log_price_rratio': 1.1280890703201294,
#   'pcat_price_rratio': 0.013088010251522064,
#   'population': 1125299.0,
#   'price': 4000.0,
#   'price_datesort_lag': 300.0,
#   'price_datesort_lead': 1500.0,
#   'price_min_sequence': 2000.0,
#   'price_min_sequence_diff': 2000.0,
#   'price_seqsort_lag': 300.0,
#   'price_seqsort_lead': 1500.0,
#   'rank_prm_asc': 1551,
#   'rank_prm_dsc': 256,
#   'rank_ttl_asc': -1,
#   'rank_ttl_dsc': -1,
#   'rank_ttlst_asc': -1,
#   'rank_ttlst_dsc': -1,
#   'reg_price_gratio': 0.7136390805244446,
#   'reg_price_iratio': 0.4868122637271881,
#   'region': 16,
#   'region_ct': 116667,
#   'region_enc': 0.13566584885120392,
#   'ridge_img': 0.11698690056800842,
#   'ridge_preds': 0.18400080502033234,
#   'rmean_price_byseq3_1': -1.0,
#   'rmean_price_byseq3_2': 1616.6666259765625,
#   'rmean_price_byseq3_3': 1933.3333740234375,
#   'rmean_price_byseq8_1': -1.0,
#   'rmean_price_byseq8_2': -1.0,
#   'rmean_price_byseq8_3': -1.0,
#   'seq_datesort_lag': 8,
#   'seq_datesort_lag_diff': 1,
#   'seq_datesort_lead': 10,
#   'seq_datesort_lead_diff': -1,
#   'seq_min_sequence': 1,
#   'seq_min_sequence_diff': 8,
#   'seq_seqsort_lag': 8,
#   'seq_seqsort_lag_diff': 1,
#   'seq_seqsort_lead': 10,
#   'seq_seqsort_lead_diff': -1,
#   'size': 18681.0,
#   'text': 'в хороший состояние домашний кинотеатр с blu ray usb если настроить то работать смарт тв торг philips bluray бытовой электроника аудио и видео',
#   'text_feat': 'видео dvd и blu ray плеер nan nan',
#   'text_feat_num_chars': 35,
#   'text_feat_num_unique_words': 6,
#   'text_feat_num_words': 7,
#   'text_feat_words_vs_unique': 85.71428680419922,
#   'title': 'philips bluray',
#   'title_num_chars': 14,
#   'title_num_unique_words': 2,
#   'title_num_words': 2,
#   'title_words_vs_unique': 100.0,
#   'translation': 'philips bluray видео dvd и blu ray плеер аудио и видео бытовой электроника',
#   'ttl_itseq_rratio': 1.0,
#   'ttl_price_rratio': 1.0,
#   'ttlst_cat_count': 1,
#   'ttlst_catpr_count': 1,
#   'ttlst_catprm_count': 1,
#   'ttlst_city_price_rratio': 1.0,
#   'ttlst_count': 1,
#   'ttlst_price_rratio': 1.0,
#   'ttlst_prm_price_rratio': 1.0,
#   'user_activ_mean': 3.875,
#   'user_activ_sum': 31.0,
#   'user_activ_var': 8.696428298950195,
#   'user_ad_ct': 10,
#   'user_avg_price': 1205.0,
#   'user_id_ct': 2,
#   'user_id_enc': 0.13931018114089966,
#   'user_log_price_rratio': 1.1280969381332397,
#   'user_type': 1,
#   'usercat_ad_ct': 10,
#   'usercat_avg_price': 1205.0,
#   'whiteness': 28.385000228881836,
#   'width': 392.0,
#   'zero_ratio_user': 0.011757912114262581},
#  {'Weekday': 5,
#   'all_titles': 'Автокресло Отдам органзу Отдам одежду Платья кофточки Продам мелкий цветной камень для декора Грунт для декора Продам сезаль, упаковку для цветов Даром ремни Почти новая обувь Пароварка новая Детские вещи Пакет одежды с рождения до полугода Материал для афрокосичек 3 упаковки Туфли новые Очень красивые сувенирные бараны в подарок Искусственный цветок 60 см Прокат костюма зайчика Фонтан Пряжа Очень красивое свадебное платье Комбинезон Игрушки комплектом Фоторамка на 2 фото Костюм теплый с шапочкой Фонтан денежный Книга 40 недель беременности даром Молокоотсос+ накладки для сосков+ присыпка Войлоковое кашпо Санки коляска с выдвижными колесами Антилопа статуэтка Войлоковое кашпо Очень красивое свадебное платье Продам швейную машинку(Чайка 134 а) Продам мелкий цветной камень для декора Костюм теплый с шапочкой Детские вещи Туфли новые Искусственный цветок 60 см Почти новая обувь Материал для афрокосичек 3 упаковки Молокоотсос+ накладки для сосков+ присыпка Пароварка новая Антилопа статуэтка Санки коляска с выдвижными колесами Книга 40 недель беременности даром Грунт для декора Пакет одежды с рождения до полугода Продам сезаль, упаковку для цветов Комбинезон Фонтан Фонтан денежный Пряжа отдам за шоколадку Очень красивые сувенирные бараны в подарок Обложки на паспорт Прикольные Даром ремни Игрушки комплектом Фоторамка на 2 фото',
#   'average_blue': 0.8459433317184448,
#   'average_green': 0.8463041186332703,
#   'average_red': 0.851558268070221,
#   'blurness': 427.70233154296875,
#   'cat_itseq_rratio': 1.0610027313232422,
#   'cat_price_iratio': 0.7091503143310547,
#   'cat_price_rratio': 0.03479902446269989,
#   'category_name': 42,
#   'category_name_ct': 135280,
#   'category_name_enc': 0.19149476289749146,
#   'category_repeat_postings': 7,
#   'city': 1557,
#   'city_ct': 21135,
#   'city_enc': 0.13679951429367065,
#   'cont_adultclothes_sizeb': 0.0,
#   'cont_adultclothes_sizel': 0.0,
#   'cont_adultclothes_sizev': 0.0,
#   'cont_appt_apFl': 0.0,
#   'cont_appt_rooms': 0.0,
#   'cont_appt_sqM': 0.0,
#   'cont_appt_totFl': 0.0,
#   'cont_car_year': 0,
#   'cont_kidsclothes_mthb': 0,
#   'cont_kidsclothes_nosz': 0,
#   'cont_kidsclothes_yrb': 0,
#   'cont_kidsclothes_yrsb': 0,
#   'cty_price_gratio': 0.16996097564697266,
#   'description': 'продать кресло от0 25кг',
#   'description_num_chars': 22,
#   'description_num_unique_words': 3,
#   'description_num_words': 3,
#   'description_words_vs_unique': 100.0,
#   'dominant_blue': 0.9921568632125854,
#   'dominant_green': 0.9921568632125854,
#   'dominant_red': 0.9921568632125854,
#   'dscr_price_rratio': 1.0,
#   'dullness': 54.064998626708984,
#   'fold': 3,
#   'height': 360.0,
#   'image_top_1': 2838,
#   'image_top_1_ct': 5825,
#   'image_top_1_enc': 0.33221402764320374,
#   'item_seq_number': 14637,
#   'item_seq_number_cont': 286,
#   'item_seq_number_ct': 500,
#   'item_seq_number_enc': 0.10392601788043976,
#   'item_seq_repeat_postings': 1,
#   'lat_lon_hdbscan_cluster_05_03': 55,
#   'lat_lon_hdbscan_cluster_10_03': 33,
#   'lat_lon_hdbscan_cluster_20_03': 18,
#   'latitude': 55.718505859375,
#   'longitude': 52.37210464477539,
#   'na_ratio_user': 0.008271179161965847,
#   'par1cty_price_prratio': 0.6032670140266418,
#   'par1utyp_price_prratio': 0.3620361089706421,
#   'par2cty_price_prratio': 0.6032670140266418,
#   'par2utyp_price_prratio': 0.3620361089706421,
#   'param_1_ct': 6873,
#   'param_1_enc': 0.3246346414089203,
#   'param_2_ct': 887771,
#   'param_2_enc': 0.16857415437698364,
#   'param_3_ct': 1168896,
#   'param_3_enc': 0.17372813820838928,
#   'parent_category_name': 4,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_count5': 944,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_fratio5': 0.6032670140266418,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_count5': 43,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_fratio5': 0.9482210874557495,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_count5': 13,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_fratio5': 0.9912444949150085,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_count5': 223,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_fratio5': 0.8750036358833313,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_count5': 6211,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_fratio5': 0.519149124622345,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_count5': 176,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_fratio5': 0.9932584762573242,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_count5': 35,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_fratio5': 1.0274510383605957,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_count5': 2378,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_fratio5': 0.3620361089706421,
#   'parent_category_name_category_name_param_1_param_2_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_user_id_count5': 7,
#   'parent_category_name_category_name_user_id_fratio5': 1.1138802766799927,
#   'parent_category_name_region_title_count5': 178,
#   'parent_category_name_region_title_fratio5': 1.0030951499938965,
#   'pcat_itseq_rratio': 1.8471157550811768,
#   'pcat_log_itseq_rratio': 0.036565765738487244,
#   'pcat_log_price_rratio': 1.1639021635055542,
#   'pcat_price_rratio': 0.11827684938907623,
#   'population': 529797.0,
#   'price': 2200.0,
#   'price_datesort_lag': 40.0,
#   'price_datesort_lead': -1.0,
#   'price_min_sequence': 0.0,
#   'price_min_sequence_diff': 2200.0,
#   'price_seqsort_lag': 40.0,
#   'price_seqsort_lead': -1.0,
#   'rank_prm_asc': 417,
#   'rank_prm_dsc': 523,
#   'rank_ttl_asc': 21,
#   'rank_ttl_dsc': 23,
#   'rank_ttlst_asc': 26,
#   'rank_ttlst_dsc': 23,
#   'reg_price_gratio': 0.435062050819397,
#   'reg_price_iratio': 0.8629037141799927,
#   'region': 21,
#   'region_ct': 111319,
#   'region_enc': 0.1422053724527359,
#   'ridge_img': 0.05106334388256073,
#   'ridge_preds': 0.3469908833503723,
#   'rmean_price_byseq3_1': -1.0,
#   'rmean_price_byseq3_2': 846.6666870117188,
#   'rmean_price_byseq3_3': -1.0,
#   'rmean_price_byseq8_1': -1.0,
#   'rmean_price_byseq8_2': 936.25,
#   'rmean_price_byseq8_3': -1.0,
#   'seq_datesort_lag': 283,
#   'seq_datesort_lag_diff': 3,
#   'seq_datesort_lead': -1,
#   'seq_datesort_lead_diff': -999,
#   'seq_min_sequence': 20,
#   'seq_min_sequence_diff': 266,
#   'seq_seqsort_lag': 283,
#   'seq_seqsort_lag_diff': 3,
#   'seq_seqsort_lead': -1,
#   'seq_seqsort_lead_diff': -999,
#   'size': 13656.0,
#   'text': 'продать кресло от0 25кг автокресло личный вещий товар для ребёнок и игрушка',
#   'text_feat': 'автомобильный кресло nan nan',
#   'text_feat_num_chars': 28,
#   'text_feat_num_unique_words': 3,
#   'text_feat_num_words': 4,
#   'text_feat_words_vs_unique': 75.0,
#   'title': 'автокресло',
#   'title_num_chars': 10,
#   'title_num_unique_words': 1,
#   'title_num_words': 1,
#   'title_words_vs_unique': 100.0,
#   'translation': 'автомобильный сидение автомобильный сидение товар для ребёнок и игрушка личный вещий',
#   'ttl_itseq_rratio': 4.378891468048096,
#   'ttl_price_rratio': 0.8548896312713623,
#   'ttlst_cat_count': 202,
#   'ttlst_catpr_count': 2,
#   'ttlst_catprm_count': 2,
#   'ttlst_city_price_rratio': 1.0011850595474243,
#   'ttlst_count': 2680,
#   'ttlst_price_rratio': 0.8606370091438293,
#   'ttlst_prm_price_rratio': 1.001296877861023,
#   'user_activ_mean': 6.324324131011963,
#   'user_activ_sum': 468.0,
#   'user_activ_var': 21.016660690307617,
#   'user_ad_ct': 57,
#   'user_avg_price': 860.370361328125,
#   'user_id_ct': 4,
#   'user_id_enc': 0.1389348953962326,
#   'user_log_price_rratio': 1.1639044284820557,
#   'user_type': 0,
#   'usercat_ad_ct': 31,
#   'usercat_avg_price': 1086.2069091796875,
#   'whiteness': 42.9900016784668,
#   'width': 360.0,
#   'zero_ratio_user': 0.008271179161965847},
#  {'Weekday': 3,
#   'all_titles': 'ВАЗ 2110, 2003',
#   'average_blue': 0.4851965308189392,
#   'average_green': 0.512564480304718,
#   'average_red': 0.44890859723091125,
#   'blurness': 1025.6044921875,
#   'cat_itseq_rratio': 0.007442332338541746,
#   'cat_price_iratio': 0.15924090147018433,
#   'cat_price_rratio': 0.03336913511157036,
#   'category_name': 0,
#   'category_name_ct': 85101,
#   'category_name_enc': 0.2550775706768036,
#   'category_repeat_postings': 1,
#   'city': 250,
#   'city_ct': 43920,
#   'city_enc': 0.13787657022476196,
#   'cont_adultclothes_sizeb': 0.0,
#   'cont_adultclothes_sizel': 0.0,
#   'cont_adultclothes_sizev': 0.0,
#   'cont_appt_apFl': 0.0,
#   'cont_appt_rooms': 0.0,
#   'cont_appt_sqM': 0.0,
#   'cont_appt_totFl': 0.0,
#   'cont_car_year': 2003,
#   'cont_kidsclothes_mthb': 0,
#   'cont_kidsclothes_nosz': 0,
#   'cont_kidsclothes_yrb': 0,
#   'cont_kidsclothes_yrsb': 0,
#   'cty_price_gratio': 0.10846412926912308,
#   'description': 'весь вопрос по телефон',
#   'description_num_chars': 24,
#   'description_num_unique_words': 4,
#   'description_num_words': 4,
#   'description_words_vs_unique': 100.0,
#   'dominant_blue': 0.572549045085907,
#   'dominant_green': 0.6078431606292725,
#   'dominant_red': 0.5333333611488342,
#   'dscr_price_rratio': 1.040816307067871,
#   'dullness': 96.375,
#   'fold': 0,
#   'height': 360.0,
#   'image_top_1': 1408,
#   'image_top_1_ct': 19569,
#   'image_top_1_enc': 0.3155987560749054,
#   'item_seq_number': 15299,
#   'item_seq_number_cont': 3,
#   'item_seq_number_ct': 64432,
#   'item_seq_number_enc': 0.17787307500839233,
#   'item_seq_repeat_postings': 1,
#   'lat_lon_hdbscan_cluster_05_03': 31,
#   'lat_lon_hdbscan_cluster_10_03': 17,
#   'lat_lon_hdbscan_cluster_20_03': -1,
#   'latitude': 48.70804977416992,
#   'longitude': 44.513301849365234,
#   'na_ratio_user': 0.011573701165616512,
#   'par1cty_price_prratio': 0.06817826628684998,
#   'par1utyp_price_prratio': 0.047956813126802444,
#   'par2cty_price_prratio': 0.05101052671670914,
#   'par2utyp_price_prratio': 0.023978818207979202,
#   'param_1_ct': 83124,
#   'param_1_enc': 0.28248247504234314,
#   'param_2_ct': 26463,
#   'param_2_enc': 0.36118924617767334,
#   'param_3_ct': 2562,
#   'param_3_enc': 0.33495455980300903,
#   'parent_category_name': 6,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_count5': 397,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_fratio5': 0.4668874740600586,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_count5': 53,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_fratio5': 0.5642553567886353,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_count5': 46,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_title_user_type_fratio5': 0.5875815153121948,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_count5': 340,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_city_user_type_fratio5': 0.47607576847076416,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_count5': 821,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_fratio5': 0.458845317363739,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_count5': 99,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_fratio5': 0.5671151876449585,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_count5': 85,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_title_user_type_fratio5': 0.5429274439811707,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_count5': 683,
#   'parent_category_name_category_name_param_1_param_2_param_3_region_user_type_fratio5': 0.46946579217910767,
#   'parent_category_name_category_name_param_1_param_2_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_param_2_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_city_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_city_fratio5': 1.0,
#   'parent_category_name_category_name_param_1_user_id_count5': 1,
#   'parent_category_name_category_name_param_1_user_id_fratio5': 1.0,
#   'parent_category_name_category_name_user_id_count5': 1,
#   'parent_category_name_category_name_user_id_fratio5': 1.0,
#   'parent_category_name_region_title_count5': 99,
#   'parent_category_name_region_title_fratio5': 0.5671151876449585,
#   'pcat_itseq_rratio': 0.008762694895267487,
#   'pcat_log_itseq_rratio': 0.0041451225988566875,
#   'pcat_log_price_rratio': 0.8687596321105957,
#   'pcat_price_rratio': 0.03823255002498627,
#   'population': 1015586.0,
#   'price': 40000.0,
#   'price_datesort_lag': -1.0,
#   'price_datesort_lead': -1.0,
#   'price_min_sequence': 40000.0,
#   'price_min_sequence_diff': 0.0,
#   'price_seqsort_lag': -1.0,
#   'price_seqsort_lead': -1.0,
#   'rank_prm_asc': 22,
#   'rank_prm_dsc': 363,
#   'rank_ttl_asc': 2,
#   'rank_ttl_dsc': 51,
#   'rank_ttlst_asc': 2,
#   'rank_ttlst_dsc': 51,
#   'reg_price_gratio': 0.16702832281589508,
#   'reg_price_iratio': 0.19786199927330017,
#   'region': 4,
#   'region_ct': 64444,
#   'region_enc': 0.14452730119228363,
#   'ridge_img': 0.17662173509597778,
#   'ridge_preds': 0.33564451336860657,
#   'rmean_price_byseq3_1': -99999.0,
#   'rmean_price_byseq3_2': -99999.0,
#   'rmean_price_byseq3_3': -99999.0,
#   'rmean_price_byseq8_1': -99999.0,
#   'rmean_price_byseq8_2': -99999.0,
#   'rmean_price_byseq8_3': -99999.0,
#   'seq_datesort_lag': -1,
#   'seq_datesort_lag_diff': -999,
#   'seq_datesort_lead': -1,
#   'seq_datesort_lead_diff': -999,
#   'seq_min_sequence': 3,
#   'seq_min_sequence_diff': 0,
#   'seq_seqsort_lag': -1,
#   'seq_seqsort_lag_diff': -999,
#   'seq_seqsort_lead': -1,
#   'seq_seqsort_lead_diff': -999,
#   'size': 36710.0,
#   'text': 'весь вопрос по телефон ваза 2110 2003 транспорт автомобиль',
#   'text_feat': 'с пробег ваза lada 2110',
#   'text_feat_num_chars': 26,
#   'text_feat_num_unique_words': 5,
#   'text_feat_num_words': 5,
#   'text_feat_words_vs_unique': 100.0,
#   'title': 'ваза 2110 2003',
#   'title_num_chars': 14,
#   'title_num_unique_words': 3,
#   'title_num_words': 3,
#   'title_words_vs_unique': 100.0,
#   'translation': 'ваза 2110 2003 с пробег ваза lada 2110 легковой автомобиль транспорт',
#   'ttl_itseq_rratio': 0.019905399531126022,
#   'ttl_price_rratio': 0.48211610317230225,
#   'ttlst_cat_count': 99,
#   'ttlst_catpr_count': 1,
#   'ttlst_catprm_count': 1,
#   'ttlst_city_price_rratio': 0.5642553567886353,
#   'ttlst_count': 2066,
#   'ttlst_price_rratio': 0.48336341977119446,
#   'ttlst_prm_price_rratio': 0.526691198348999,
#   'user_activ_mean': -9.0,
#   'user_activ_sum': -9.0,
#   'user_activ_var': -9.0,
#   'user_ad_ct': 1,
#   'user_avg_price': 40000.0,
#   'user_id_ct': 1,
#   'user_id_enc': 0.13869604468345642,
#   'user_log_price_rratio': 0.8687373995780945,
#   'user_type': 1,
#   'usercat_ad_ct': 1,
#   'usercat_avg_price': 40000.0,
#   'whiteness': 0.07000000029802322,
#   'width': 640.0,
#   'zero_ratio_user': 0.011573701165616512}]

# %%
start_vect=time.time()
vectorizer.fit(df.loc[traindex,:].to_dict('records'))
ready_df = vectorizer.transform(df.to_dict('records'))
tfvocab = vectorizer.get_feature_names()
tfvocab[:50]
print('[{}] Vectorisation completed'.format(time.time() - start_time))
# Drop Text Cols
df.drop(textfeats+['text', 'all_titles', 'translation'], axis=1,inplace=True)
#drop_cols= [c for c in textfeats+['text', 'all_titles', 'translation'] if c in df.columns]
#df.drop(drop_cols, axis=1,inplace=True)
# Out:
# [689.5389709472656] [TF-IDF] Term Frequency Inverse Document Frequency Stage
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-615fad31c860> in <module>()
#      33
#      34 start_vect=time.time()
# ---> 35 vectorizer.fit(df.loc[traindex,:].to_dict('records'))
#      36 ready_df = vectorizer.transform(df.to_dict('records'))
#      37 tfvocab = vectorizer.get_feature_names()
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in fit(self, X, y)
#     712         transformers = Parallel(n_jobs=self.n_jobs)(
#     713             delayed(_fit_one_transformer)(trans, X, y)
# --> 714             for _, trans, _ in self._iter())
#     715         self._update_transformer_list(transformers)
#     716         return self
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in _fit_one_transformer(transformer, X, y)
#     565
#     566 def _fit_one_transformer(transformer, X, y):
# --> 567     return transformer.fit(X, y)
#     568
#     569
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in fit(self, raw_documents, y)
#    1359         self : TfidfVectorizer
#    1360         """
# -> 1361         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1362         self._tfidf.fit(X)
#    1363         return self
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
#     794                     feature_idx = vocabulary[feature]
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     264
#     265             return lambda doc: self._word_ngrams(
# --> 266                 tokenize(preprocess(self.decode(doc))), stop_words)
#     267
#     268         else:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in _word_ngrams(self, tokens, stop_words)
#     129
#     130         # handle token n-grams
# --> 131         min_n, max_n = self.ngram_range
#     132         if max_n != 1:
#     133             original_tokens = tokens
#
# TypeError: 'int' object is not iterable

# %%
gc.collect()

print('[{}] Drop all the categorical'.format(time.time() - start_time))
df.drop(categorical, axis=1,inplace=True)

# %%
import tensorflow as tf
import os, random
os.environ['PYTHONHASHSEED'] = '10000'
np.random.seed(10001)
random.seed(10002)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=5, inter_op_parallelism_threads=1)
from keras import backend
tf.set_random_seed(10003)
backend.set_session(tf.Session(graph=tf.get_default_graph(), config=session_conf))
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Dropout, Dense, concatenate, GRU, Embedding, Flatten, Activation, BatchNormalization, PReLU
from keras.initializers import he_uniform
from keras.layers import Conv1D
from keras.layers import GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.optimizers import Adam, SGD
from keras.models import Model

# %%
f = 0
print('Fold %s'%(f) + ' [{}] Modeling Stage'.format(time.time() - start_time))
trnidx = (df['fold'].loc[traindex] != f).values
trndf = df.drop('fold', 1).loc[traindex,:][trnidx].copy()
trndf[trndf>10000] = 10000
trndf[trndf<0] = 0
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
trndf = scaler.fit_transform(np.log1p(trndf.values))
#X_train = [trndf,ready_df[0:traindex.shape[0]][trnidx]]
X_train = csr_matrix(hstack([csr_matrix(trndf),ready_df[0:traindex.shape[0]][trnidx]]))
y_train = y[trnidx]
tstdf =  df.drop('fold', 1).loc[traindex,:][~trnidx].copy()
tstdf[tstdf>10000] = 10000
tstdf[tstdf<0] = 0
tstdf = scaler.transform(np.log1p(tstdf.values))
#X_test =  [tstdf, ready_df[0:traindex.shape[0]][~trnidx]]
X_test =  csr_matrix(hstack([csr_matrix(tstdf), ready_df[0:traindex.shape[0]][~trnidx]]))
y_test  = y[~trnidx]

# %%
#print('[{}] Load Densenet image features'.format(time.time() - start_time))
#dnimgtrn = np.load(path+'../features/densenet_pool_array_train.npy')
#dnimgtrn = dnimgtrn
#scaler = preprocessing.StandardScaler()
#dnimgtrn = scaler.fit_transform(dnimgtrn)
#gc.collect()
#dnimgtst = np.load(path+'../features/densenet_pool_array_test.npy')
#dnimgtst = scaler.transform(dnimgtst)
#gc.collect()

# %%
# !free -m

# %%
from keras.layers import BatchNormalization, PReLU

def sparseNN():                                             
    sparse_data = Input( shape=[ready_df.shape[1]], 
        dtype = 'float32',   sparse = True, name='sparse_data')  

    #dense = Input(shape=[trndf.shape[1]], name="dense")

    #x = concatenate( [sparse_data, dense] ) 
    x = Dense(200 , kernel_initializer=he_uniform(seed=0) )(sparse)    
    x = PReLU()(x)
    #x = BatchNormalization()(x)
    x = Dense(200 , kernel_initializer=he_uniform(seed=0) )(x)
    x = PReLU()(x)
    x = Dense(100 , kernel_initializer=he_uniform(seed=0) )(x)
    x = PReLU()(x)
    x= Dense(1)(x)
    
    model = Model([sparse_data],x)
    
    optimizer = Adam(.0011)
    model.compile(loss="mse", optimizer=optimizer)
    return model

# %%
BATCH_SIZE = 1024*20
nnbags = 1
print("Fitting SPARSE NN model ...")
gc.collect()
y_predls = []
sparse_nn = sparseNN()
sparse_nn.fit(X_train, y_train, \
            batch_size=BATCH_SIZE, \
            validation_data = (X_test, y_test), \
            epochs=1, verbose=1 )
gc.collect()

# %%
BATCH_SIZE = 1024*20
sparse_nn.fit(X_train, y_train, \
            batch_size=BATCH_SIZE, \
            validation_data = (X_test, y_test), \
            epochs=1, verbose=1 )
gc.collect()

# %%
y_predls.append(sparse_nn.predict(X_test, batch_size=1024*128))
print('RMSE fold %s:'%(f), np.sqrt(metrics.mean_squared_error(y_test, sum(y_predls)/len(y_predls))))

# %% [raw]
# Fitting SPARSE NN model ...
# Train on 1189868 samples, validate on 313556 samples
# Epoch 1/1
# 1189868/1189868 [==============================] - 488s 410us/step - loss: 0.0502 - val_loss: 0.0486
# RMSE fold 0: 0.2201112868520275
# Train on 1189868 samples, validate on 313556 samples
# Epoch 1/1
# 1189868/1189868 [==============================] - 487s 409us/step - loss: 0.0499 - val_loss: 0.0489
# RMSE fold 0: 0.2195746424584911

# %%
# Placeholder for predictions
df['fold'].value_counts()
y_pred_trn = pd.Series(-np.zeros(df.loc[traindex,:].shape[0]), index = traindex)
y_pred_tst = pd.Series(-np.zeros(df.loc[testdex ,:].shape[0]), index = testdex)
best_iters = []
bags       = 1
BATCH_SIZE = 5000
nnbags     = 3
bags       = 1
for bag in range(bags):
    for f in range(6):
        print('Fold %s'%(f) + ' [{}] Modeling Stage'.format(time.time() - start_time))
        trnidx = (df['fold'].loc[traindex] != f).values
        trndf = df.drop('fold', 1).loc[traindex,:][trnidx].copy()
        trndf[trndf>10000] = 10000
        trndf[trndf<0] = 0
        from sklearn.preprocessing import StandardScaler
        scaler = StandardScaler()
        trndf = scaler.fit_transform(trndf.values)
        X_train = csr_matrix(hstack([csr_matrix(trndf),ready_df[0:traindex.shape[0]][trnidx]]))
        y_train = y[trnidx]
        # 5 is the test fold
        if f == 5:
            tstdf = df.drop('fold', 1).loc[testdex,:].copy()
            tstdf[tstdf>10000] = 10000
            tstdf[tstdf<-0] = 0
            tstdf = scaler.transform(tstdf.values)
            X_test = csr_matrix(hstack([csr_matrix(tstdf),ready_df[traindex.shape[0]:]]))
        else:
            tstdf =  df.drop('fold', 1).loc[traindex,:][~trnidx].copy()
            tstdf[tstdf>10000] = 10000
            tstdf[tstdf<0] = 0
            tstdf = scaler.transform(tstdf.values)
            X_test = csr_matrix(hstack([csr_matrix(tstdf), ready_df[0:traindex.shape[0]][~trnidx]]))
            y_test  = y[~trnidx]
        #tfvocab = df.drop('fold', 1).columns.tolist() + vectorizer.get_feature_names()
        del trndf
        gc.collect()
        for shape in [X_train, X_test]:
            print("Fold {} : {} Rows and {} Cols".format(f, *shape.shape))
        gc.collect();
        gc.collect()
    
        if f==5:
            best_iter = 0
            print('avg best iter: %s'%(best_iter))
            # ridge = Ridge(solver='auto', fit_intercept=True, alpha=0.4, max_iter=200, normalize=False, tol=0.01)
            # ridge.fit(X_train, y_train)
            y_predls = []
            for ep in range(nnbags):
                gc.collect()
                sparse_nn = sparseNN()
                sparse_nn.fit(X_train, y_train, \
                              batch_size=BATCH_SIZE, \
                              epochs=1, verbose=1 )
                y_predls.append(sparse_nn.predict(X_test, batch_size=20000))
            y_pred = sum(y_predls)/len(y_predls)
            
            
        else:
            best_iter = 0
            print('avg best iter: %s'%(best_iter))
            # ridge = Ridge(solver='auto', fit_intercept=True, alpha=0.4, max_iter=200, normalize=False, tol=0.01)
            # ridge.fit(X_train, y_train)
            y_predls = []
            for ep in range(nnbags):
                gc.collect()
                sparse_nn = sparseNN()
                sparse_nn.fit(X_train, y_train, \
                              batch_size=BATCH_SIZE, \
                              validation_data = (X_test, y_test), \
                              epochs=1, verbose=1 )
                y_predls.append(sparse_nn.predict(X_test, batch_size=20000))
                print('RMSE fold %s bag %s:'%(f, ep), np.sqrt(metrics.mean_squared_error(y_test, sum(y_predls)/len(y_predls))))
            y_pred = sum(y_predls)/len(y_predls)
            
        print("Model Evaluation Stage")
        if f == 5:
            y_pred_tst[:] += y_pred.flatten() # ridge.predict(X_test)
        else:
            y_pred_trn[~trnidx] += y_pred.flatten() # ridge.predict(X_test)
            print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_trn[~trnidx])))
        del X_test
        gc.collect()
        y_pred_trn.to_csv("rmlp5CV_2306_trn.csv",index=True)
        y_pred_tst.to_csv("rmlp5CV_2306_tst.csv",index=True)

# %%
lgsub = pd.concat([y_pred_trn, y_pred_tst]).reset_index()
lgsub.rename(columns = {0 : 'deal_probability'}, inplace=True)
lgsub['deal_probability'] = lgsub['deal_probability']/(bag+1)
lgsub.set_index('item_id', inplace = True)
print('RMSE for all :', np.sqrt(metrics.mean_squared_error(y, lgsub.loc[traindex])))
lgsub.to_csv("rmlp5CV_2306.csv.gz",index=True,header=True, compression = 'gzip')

lgsub.to_csv(path + "../sub/rmlp5CV_2306.csv.gz",index=True,header=True, compression = 'gzip')

# %%
gc.collect()

# %%
# Placeholder for predictions
df['fold'].value_counts()
y_pred_trn = pd.Series(-np.zeros(df.loc[traindex,:].shape[0]), index = traindex)
y_pred_tst = pd.Series(-np.zeros(df.loc[testdex ,:].shape[0]), index = testdex)
best_iters = []
bags       = 1
BATCH_SIZE = 5000
nnbags     = 3
bags       = 1
for bag in range(bags):
    for f in range(6):
        print('Fold %s'%(f) + ' [{}] Modeling Stage'.format(time.time() - start_time))
        scaler = StandardScaler()
        trnidx = (df['fold'].loc[traindex] != f).values
        trndf = df.drop('fold', 1).loc[traindex,:][trnidx].copy()
        trndf[trndf>1000000] = 1000000
        trndf[trndf<0] = 0
        skew = trndf.skew()
        for col in trndf.columns:
            if skew[col]>1:
                trndf[col] = np.log1p(trndf[col].values)
        trndf = scaler.fit_transform(trndf.values)
        X_train = csr_matrix(hstack([csr_matrix(trndf),ready_df[0:traindex.shape[0]][trnidx]]))
        y_train = y[trnidx]   
        if f == 5:
            tstdf =  df.drop('fold', 1).loc[testdex,:].copy()
            tstdf[tstdf>1000000] = 1000000
            tstdf[tstdf<0] = 0
            for col in tstdf.columns:
                if skew[col]>1:
                    tstdf[col] = np.log1p(tstdf[col].values)
            tstdf = scaler.transform(tstdf.values)
            X_test = csr_matrix(hstack([csr_matrix(tstdf),ready_df[traindex.shape[0]:]]))
        else:
            tstdf =  df.drop('fold', 1).loc[traindex,:][~trnidx].copy()
            tstdf[tstdf>1000000] = 1000000
            tstdf[tstdf<0] = 0
            for col in tstdf.columns:
                if skew[col]>1:
                    tstdf[col] = np.log1p(tstdf[col].values)
            tstdf = scaler.transform(tstdf.values)
            X_test = csr_matrix(hstack([csr_matrix(tstdf), ready_df[0:traindex.shape[0]][~trnidx]]))
            y_test  = y[~trnidx]
        #tfvocab = df.drop('fold', 1).columns.tolist() + vectorizer.get_feature_names()
        del trndf
        gc.collect()
        for shape in [X_train, X_test]:
            print("Fold {} : {} Rows and {} Cols".format(f, *shape.shape))
        gc.collect();
        gc.collect()
    
        if f==5:
            best_iter = 0
            print('avg best iter: %s'%(best_iter))
            # ridge = Ridge(solver='auto', fit_intercept=True, alpha=0.4, max_iter=200, normalize=False, tol=0.01)
            # ridge.fit(X_train, y_train)
            y_predls = []
            for ep in range(nnbags):
                gc.collect()
                sparse_nn = sparseNN()
                sparse_nn.fit(X_train, y_train, \
                              batch_size=BATCH_SIZE, \
                              epochs=1, verbose=1 )
                y_predls.append(np.clip(sparse_nn.predict(X_test, batch_size=20000),-0.1, 1.1))
            y_pred = sum(y_predls)/len(y_predls)
        else:
            best_iter = 0
            print('avg best iter: %s'%(best_iter))
            # ridge = Ridge(solver='auto', fit_intercept=True, alpha=0.4, max_iter=200, normalize=False, tol=0.01)
            # ridge.fit(X_train, y_train)
            y_predls = []
            for ep in range(nnbags):
                gc.collect()
                sparse_nn = sparseNN()
                sparse_nn.fit(X_train, y_train, \
                              batch_size=BATCH_SIZE, \
                              validation_data = (X_test, y_test), \
                              epochs=1, verbose=1 )
                y_predls.append(np.clip(sparse_nn.predict(X_test, batch_size=20000),-0.1, 1.1))
                print('RMSE fold %s bag %s:'%(f, ep), np.sqrt(metrics.mean_squared_error(y_test, sum(y_predls)/len(y_predls))))
            y_pred = sum(y_predls)/len(y_predls)
            
        print("Model Evaluation Stage")
        if f == 5:
            y_pred_tst[:] += y_pred.flatten() # ridge.predict(X_test)
        else:
            y_pred_trn[~trnidx] += y_pred.flatten() # ridge.predict(X_test)
            print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_trn[~trnidx])))
        del X_test
        gc.collect()
        y_pred_trn.to_csv("rmlp5CV_2306B_trn.csv",index=True)
        y_pred_tst.to_csv("rmlp5CV_2306B_tst.csv",index=True)

# %%
lgsub = pd.concat([y_pred_trn, y_pred_tst]).reset_index()
lgsub.rename(columns = {0 : 'deal_probability'}, inplace=True)
lgsub['deal_probability'] = lgsub['deal_probability']/(bag+1)
lgsub.set_index('item_id', inplace = True)
print('RMSE for all :', np.sqrt(metrics.mean_squared_error(y, lgsub.loc[traindex])))
lgsub.to_csv("rmlp5CV_2306B.csv.gz",index=True,header=True, compression = 'gzip')

lgsub.to_csv(path + "../sub/rmlp5CV_2306B.csv.gz",index=True,header=True, compression = 'gzip')
