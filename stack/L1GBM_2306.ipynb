# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    import gc
import pandas as pd
import numpy as np
from sklearn import metrics#, linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from lightgbm import LGBMRegressor
import sys
import warnings
import itertools

if not sys.warnoptions:
    warnings.simplefilter("ignore")

path = "/home/darragh/avito/data/"
#path = '/Users/dhanley2/Documents/avito/data/'
#path = '/home/ubuntu/avito/data/'
#data_path = 'data/'

# %%
#lgb25 = pd.read_csv('../lgCV_2505.csv.gz', compression='gzip')
lgb02A = pd.read_csv(path+'../sub/lgCV_0206A.csv.gz', compression='gzip')
lgb09 = pd.read_csv(path+'../sub/lgCV_0906.csv.gz', compression='gzip')
lgb10 = pd.read_csv(path+'../sub/lgCV_1006.csv.gz', compression='gzip')
lgb11A= pd.read_csv(path+'../sub/lgCV_1106A.csv.gz', compression='gzip')
lgb11D= pd.read_csv(path+'../sub/lgCV_1106D.csv.gz', compression='gzip')
lgb14= pd.read_csv(path+'../sub/lgCV_1406.csv.gz', compression='gzip')
lgb14A= pd.read_csv(path+'../sub/lgCV_1406A.csv.gz', compression='gzip')
lgb27 = pd.read_csv(path+'../sub/lgCV_2705B.csv.gz', compression='gzip')
lgb31 = pd.read_csv(path+'../sub/lgCV_3105.csv.gz', compression='gzip')
lgb02 = pd.read_csv(path+'../sub/lgCV_0206.csv.gz', compression='gzip')
lgb17 = pd.read_csv(path+'../sub/lgCV_1706.csv.gz', compression='gzip')
lgb19 = pd.read_csv(path+'../sub/lgCV_1906.csv.gz', compression='gzip')
lgb20 = pd.read_csv(path+'../sub/lgCV_2006.csv.gz', compression='gzip')
lgb20C = pd.read_csv(path+'../sub/lgCV_2006C.csv.gz', compression='gzip')
lgb20B = pd.read_csv(path+'../sub/lgCV_2006B.csv.gz', compression='gzip')
lgb20AA = pd.read_csv(path+'../sub/lgCV_2006AA.csv.gz', compression='gzip')
lgb19A= pd.read_csv(path+'../sub/lgCV_1906A.csv.gz', compression='gzip')
rnn =   pd.read_csv(path+'../sub/rnnCV_2805.csv.gz', compression='gzip')
rnn27 = pd.read_csv(path+'../sub/rnnCV_2705A.csv.gz', compression='gzip')
rnn12 = pd.read_csv(path+'../sub/rnnCV_1206.csv.gz', compression='gzip')
rnn12 = pd.read_csv(path+'../sub/rnnCV_1206.csv.gz', compression='gzip')
mlp =   pd.read_csv(path+'../sub/mlpCV_2505.csv.gz', compression='gzip')
rdgv19 =   pd.read_csv(path+'../sub/rdgv19CV_1606.csv.gz', compression='gzip')
rdgv20 =   pd.read_csv(path+'../sub/rdg5CV_2006B.csv.gz', compression='gzip')
rdgv23 =   pd.read_csv(path+'../sub/rdg5CV_2306.csv.gz', compression='gzip')


truth = pd.read_csv(path+'train.csv.zip', compression='zip', parse_dates = ["activation_date"])
y =     truth['deal_probability'].values
truth.drop('deal_probability', 1)
test =  pd.read_csv(path+'test.csv.zip', compression='zip', parse_dates = ["activation_date"])
test['deal_probability']=float('NAN') 
truth = pd.concat([truth,test[truth.columns]],axis=0)

# %%
entropy = pd.read_csv(path+'../features/user_entropy_2306.gz', compression='gzip')
entropy.drop(['user_id', 'index'], 1, inplace = True)
entropy.head()
# Out:
#    user_id__category_name__entropy  user_id__parent_category_name__entropy  \
# 0                         0.000000                                0.000000
# 1                         0.000000                                0.000000
# 2                         0.325083                                0.000000
# 3                         1.931448                                0.935704
# 4                         0.000000                                0.000000
#
#    user_id__title__entropy  user_id__param_1__entropy  user_id__city__entropy  \
# 0                 0.636514                   0.636514                     0.0
# 1                 0.000000                   0.000000                     0.0
# 2                 2.163956                   0.325083                     0.0
# 3                 3.459348                   2.538687                     0.0
# 4                 0.000000                   0.000000                     0.0
#
#    user_id__param_2__entropy  user_id__param_3__entropy  \
# 0                   0.000000                   0.000000
# 1                   0.000000                   0.000000
# 2                   2.163956                   0.000000
# 3                   1.342766                   0.737584
# 4                   0.000000                   0.000000
#
#    user_id__activation_date__entropy
# 0                           1.098612
# 1                           0.000000
# 2                           1.504788
# 3                           0.937894
# 4                           0.000000

# %%
lgb14['deal_probability'] =  ( lgb14['deal_probability'].values + lgb14A['deal_probability'].values)*0.5
lgb17['deal_probability'] =  ( lgb17['deal_probability'].values + lgb19['deal_probability'].values)*0.25
lgb20['deal_probability'] =  ( lgb20['deal_probability'].values) * 0.5

# %%
#img_cts = truth['image_top_1'].value_counts().reset_index()
#truth['image_top_big'] = 'lo_count'
#big_top_1 = img_cts[img_cts['image_top_1']>5000]['index'].tolist()
#idx = truth['image_top_1'].isin(big_top_1)
#truth['image_top_big'][idx] = truth['image_top_1'][idx].astype(str).values

def keep_big(df, col, cutoff):
    cts = df[col].value_counts().reset_index()
    df[col+'_big'] = 'lo_count'
    big = cts[cts[col]>cutoff]['index'].tolist()
    idx = df[col].isin(big)
    df[col+'_big'][idx] = df[col][idx].astype(str).values
    return df[col+'_big'].values
truth['image_top_1_big'] = keep_big(truth, 'image_top_1', 5000)
truth['param_1_big'] = keep_big(truth, 'param_1', 5000)
truth['param_2_big'] = keep_big(truth, 'param_2', 5000)
truth['param_3_big'] = keep_big(truth, 'param_3', 5000)
truth['city_big'] = keep_big(truth, 'city', 5000)

# %%
truth[[c for c in truth.columns if 'big' in c]].head()
# Out:
#   image_top_1_big                param_1_big param_2_big param_3_big  \
# 0        lo_count  Постельные принадлежности    lo_count    lo_count
# 1        lo_count                     Другое    lo_count    lo_count
# 2        lo_count                   lo_count    lo_count    lo_count
# 3           796.0       Автомобильные кресла    lo_count    lo_count
# 4          2264.0                 С пробегом  ВАЗ (LADA)    lo_count
#
#            city_big
# 0      Екатеринбург
# 1            Самара
# 2    Ростов-на-Дону
# 3  Набережные Челны
# 4         Волгоград

# %%
#lgb25.rename(columns={'deal_probability': 'lgb25_preds' }, inplace=True)
lgb31.rename(columns={'deal_probability': 'lgb31_preds' }, inplace=True)
lgb27.rename(columns={'deal_probability': 'lgb27_preds' }, inplace=True)
lgb02.rename(columns={'deal_probability': 'lgb02_preds' }, inplace=True)
lgb09.rename(columns={'deal_probability': 'lgb09_preds' }, inplace=True)
lgb10.rename(columns={'deal_probability': 'lgb10_preds' }, inplace=True)
lgb11D.rename(columns={'deal_probability': 'lgb11D_preds' }, inplace=True)
lgb11A.rename(columns={'deal_probability': 'lgb11A_preds' }, inplace=True)
lgb14.rename(columns={'deal_probability': 'lgb14_preds' }, inplace=True)
lgb17.rename(columns={'deal_probability': 'lgb17_preds' }, inplace=True)
lgb20.rename(columns={'deal_probability': 'lgb20_preds' }, inplace=True)
lgb20C.rename(columns={'deal_probability': 'lgb20C_preds' }, inplace=True)
lgb20B.rename(columns={'deal_probability': 'lgb20B_preds' }, inplace=True)
lgb20AA.rename(columns={'deal_probability': 'lgb20AA_preds' }, inplace=True)
lgb19A.rename(columns={'deal_probability': 'lgb19A_preds' }, inplace=True)
lgb02A.rename(columns={'deal_probability': 'lgb02A_preds' }, inplace=True)
rnn27.rename(columns={'deal_probability': 'rnn27_preds' }, inplace=True)
rnn12.rename(columns={'deal_probability': 'rnn12_preds' }, inplace=True)
rdgv19.rename(columns={'deal_probability': 'rdgv19_preds' }, inplace=True)
rdgv20.rename(columns={'deal_probability': 'rdgv20_preds' }, inplace=True)
rdgv23.rename(columns={'deal_probability': 'rdgv23_preds' }, inplace=True)
mlp.rename(columns={'deal_probability': 'mlp_preds' }, inplace=True)
preds_df = lgb27.merge(rnn, on='item_id')\
                .merge(mlp, on='item_id')\
                .merge(lgb31, on='item_id')\
                .merge(lgb02, on='item_id')\
                .merge(lgb09, on='item_id')\
                .merge(lgb10, on='item_id')\
                .merge(lgb11A, on='item_id')\
                .merge(lgb11D, on='item_id')\
                .merge(lgb14, on='item_id')\
                .merge(lgb17, on='item_id')\
                .merge(lgb20, on='item_id')\
                .merge(lgb20C, on='item_id')\
                .merge(lgb20B, on='item_id')\
                .merge(lgb20AA, on='item_id')\
                .merge(lgb19A, on='item_id')\
                .merge(lgb02A, on='item_id')\
                .merge(rnn27, on='item_id')\
                .merge(rnn12, on='item_id')\
                .merge(rdgv19, on='item_id')\
                .merge(rdgv20, on='item_id')\
                .merge(rdgv23, on='item_id')\
                .merge(truth, on='item_id',how='left')

# %%
pred_cols = [col for col in preds_df.columns if ('_preds' in col) \
             and ('lgb27' not in col) and ('lgb02_' not in col) and ('lgb11A_' not in col) \
             and ('rdgv19_' not in col) and ('lgb17_' not in col)]

preds_df['preds_sum'] = preds_df[pred_cols].sum(axis=1)
pred_cols
# Out:
# ['rnn_preds',
#  'mlp_preds',
#  'lgb31_preds',
#  'lgb09_preds',
#  'lgb10_preds',
#  'lgb11D_preds',
#  'lgb14_preds',
#  'lgb20_preds',
#  'lgb20C_preds',
#  'lgb20B_preds',
#  'lgb20AA_preds',
#  'lgb19A_preds',
#  'lgb02A_preds',
#  'rnn27_preds',
#  'rnn12_preds',
#  'rdgv20_preds',
#  'rdgv23_preds']

# %%
preds_df['price'].fillna(-1,inplace=True)
preds_df['_max_'] = np.max(np.array([preds_df[col] for col in pred_cols]),axis=0).astype(np.float32)
preds_df['_min_'] = np.min(np.array([preds_df[col] for col in pred_cols]),axis=0).astype(np.float32)
preds_df['_avg_'] = np.mean(np.array([preds_df[col] for col in pred_cols]),axis=0).astype(np.float32)
preds_df['_med_'] = np.median(np.array([preds_df[col] for col in pred_cols]),axis=0).astype(np.float32)
preds_df['_std_'] = np.std(np.array([preds_df[col] for col in pred_cols]),axis=0).astype(np.float32)

# %%
#for v in ['rnn', 'rdg', 'lgb1', 'lgb2']:
#    cols = [col for col in preds_df.columns if v in col]
#    preds_df[v+'_max_'] = np.max(np.array([preds_df[col] for col in cols]),axis=0).astype(np.float32)
#    preds_df[v+'_min_'] = np.min(np.array([preds_df[col] for col in cols]),axis=0).astype(np.float32)
#    preds_df[v+'_avg_'] = np.mean(np.array([preds_df[col] for col in cols]),axis=0).astype(np.float32)
#    preds_df[v+'_med_'] = np.median(np.array([preds_df[col] for col in cols]),axis=0).astype(np.float32)
#    preds_df[v+'_std_'] = np.std(np.array([preds_df[col] for col in cols]),axis=0).astype(np.float32)

# %%
import itertools
for p1, p2 in itertools.combinations(pred_cols, 2):
    print('difference_%s__%s'%(p1,p2))
    preds_df['difference_%s__%s'%(p1,p2)] = (preds_df[p2] - preds_df[p1]).astype(np.float32)
    preds_df['sums_%s__%s'%(p1,p2)] = (preds_df[p2] + preds_df[p1]).astype(np.float32)
# Out:
# difference_rnn_preds__mlp_preds
# difference_rnn_preds__lgb31_preds
# difference_rnn_preds__lgb09_preds
# difference_rnn_preds__lgb10_preds
# difference_rnn_preds__lgb11D_preds
# difference_rnn_preds__lgb14_preds
# difference_rnn_preds__lgb20_preds
# difference_rnn_preds__lgb20C_preds
# difference_rnn_preds__lgb20B_preds
# difference_rnn_preds__lgb20AA_preds
# difference_rnn_preds__lgb19A_preds
# difference_rnn_preds__lgb02A_preds
# difference_rnn_preds__rnn27_preds
# difference_rnn_preds__rnn12_preds
# difference_rnn_preds__rdgv20_preds
# difference_rnn_preds__rdgv23_preds
# difference_mlp_preds__lgb31_preds
# difference_mlp_preds__lgb09_preds
# difference_mlp_preds__lgb10_preds
# difference_mlp_preds__lgb11D_preds
# difference_mlp_preds__lgb14_preds
# difference_mlp_preds__lgb20_preds
# difference_mlp_preds__lgb20C_preds
# difference_mlp_preds__lgb20B_preds
# difference_mlp_preds__lgb20AA_preds
# difference_mlp_preds__lgb19A_preds
# difference_mlp_preds__lgb02A_preds
# difference_mlp_preds__rnn27_preds
# difference_mlp_preds__rnn12_preds
# difference_mlp_preds__rdgv20_preds
# difference_mlp_preds__rdgv23_preds
# difference_lgb31_preds__lgb09_preds
# difference_lgb31_preds__lgb10_preds
# difference_lgb31_preds__lgb11D_preds
# difference_lgb31_preds__lgb14_preds
# difference_lgb31_preds__lgb20_preds
# difference_lgb31_preds__lgb20C_preds
# difference_lgb31_preds__lgb20B_preds
# difference_lgb31_preds__lgb20AA_preds
# difference_lgb31_preds__lgb19A_preds
# difference_lgb31_preds__lgb02A_preds
# difference_lgb31_preds__rnn27_preds
# difference_lgb31_preds__rnn12_preds
# difference_lgb31_preds__rdgv20_preds
# difference_lgb31_preds__rdgv23_preds
# difference_lgb09_preds__lgb10_preds
# difference_lgb09_preds__lgb11D_preds
# difference_lgb09_preds__lgb14_preds
# difference_lgb09_preds__lgb20_preds
# difference_lgb09_preds__lgb20C_preds
# difference_lgb09_preds__lgb20B_preds
# difference_lgb09_preds__lgb20AA_preds
# difference_lgb09_preds__lgb19A_preds
# difference_lgb09_preds__lgb02A_preds
# difference_lgb09_preds__rnn27_preds
# difference_lgb09_preds__rnn12_preds
# difference_lgb09_preds__rdgv20_preds
# difference_lgb09_preds__rdgv23_preds
# difference_lgb10_preds__lgb11D_preds
# difference_lgb10_preds__lgb14_preds
# difference_lgb10_preds__lgb20_preds
# difference_lgb10_preds__lgb20C_preds
# difference_lgb10_preds__lgb20B_preds
# difference_lgb10_preds__lgb20AA_preds
# difference_lgb10_preds__lgb19A_preds
# difference_lgb10_preds__lgb02A_preds
# difference_lgb10_preds__rnn27_preds
# difference_lgb10_preds__rnn12_preds
# difference_lgb10_preds__rdgv20_preds
# difference_lgb10_preds__rdgv23_preds
# difference_lgb11D_preds__lgb14_preds
# difference_lgb11D_preds__lgb20_preds
# difference_lgb11D_preds__lgb20C_preds
# difference_lgb11D_preds__lgb20B_preds
# difference_lgb11D_preds__lgb20AA_preds
# difference_lgb11D_preds__lgb19A_preds
# difference_lgb11D_preds__lgb02A_preds
# difference_lgb11D_preds__rnn27_preds
# difference_lgb11D_preds__rnn12_preds
# difference_lgb11D_preds__rdgv20_preds
# difference_lgb11D_preds__rdgv23_preds
# difference_lgb14_preds__lgb20_preds
# difference_lgb14_preds__lgb20C_preds
# difference_lgb14_preds__lgb20B_preds
# difference_lgb14_preds__lgb20AA_preds
# difference_lgb14_preds__lgb19A_preds
# difference_lgb14_preds__lgb02A_preds
# difference_lgb14_preds__rnn27_preds
# difference_lgb14_preds__rnn12_preds
# difference_lgb14_preds__rdgv20_preds
# difference_lgb14_preds__rdgv23_preds
# difference_lgb20_preds__lgb20C_preds
# difference_lgb20_preds__lgb20B_preds
# difference_lgb20_preds__lgb20AA_preds
# difference_lgb20_preds__lgb19A_preds
# difference_lgb20_preds__lgb02A_preds
# difference_lgb20_preds__rnn27_preds
# difference_lgb20_preds__rnn12_preds
# difference_lgb20_preds__rdgv20_preds
# difference_lgb20_preds__rdgv23_preds
# difference_lgb20C_preds__lgb20B_preds
# difference_lgb20C_preds__lgb20AA_preds
# difference_lgb20C_preds__lgb19A_preds
# difference_lgb20C_preds__lgb02A_preds
# difference_lgb20C_preds__rnn27_preds
# difference_lgb20C_preds__rnn12_preds
# difference_lgb20C_preds__rdgv20_preds
# difference_lgb20C_preds__rdgv23_preds
# difference_lgb20B_preds__lgb20AA_preds
# difference_lgb20B_preds__lgb19A_preds
# difference_lgb20B_preds__lgb02A_preds
# difference_lgb20B_preds__rnn27_preds
# difference_lgb20B_preds__rnn12_preds
# difference_lgb20B_preds__rdgv20_preds
# difference_lgb20B_preds__rdgv23_preds
# difference_lgb20AA_preds__lgb19A_preds
# difference_lgb20AA_preds__lgb02A_preds
# difference_lgb20AA_preds__rnn27_preds
# difference_lgb20AA_preds__rnn12_preds
# difference_lgb20AA_preds__rdgv20_preds
# difference_lgb20AA_preds__rdgv23_preds
# difference_lgb19A_preds__lgb02A_preds
# difference_lgb19A_preds__rnn27_preds
# difference_lgb19A_preds__rnn12_preds
# difference_lgb19A_preds__rdgv20_preds
# difference_lgb19A_preds__rdgv23_preds
# difference_lgb02A_preds__rnn27_preds
# difference_lgb02A_preds__rnn12_preds
# difference_lgb02A_preds__rdgv20_preds
# difference_lgb02A_preds__rdgv23_preds
# difference_rnn27_preds__rnn12_preds
# difference_rnn27_preds__rdgv20_preds
# difference_rnn27_preds__rdgv23_preds
# difference_rnn12_preds__rdgv20_preds
# difference_rnn12_preds__rdgv23_preds
# difference_rdgv20_preds__rdgv23_preds

# %%
for col in entropy.columns:
    print(col)
    preds_df[col] = (entropy[col].values).astype(np.float32)
del entropy
gc.collect()
# Out:
# user_id__category_name__entropy
# user_id__parent_category_name__entropy
# user_id__title__entropy
# user_id__param_1__entropy
# user_id__city__entropy
# user_id__param_2__entropy
# user_id__param_3__entropy
# user_id__activation_date__entropy
# 501

# %%
gc.collect()
# Out:
# 0

# %%
preds_df.head()
# Out:
#         item_id  lgb27_preds  rnn_preds  mlp_preds  lgb31_preds  lgb02_preds  \
# 0  b912c3c6a6ad     0.091656   0.069891   0.091223     0.083219     0.090855
# 1  2dac0150717d     0.147801   0.075968   0.211844     0.157973     0.119609
# 2  ba83aefab5dc     0.186261   0.167167   0.236579     0.227048     0.258980
# 3  02996f1dd2ea     0.241699   0.260876   0.383699     0.231447     0.284130
# 4  7c90be56d2ab     0.407423   0.431520   0.420657     0.412563     0.430581
#
#    lgb09_preds  lgb10_preds  lgb11A_preds  lgb11D_preds  \
# 0     0.109624     0.107764      0.095101      0.092921
# 1     0.157466     0.161107      0.140269      0.144395
# 2     0.245236     0.219107      0.234076      0.222678
# 3     0.289101     0.255519      0.241802      0.271355
# 4     0.511145     0.511676      0.504849      0.503961
#
#                  ...                  difference_rdgv20_preds__rdgv23_preds  \
# 0                ...                                               0.023870
# 1                ...                                              -0.062379
# 2                ...                                              -0.028658
# 3                ...                                               0.032576
# 4                ...                                              -0.091717
#
#    sums_rdgv20_preds__rdgv23_preds  user_id__category_name__entropy  \
# 0                         0.142215                         0.000000
# 1                         0.359826                         0.000000
# 2                         0.355298                         0.325083
# 3                         0.640029                         1.931448
# 4                         0.862042                         0.000000
#
#    user_id__parent_category_name__entropy  user_id__title__entropy  \
# 0                                0.000000                 0.636514
# 1                                0.000000                 0.000000
# 2                                0.000000                 2.163956
# 3                                0.935704                 3.459348
# 4                                0.000000                 0.000000
#
#    user_id__param_1__entropy  user_id__city__entropy  \
# 0                   0.636514                     0.0
# 1                   0.000000                     0.0
# 2                   0.325083                     0.0
# 3                   2.538687                     0.0
# 4                   0.000000                     0.0
#
#    user_id__param_2__entropy  user_id__param_3__entropy  \
# 0                   0.000000                   0.000000
# 1                   0.000000                   0.000000
# 2                   2.163956                   0.000000
# 3                   1.342766                   0.737584
# 4                   0.000000                   0.000000
#
#    user_id__activation_date__entropy
# 0                           1.098612
# 1                           0.000000
# 2                           1.504788
# 3                           0.937894
# 4                           0.000000
#
# [5 rows x 332 columns]

# %% [markdown]
# ### Train scores

# %%
pred_cols = [col for col in preds_df.columns if ('preds' in col) 
             and ('difference' not in col) 
             and ('sum' not in col)]
pred_cols
# Out:
# ['lgb27_preds',
#  'rnn_preds',
#  'mlp_preds',
#  'lgb31_preds',
#  'lgb02_preds',
#  'lgb09_preds',
#  'lgb10_preds',
#  'lgb11A_preds',
#  'lgb11D_preds',
#  'lgb14_preds',
#  'lgb17_preds',
#  'lgb20_preds',
#  'lgb20C_preds',
#  'lgb20B_preds',
#  'lgb20AA_preds',
#  'lgb19A_preds',
#  'lgb02A_preds',
#  'rnn27_preds',
#  'rnn12_preds',
#  'rdgv19_preds',
#  'rdgv20_preds',
#  'rdgv23_preds']

# %%
idx = preds_df['deal_probability']==preds_df['deal_probability']
print(idx.value_counts())
for col in [c for c in preds_df.columns if ('_preds' in c) and ('difference' not in c) and ('sum' not in c)]:
    print('RMSE %s: '%(col), np.sqrt(metrics.mean_squared_error(preds_df['deal_probability'][idx].values, preds_df[col][idx].values)))
# Out:
# True     1503424
# False     508438
# Name: deal_probability, dtype: int64
# RMSE lgb27_preds:  0.21681527582821059
# RMSE rnn_preds:  0.21771476573780568
# RMSE mlp_preds:  0.2187544351068867
# RMSE lgb31_preds:  0.21681135578306754
# RMSE lgb02_preds:  0.21625386267187377
# RMSE lgb09_preds:  0.21581543265040168
# RMSE lgb10_preds:  0.21533498019117664
# RMSE lgb11A_preds:  0.21403812331071156
# RMSE lgb11D_preds:  0.21392147604708842
# RMSE lgb14_preds:  0.21329729304260686
# RMSE lgb17_preds:  0.21311496843894262
# RMSE lgb20_preds:  0.21300538173982395
# RMSE lgb20C_preds:  0.21333102462329412
# RMSE lgb20B_preds:  0.21317314259822653
# RMSE lgb20AA_preds:  0.21329931538907382
# RMSE lgb19A_preds:  0.21341739569735188
# RMSE lgb02A_preds:  0.21627136604335995
# RMSE rnn27_preds:  0.21698040871120608
# RMSE rnn12_preds:  0.2167114508342396
# RMSE rdgv19_preds:  0.24593955235646558
# RMSE rdgv20_preds:  0.22348322742981183
# RMSE rdgv23_preds:  0.22510898554248446

# %%
foldls = [["2017-03-15", "2017-03-16", "2017-03-17"], \
       ["2017-03-18", "2017-03-19", "2017-03-20"], \
       ["2017-03-21", "2017-03-22", "2017-03-23"], \
       ["2017-03-24", "2017-03-25", "2017-03-26"], \
        ["2017-03-27", "2017-03-28", "2017-03-29", \
            "2017-03-30", "2017-03-31", "2017-04-01", \
            "2017-04-02", "2017-04-03","2017-04-07"]]
foldls = [[pd.to_datetime(d) for d in f] for f in foldls]
preds_df['fold'] = -1
for t, fold in enumerate(foldls):
    preds_df['fold'][preds_df.activation_date.isin(fold)] = t

# %%
scores = []
for col in [c for c in preds_df.columns if ('_preds' in c) \
            and ('difference' not in c) \
            and ('sum' not in c)]:
    lstmp = [col]
    for i in range(5):
        idx = preds_df['fold']==i
        lstmp.append(np.sqrt(metrics.mean_squared_error(preds_df['deal_probability'][idx].values, \
                                                        preds_df[col][idx].values)))
    scores.append(lstmp)
pd.DataFrame(scores, columns = ['Model']+['Fold%s'%(i) for i in range(5)])
# Out:
#             Model     Fold0     Fold1     Fold2     Fold3     Fold4
# 0     lgb27_preds  0.216848  0.217096  0.217923  0.217597  0.213692
# 1       rnn_preds  0.218756  0.218966  0.215764  0.219554  0.214747
# 2       mlp_preds  0.219660  0.220088  0.216672  0.220347  0.216385
# 3     lgb31_preds  0.216537  0.216643  0.219230  0.217169  0.213430
# 4     lgb02_preds  0.216371  0.216447  0.217354  0.217032  0.213158
# 5     lgb09_preds  0.215514  0.215678  0.218418  0.216073  0.212293
# 6     lgb10_preds  0.215240  0.215533  0.217072  0.215802  0.212023
# 7    lgb11A_preds  0.215011  0.215205  0.211879  0.215771  0.211735
# 8    lgb11D_preds  0.214818  0.215074  0.211837  0.215720  0.211549
# 9     lgb14_preds  0.214204  0.214441  0.211074  0.215146  0.211051
# 10    lgb17_preds  0.214061  0.214275  0.210872  0.214884  0.210930
# 11    lgb20_preds  0.213929  0.214201  0.210747  0.214698  0.210926
# 12   lgb20C_preds  0.214171  0.214553  0.211112  0.215042  0.211248
# 13   lgb20B_preds  0.214104  0.214297  0.210971  0.214910  0.211047
# 14  lgb20AA_preds  0.214170  0.214483  0.211014  0.215037  0.211288
# 15   lgb19A_preds  0.214280  0.214530  0.211292  0.215184  0.211253
# 16   lgb02A_preds  0.216081  0.216051  0.218825  0.216562  0.212741
# 17    rnn27_preds  0.218097  0.218115  0.214982  0.218651  0.214379
# 18    rnn12_preds  0.217658  0.217913  0.214952  0.218472  0.213781
# 19   rdgv19_preds  0.246571  0.246399  0.244456  0.247503  0.244406
# 20   rdgv20_preds  0.224235  0.224335  0.221782  0.224992  0.221599
# 21   rdgv23_preds  0.226034  0.225994  0.223219  0.226920  0.222791

# %% [markdown]
# ### Correlations in test and train

# %%
# Test correlation
preds_df[~preds_df['deal_probability'].isnull()][[c for c in preds_df.columns if ('_preds' in c) \
                                                  and ('difference' not in c) and ('sum' not in c) ]].corr()
# Out:
#                lgb27_preds  rnn_preds  mlp_preds  lgb31_preds  lgb02_preds  \
# lgb27_preds       1.000000   0.915952   0.919171     0.990750     0.988682
# rnn_preds         0.915952   1.000000   0.929710     0.910602     0.913307
# mlp_preds         0.919171   0.929710   1.000000     0.914307     0.916343
# lgb31_preds       0.990750   0.910602   0.914307     1.000000     0.991984
# lgb02_preds       0.988682   0.913307   0.916343     0.991984     1.000000
# lgb09_preds       0.978331   0.908867   0.909521     0.981891     0.982596
# lgb10_preds       0.978298   0.913286   0.913883     0.981375     0.982052
# lgb11A_preds      0.966819   0.915655   0.915367     0.966656     0.970858
# lgb11D_preds      0.965873   0.913936   0.913018     0.965897     0.969933
# lgb14_preds       0.961540   0.912870   0.911656     0.961575     0.966325
# lgb17_preds       0.963754   0.915690   0.915252     0.963672     0.968201
# lgb20_preds       0.961191   0.913122   0.912500     0.961171     0.965676
# lgb20C_preds      0.958111   0.910139   0.909923     0.958000     0.961399
# lgb20B_preds      0.954982   0.909274   0.907368     0.955024     0.958416
# lgb20AA_preds     0.958141   0.910838   0.909956     0.958066     0.962551
# lgb19A_preds      0.957731   0.910086   0.908837     0.957796     0.962391
# lgb02A_preds      0.983143   0.911443   0.913600     0.986851     0.987434
# rnn27_preds       0.916804   0.985360   0.925010     0.914204     0.916726
# rnn12_preds       0.920576   0.978274   0.929518     0.916939     0.920105
# rdgv19_preds      0.568406   0.551100   0.577280     0.570034     0.567698
# rdgv20_preds      0.889293   0.870967   0.894224     0.886311     0.887142
# rdgv23_preds      0.898176   0.879138   0.909667     0.895124     0.894194
#
#                lgb09_preds  lgb10_preds  lgb11A_preds  lgb11D_preds  \
# lgb27_preds       0.978331     0.978298      0.966819      0.965873
# rnn_preds         0.908867     0.913286      0.915655      0.913936
# mlp_preds         0.909521     0.913883      0.915367      0.913018
# lgb31_preds       0.981891     0.981375      0.966656      0.965897
# lgb02_preds       0.982596     0.982052      0.970858      0.969933
# lgb09_preds       1.000000     0.990447      0.976755      0.976540
# lgb10_preds       0.990447     1.000000      0.982841      0.982033
# lgb11A_preds      0.976755     0.982841      1.000000      0.992400
# lgb11D_preds      0.976540     0.982033      0.992400      1.000000
# lgb14_preds       0.972392     0.977396      0.988703      0.989978
# lgb17_preds       0.972977     0.978691      0.989962      0.990876
# lgb20_preds       0.970851     0.976402      0.987555      0.988477
# lgb20C_preds      0.964949     0.971149      0.981921      0.982563
# lgb20B_preds      0.961188     0.967745      0.978661      0.979283
# lgb20AA_preds     0.966872     0.972605      0.983654      0.984497
# lgb19A_preds      0.968260     0.973449      0.984745      0.985921
# lgb02A_preds      0.988708     0.985858      0.971893      0.971846
# rnn27_preds       0.912375     0.916436      0.918727      0.917196
# rnn12_preds       0.915090     0.920034      0.923137      0.921322
# rdgv19_preds      0.560909     0.562639      0.558477      0.557072
# rdgv20_preds      0.882808     0.888719      0.891140      0.888543
# rdgv23_preds      0.882028     0.889426      0.889225      0.885673
#
#                lgb14_preds      ...       lgb20C_preds  lgb20B_preds  \
# lgb27_preds       0.961540      ...           0.958111      0.954982
# rnn_preds         0.912870      ...           0.910139      0.909274
# mlp_preds         0.911656      ...           0.909923      0.907368
# lgb31_preds       0.961575      ...           0.958000      0.955024
# lgb02_preds       0.966325      ...           0.961399      0.958416
# lgb09_preds       0.972392      ...           0.964949      0.961188
# lgb10_preds       0.977396      ...           0.971149      0.967745
# lgb11A_preds      0.988703      ...           0.981921      0.978661
# lgb11D_preds      0.989978      ...           0.982563      0.979283
# lgb14_preds       1.000000      ...           0.984699      0.981670
# lgb17_preds       0.994906      ...           0.986776      0.983937
# lgb20_preds       0.991492      ...           0.988110      0.985111
# lgb20C_preds      0.984699      ...           1.000000      0.984618
# lgb20B_preds      0.981670      ...           0.984618      1.000000
# lgb20AA_preds     0.987318      ...           0.986415      0.982402
# lgb19A_preds      0.990040      ...           0.982779      0.979765
# lgb02A_preds      0.967560      ...           0.960275      0.956371
# rnn27_preds       0.916160      ...           0.913287      0.912572
# rnn12_preds       0.920547      ...           0.917450      0.916628
# rdgv19_preds      0.553930      ...           0.554074      0.552729
# rdgv20_preds      0.884350      ...           0.889687      0.889143
# rdgv23_preds      0.879642      ...           0.881111      0.878338
#
#                lgb20AA_preds  lgb19A_preds  lgb02A_preds  rnn27_preds  \
# lgb27_preds         0.958141      0.957731      0.983143     0.916804
# rnn_preds           0.910838      0.910086      0.911443     0.985360
# mlp_preds           0.909956      0.908837      0.913600     0.925010
# lgb31_preds         0.958066      0.957796      0.986851     0.914204
# lgb02_preds         0.962551      0.962391      0.987434     0.916726
# lgb09_preds         0.966872      0.968260      0.988708     0.912375
# lgb10_preds         0.972605      0.973449      0.985858     0.916436
# lgb11A_preds        0.983654      0.984745      0.971893     0.918727
# lgb11D_preds        0.984497      0.985921      0.971846     0.917196
# lgb14_preds         0.987318      0.990040      0.967560     0.916160
# lgb17_preds         0.989026      0.990674      0.968335     0.918859
# lgb20_preds         0.990462      0.989451      0.966075     0.916268
# lgb20C_preds        0.986415      0.982779      0.960275     0.913287
# lgb20B_preds        0.982402      0.979765      0.956371     0.912572
# lgb20AA_preds       1.000000      0.985254      0.962059     0.913909
# lgb19A_preds        0.985254      1.000000      0.963496     0.913268
# lgb02A_preds        0.962059      0.963496      1.000000     0.914911
# rnn27_preds         0.913909      0.913268      0.914911     1.000000
# rnn12_preds         0.918365      0.917690      0.917453     0.979744
# rdgv19_preds        0.553319      0.552865      0.564071     0.558103
# rdgv20_preds        0.886154      0.882997      0.882887     0.872862
# rdgv23_preds        0.880681      0.877786      0.887012     0.879827
#
#                rnn12_preds  rdgv19_preds  rdgv20_preds  rdgv23_preds
# lgb27_preds       0.920576      0.568406      0.889293      0.898176
# rnn_preds         0.978274      0.551100      0.870967      0.879138
# mlp_preds         0.929518      0.577280      0.894224      0.909667
# lgb31_preds       0.916939      0.570034      0.886311      0.895124
# lgb02_preds       0.920105      0.567698      0.887142      0.894194
# lgb09_preds       0.915090      0.560909      0.882808      0.882028
# lgb10_preds       0.920034      0.562639      0.888719      0.889426
# lgb11A_preds      0.923137      0.558477      0.891140      0.889225
# lgb11D_preds      0.921322      0.557072      0.888543      0.885673
# lgb14_preds       0.920547      0.553930      0.884350      0.879642
# lgb17_preds       0.923748      0.558075      0.888366      0.885074
# lgb20_preds       0.920873      0.555115      0.888396      0.883102
# lgb20C_preds      0.917450      0.554074      0.889687      0.881111
# lgb20B_preds      0.916628      0.552729      0.889143      0.878338
# lgb20AA_preds     0.918365      0.553319      0.886154      0.880681
# lgb19A_preds      0.917690      0.552865      0.882997      0.877786
# lgb02A_preds      0.917453      0.564071      0.882887      0.887012
# rnn27_preds       0.979744      0.558103      0.872862      0.879827
# rnn12_preds       1.000000      0.564928      0.874289      0.884280
# rdgv19_preds      0.564928      1.000000      0.580895      0.620282
# rdgv20_preds      0.874289      0.580895      1.000000      0.932789
# rdgv23_preds      0.884280      0.620282      0.932789      1.000000
#
# [22 rows x 22 columns]

# %%
# Train correlation
preds_df[preds_df['deal_probability'].isnull()][[c for c in preds_df.columns if ('_preds' in c)  \
                                                  and ('difference' not in c) and ('sum' not in c) ]].corr()
# Out:
#                lgb27_preds  rnn_preds  mlp_preds  lgb31_preds  lgb02_preds  \
# lgb27_preds       1.000000   0.930288   0.924283     0.991439     0.989502
# rnn_preds         0.930288   1.000000   0.939951     0.927835     0.927867
# mlp_preds         0.924283   0.939951   1.000000     0.922413     0.921927
# lgb31_preds       0.991439   0.927835   0.922413     1.000000     0.993168
# lgb02_preds       0.989502   0.927867   0.921927     0.993168     1.000000
# lgb09_preds       0.979729   0.926158   0.918064     0.982874     0.984427
# lgb10_preds       0.979341   0.928367   0.920496     0.982519     0.983525
# lgb11A_preds      0.975840   0.927119   0.919275     0.978877     0.980105
# lgb11D_preds      0.973725   0.925632   0.917496     0.976777     0.978173
# lgb14_preds       0.970062   0.924680   0.916323     0.973170     0.975031
# lgb17_preds       0.972503   0.926976   0.919199     0.975607     0.977087
# lgb20_preds       0.970167   0.925169   0.917325     0.973347     0.974891
# lgb20C_preds      0.967707   0.922258   0.914782     0.970790     0.971359
# lgb20B_preds      0.964793   0.921521   0.912745     0.968049     0.968556
# lgb20AA_preds     0.967953   0.923007   0.915276     0.970928     0.972462
# lgb19A_preds      0.967059   0.922491   0.914513     0.970094     0.971908
# lgb02A_preds      0.984742   0.928496   0.922121     0.988043     0.989577
# rnn27_preds       0.930692   0.988198   0.935069     0.931468     0.931447
# rnn12_preds       0.932951   0.984113   0.936609     0.932981     0.933333
# rdgv19_preds      0.571110   0.559376   0.561935     0.572757     0.570342
# rdgv20_preds      0.893300   0.884649   0.896161     0.893488     0.891668
# rdgv23_preds      0.897237   0.889785   0.904597     0.897623     0.894092
#
#                lgb09_preds  lgb10_preds  lgb11A_preds  lgb11D_preds  \
# lgb27_preds       0.979729     0.979341      0.975840      0.973725
# rnn_preds         0.926158     0.928367      0.927119      0.925632
# mlp_preds         0.918064     0.920496      0.919275      0.917496
# lgb31_preds       0.982874     0.982519      0.978877      0.976777
# lgb02_preds       0.984427     0.983525      0.980105      0.978173
# lgb09_preds       1.000000     0.991413      0.988267      0.986666
# lgb10_preds       0.991413     1.000000      0.992340      0.990473
# lgb11A_preds      0.988267     0.992340      1.000000      0.993474
# lgb11D_preds      0.986666     0.990473      0.993474      1.000000
# lgb14_preds       0.983504     0.986869      0.990047      0.991525
# lgb17_preds       0.984455     0.988382      0.991264      0.992446
# lgb20_preds       0.982575     0.986348      0.989291      0.990493
# lgb20C_preds      0.977530     0.981817      0.984420      0.985464
# lgb20B_preds      0.974252     0.978865      0.981649      0.982692
# lgb20AA_preds     0.979460     0.983340      0.986105      0.987158
# lgb19A_preds      0.980115     0.983483      0.986600      0.988002
# lgb02A_preds      0.989106     0.986654      0.983556      0.981933
# rnn27_preds       0.929748     0.931841      0.930518      0.929068
# rnn12_preds       0.931167     0.933902      0.932743      0.931133
# rdgv19_preds      0.565333     0.566736      0.563841      0.561824
# rdgv20_preds      0.890096     0.894439      0.894709      0.892015
# rdgv23_preds      0.884800     0.890532      0.889705      0.886031
#
#                lgb14_preds      ...       lgb20C_preds  lgb20B_preds  \
# lgb27_preds       0.970062      ...           0.967707      0.964793
# rnn_preds         0.924680      ...           0.922258      0.921521
# mlp_preds         0.916323      ...           0.914782      0.912745
# lgb31_preds       0.973170      ...           0.970790      0.968049
# lgb02_preds       0.975031      ...           0.971359      0.968556
# lgb09_preds       0.983504      ...           0.977530      0.974252
# lgb10_preds       0.986869      ...           0.981817      0.978865
# lgb11A_preds      0.990047      ...           0.984420      0.981649
# lgb11D_preds      0.991525      ...           0.985464      0.982692
# lgb14_preds       1.000000      ...           0.987065      0.984581
# lgb17_preds       0.995582      ...           0.988925      0.986438
# lgb20_preds       0.992887      ...           0.989810      0.987227
# lgb20C_preds      0.987065      ...           1.000000      0.986966
# lgb20B_preds      0.984581      ...           0.986966      1.000000
# lgb20AA_preds     0.989161      ...           0.988314      0.984862
# lgb19A_preds      0.991390      ...           0.985123      0.982650
# lgb02A_preds      0.978724      ...           0.973004      0.969521
# rnn27_preds       0.928224      ...           0.925809      0.925216
# rnn12_preds       0.930421      ...           0.927769      0.927019
# rdgv19_preds      0.558673      ...           0.558790      0.557110
# rdgv20_preds      0.888155      ...           0.892642      0.892666
# rdgv23_preds      0.879956      ...           0.881461      0.878936
#
#                lgb20AA_preds  lgb19A_preds  lgb02A_preds  rnn27_preds  \
# lgb27_preds         0.967953      0.967059      0.984742     0.930692
# rnn_preds           0.923007      0.922491      0.928496     0.988198
# mlp_preds           0.915276      0.914513      0.922121     0.935069
# lgb31_preds         0.970928      0.970094      0.988043     0.931468
# lgb02_preds         0.972462      0.971908      0.989577     0.931447
# lgb09_preds         0.979460      0.980115      0.989106     0.929748
# lgb10_preds         0.983340      0.983483      0.986654     0.931841
# lgb11A_preds        0.986105      0.986600      0.983556     0.930518
# lgb11D_preds        0.987158      0.988002      0.981933     0.929068
# lgb14_preds         0.989161      0.991390      0.978724     0.928224
# lgb17_preds         0.990752      0.991955      0.979791     0.930381
# lgb20_preds         0.991763      0.990813      0.977889     0.928662
# lgb20C_preds        0.988314      0.985123      0.973004     0.925809
# lgb20B_preds        0.984862      0.982650      0.969521     0.925216
# lgb20AA_preds       1.000000      0.987308      0.974798     0.926462
# lgb19A_preds        0.987308      1.000000      0.975407     0.925964
# lgb02A_preds        0.974798      0.975407      1.000000     0.932071
# rnn27_preds         0.926462      0.925964      0.932071     1.000000
# rnn12_preds         0.928621      0.928202      0.933267     0.987051
# rdgv19_preds        0.558586      0.557790      0.567816     0.562929
# rdgv20_preds        0.889949      0.887164      0.890167     0.885260
# rdgv23_preds        0.881697      0.878607      0.889934     0.888474
#
#                rnn12_preds  rdgv19_preds  rdgv20_preds  rdgv23_preds
# lgb27_preds       0.932951      0.571110      0.893300      0.897237
# rnn_preds         0.984113      0.559376      0.884649      0.889785
# mlp_preds         0.936609      0.561935      0.896161      0.904597
# lgb31_preds       0.932981      0.572757      0.893488      0.897623
# lgb02_preds       0.933333      0.570342      0.891668      0.894092
# lgb09_preds       0.931167      0.565333      0.890096      0.884800
# lgb10_preds       0.933902      0.566736      0.894439      0.890532
# lgb11A_preds      0.932743      0.563841      0.894709      0.889705
# lgb11D_preds      0.931133      0.561824      0.892015      0.886031
# lgb14_preds       0.930421      0.558673      0.888155      0.879956
# lgb17_preds       0.932982      0.561605      0.891974      0.885434
# lgb20_preds       0.930992      0.559851      0.891846      0.883430
# lgb20C_preds      0.927769      0.558790      0.892642      0.881461
# lgb20B_preds      0.927019      0.557110      0.892666      0.878936
# lgb20AA_preds     0.928621      0.558586      0.889949      0.881697
# lgb19A_preds      0.928202      0.557790      0.887164      0.878607
# lgb02A_preds      0.933267      0.567816      0.890167      0.889934
# rnn27_preds       0.987051      0.562929      0.885260      0.888474
# rnn12_preds       1.000000      0.568866      0.885706      0.891643
# rdgv19_preds      0.568866      1.000000      0.588115      0.622936
# rdgv20_preds      0.885706      0.588115      1.000000      0.936256
# rdgv23_preds      0.891643      0.622936      0.936256      1.000000
#
# [22 rows x 22 columns]

# %%
cols = [c for c in preds_df.columns if '_preds' in c]
cols += [c for c in preds_df.columns if 'difference' in c]
cols += [c for c in preds_df.columns if '_entropy' in c]
cols += ['price', 'item_seq_number']
for ii in ['_max_', '_min_', '_avg_', '_std_', '_med_']:
    cols += [c for c in preds_df.columns if ii in c]
categories = ['region', 'param_1_big', 'parent_category_name', 'category_name', \
              'param_2_big', 'param_3_big', 'city_big', 'user_type', 'image_top_1_big']#,
cols += categories
cols = list(set(cols))

# %%
for col in categories:
    preds_df[col] = LabelEncoder().fit_transform(preds_df[col].fillna("0"))

# %%
train_df = preds_df[~preds_df['deal_probability'].isnull()]
test_df = preds_df[preds_df['deal_probability'].isnull()]

# %%
n_estimators = 4000
train_X, valid_X, train_y, valid_y = train_test_split(train_df[cols], y, train_size=.8, random_state=12345)
eval_set = [(train_X,train_y),(valid_X,valid_y)]

# %%
len(train_X)
# Out:
# 1202739

# %%
# %%time
gc.collect()
clf = LGBMRegressor(n_estimators=n_estimators, 
                    max_depth=-1, 
                    feature_fraction= 0.4,
                    num_leaves=32, 
                    learning_rate=.01)#, device='gpu')
clf.fit(train_X, train_y, early_stopping_rounds=80, 
        eval_set=eval_set, eval_metric='rmse', verbose=100, 
        categorical_feature=categories)
# [2796]	training's rmse: 0.208275	valid_1's rmse: 0.212167
# [2500]	training's rmse: 0.208429	valid_1's rmse: 0.212098
# [2107]	training's rmse: 0.208771	valid_1's rmse: 0.212027

# [2754]	training's rmse: 0.207707	valid_1's rmse: 0.211824
# [1697]	training's rmse: 0.208956	valid_1's rmse: 0.211799
# [2066]	training's rmse: 0.208224	valid_1's rmse: 0.211682

# [2683]	training's rmse: 0.207184	valid_1's rmse: 0.211402
# [2551]	training's rmse: 0.207177	valid_1's rmse: 0.211261
# Out:
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.218701	valid_1's rmse: 0.219092
# [200]	training's rmse: 0.212151	valid_1's rmse: 0.212771
# [300]	training's rmse: 0.210975	valid_1's rmse: 0.211801
# [400]	training's rmse: 0.210576	valid_1's rmse: 0.21159
# [500]	training's rmse: 0.210316	valid_1's rmse: 0.211493
# [600]	training's rmse: 0.210098	valid_1's rmse: 0.211439
# [700]	training's rmse: 0.209902	valid_1's rmse: 0.211403
# [800]	training's rmse: 0.209725	valid_1's rmse: 0.21138
# [900]	training's rmse: 0.209558	valid_1's rmse: 0.211366
# [1000]	training's rmse: 0.209399	valid_1's rmse: 0.211352
# [1100]	training's rmse: 0.209241	valid_1's rmse: 0.211338
# [1200]	training's rmse: 0.209087	valid_1's rmse: 0.211327
# [1300]	training's rmse: 0.208937	valid_1's rmse: 0.211317
# [1400]	training's rmse: 0.208786	valid_1's rmse: 0.21131
# [1500]	training's rmse: 0.208641	valid_1's rmse: 0.211303
# [1600]	training's rmse: 0.208496	valid_1's rmse: 0.211296
# [1700]	training's rmse: 0.208353	valid_1's rmse: 0.211289
# [1800]	training's rmse: 0.20821	valid_1's rmse: 0.211284
# [1900]	training's rmse: 0.208068	valid_1's rmse: 0.211282
# [2000]	training's rmse: 0.207929	valid_1's rmse: 0.211277
# [2100]	training's rmse: 0.207789	valid_1's rmse: 0.211274
# [2200]	training's rmse: 0.207652	valid_1's rmse: 0.211271
# [2300]	training's rmse: 0.207516	valid_1's rmse: 0.211268
# [2400]	training's rmse: 0.20738	valid_1's rmse: 0.211265
# [2500]	training's rmse: 0.207245	valid_1's rmse: 0.211262
# [2600]	training's rmse: 0.207111	valid_1's rmse: 0.211262
# Early stopping, best iteration is:
# [2551]	training's rmse: 0.207177	valid_1's rmse: 0.211261
# CPU times: user 1h 51min 48s, sys: 42.7 s, total: 1h 52min 30s
# Wall time: 15min 1s

# %%
sorted(zip(clf.feature_importances_, train_X.columns ),key=lambda x: -x[0])
# Out:
# [(4804, 'city_big'),
#  (3689, 'param_1_big'),
#  (2632, 'category_name'),
#  (2530, 'region'),
#  (1580, 'image_top_1_big'),
#  (1038, 'rdgv19_preds'),
#  (1035, 'user_id__activation_date__entropy'),
#  (959, 'difference_mlp_preds__rdgv23_preds'),
#  (921, 'difference_rnn_preds__rnn27_preds'),
#  (761, 'param_3_big'),
#  (668, 'difference_rnn_preds__rnn12_preds'),
#  (575, 'difference_lgb20B_preds__rdgv23_preds'),
#  (556, 'difference_lgb20_preds__rdgv23_preds'),
#  (513, 'user_id__title__entropy'),
#  (503, 'difference_rnn27_preds__rdgv23_preds'),
#  (499, 'difference_lgb11D_preds__lgb14_preds'),
#  (492, 'difference_rnn12_preds__rdgv23_preds'),
#  (490, 'user_id__parent_category_name__entropy'),
#  (487, 'user_id__param_1__entropy'),
#  (465, 'difference_lgb20C_preds__rdgv23_preds'),
#  (458, 'difference_rdgv20_preds__rdgv23_preds'),
#  (445, 'difference_lgb09_preds__lgb02A_preds'),
#  (445, 'price'),
#  (443, 'difference_lgb10_preds__lgb20_preds'),
#  (443, 'difference_rnn27_preds__rnn12_preds'),
#  (439, 'difference_lgb20AA_preds__rdgv23_preds'),
#  (419, 'user_id__param_3__entropy'),
#  (418, 'user_id__category_name__entropy'),
#  (410, 'difference_lgb11D_preds__lgb19A_preds'),
#  (402, 'difference_lgb19A_preds__rdgv23_preds'),
#  (400, 'difference_lgb14_preds__lgb19A_preds'),
#  (392, 'sums_mlp_preds__lgb20B_preds'),
#  (388, 'difference_lgb11D_preds__lgb20_preds'),
#  (382, 'difference_lgb31_preds__lgb09_preds'),
#  (377, 'difference_lgb09_preds__lgb10_preds'),
#  (375, 'difference_lgb20_preds__lgb20AA_preds'),
#  (372, 'sums_lgb20B_preds__rnn27_preds'),
#  (371, 'difference_lgb11D_preds__lgb20AA_preds'),
#  (364, 'sums_lgb20B_preds__rnn12_preds'),
#  (362, 'difference_lgb20C_preds__lgb20AA_preds'),
#  (362, 'difference_lgb31_preds__lgb20B_preds'),
#  (359, 'difference_mlp_preds__lgb31_preds'),
#  (354, 'difference_mlp_preds__rnn12_preds'),
#  (352, 'item_seq_number'),
#  (350, 'difference_lgb31_preds__lgb02A_preds'),
#  (349, 'difference_lgb20B_preds__lgb20AA_preds'),
#  (346, 'difference_lgb14_preds__lgb20_preds'),
#  (344, 'difference_lgb20C_preds__lgb20B_preds'),
#  (343, 'difference_lgb09_preds__lgb11D_preds'),
#  (343, 'difference_lgb11D_preds__lgb20B_preds'),
#  (340, 'difference_lgb20_preds__lgb20B_preds'),
#  (331, 'difference_lgb09_preds__lgb19A_preds'),
#  (326, 'difference_lgb20C_preds__lgb19A_preds'),
#  (324, 'difference_rnn_preds__mlp_preds'),
#  (324, 'difference_lgb20_preds__lgb20C_preds'),
#  (323, 'difference_lgb11D_preds__lgb20C_preds'),
#  (323, 'sums_mlp_preds__lgb20_preds'),
#  (322, 'difference_lgb10_preds__lgb20AA_preds'),
#  (318, 'difference_mlp_preds__rnn27_preds'),
#  (317, 'difference_lgb14_preds__lgb20AA_preds'),
#  (312, 'difference_lgb20B_preds__lgb19A_preds'),
#  (311, 'difference_lgb20AA_preds__lgb19A_preds'),
#  (311, 'difference_lgb14_preds__lgb20B_preds'),
#  (310, 'difference_rnn_preds__rdgv23_preds'),
#  (306, 'difference_lgb14_preds__rdgv23_preds'),
#  (306, 'sums_lgb20_preds__rnn27_preds'),
#  (302, 'difference_lgb10_preds__lgb14_preds'),
#  (299, 'difference_lgb10_preds__lgb02A_preds'),
#  (297, 'difference_lgb20_preds__lgb19A_preds'),
#  (294, 'difference_lgb11D_preds__lgb02A_preds'),
#  (294, 'difference_lgb09_preds__lgb20C_preds'),
#  (291, 'difference_lgb09_preds__lgb20_preds'),
#  (291, 'difference_lgb10_preds__lgb11D_preds'),
#  (290, 'difference_mlp_preds__rdgv20_preds'),
#  (289, 'rnn27_preds'),
#  (288, 'difference_mlp_preds__lgb11D_preds'),
#  (284, 'difference_lgb10_preds__lgb20C_preds'),
#  (284, 'sums_lgb20_preds__lgb20B_preds'),
#  (283, 'difference_lgb14_preds__lgb20C_preds'),
#  (282, 'difference_lgb09_preds__rdgv23_preds'),
#  (281, 'difference_lgb14_preds__lgb02A_preds'),
#  (281, 'difference_lgb31_preds__lgb19A_preds'),
#  (275, 'difference_lgb31_preds__lgb20C_preds'),
#  (272, 'difference_lgb19A_preds__lgb02A_preds'),
#  (270, 'param_2_big'),
#  (270, 'difference_lgb09_preds__lgb20AA_preds'),
#  (267, 'difference_lgb31_preds__lgb20_preds'),
#  (267, 'difference_rnn12_preds__rdgv20_preds'),
#  (265, 'difference_lgb10_preds__lgb19A_preds'),
#  (260, 'difference_lgb31_preds__lgb10_preds'),
#  (259, 'difference_lgb31_preds__lgb20AA_preds'),
#  (259, 'difference_lgb31_preds__lgb11D_preds'),
#  (259, 'user_id__param_2__entropy'),
#  (259, 'difference_lgb20B_preds__lgb02A_preds'),
#  (258, 'difference_lgb10_preds__lgb20B_preds'),
#  (253, 'difference_lgb20AA_preds__lgb02A_preds'),
#  (252, 'difference_rnn27_preds__rdgv20_preds'),
#  (252, 'difference_lgb20_preds__lgb02A_preds'),
#  (250, 'difference_lgb31_preds__rnn12_preds'),
#  (250, 'difference_mlp_preds__lgb02A_preds'),
#  (250, 'mlp_preds'),
#  (247, 'difference_mlp_preds__lgb10_preds'),
#  (245, 'difference_mlp_preds__lgb20_preds'),
#  (243, 'difference_lgb20B_preds__rdgv20_preds'),
#  (241, 'difference_lgb09_preds__lgb14_preds'),
#  (240, 'difference_lgb31_preds__rnn27_preds'),
#  (239, 'difference_mlp_preds__lgb09_preds'),
#  (238, 'sums_lgb20_preds__rnn12_preds'),
#  (238, 'difference_lgb31_preds__lgb14_preds'),
#  (237, 'difference_mlp_preds__lgb20C_preds'),
#  (234, 'difference_lgb19A_preds__rnn12_preds'),
#  (233, 'difference_mlp_preds__lgb20B_preds'),
#  (233, 'sums_mlp_preds__rnn27_preds'),
#  (233, 'difference_lgb19A_preds__rdgv20_preds'),
#  (232, 'difference_lgb02A_preds__rnn12_preds'),
#  (231, 'difference_lgb31_preds__rdgv20_preds'),
#  (229, 'difference_lgb09_preds__lgb20B_preds'),
#  (228, 'difference_lgb20_preds__rnn12_preds'),
#  (227, 'difference_lgb31_preds__rdgv23_preds'),
#  (227, 'sums_mlp_preds__rnn12_preds'),
#  (226, 'difference_lgb20AA_preds__rnn12_preds'),
#  (224, '_min_'),
#  (223, 'difference_rnn_preds__rdgv20_preds'),
#  (221, 'difference_lgb10_preds__rnn12_preds'),
#  (219, 'difference_lgb20C_preds__lgb02A_preds'),
#  (219, 'difference_mlp_preds__lgb20AA_preds'),
#  (218, 'difference_lgb20C_preds__rnn12_preds'),
#  (217, 'difference_lgb09_preds__rdgv20_preds'),
#  (214, 'difference_lgb11D_preds__rnn27_preds'),
#  (212, 'difference_lgb11D_preds__rdgv23_preds'),
#  (212, 'difference_lgb02A_preds__rdgv20_preds'),
#  (212, 'difference_lgb02A_preds__rnn27_preds'),
#  (211, 'difference_mlp_preds__lgb14_preds'),
#  (211, '_std_'),
#  (208, 'difference_rnn_preds__lgb20AA_preds'),
#  (207, 'difference_lgb02A_preds__rdgv23_preds'),
#  (206, 'difference_lgb20B_preds__rnn12_preds'),
#  (204, 'sums_lgb20C_preds__rnn27_preds'),
#  (204, 'difference_rnn_preds__lgb11D_preds'),
#  (200, 'difference_lgb11D_preds__rdgv20_preds'),
#  (200, 'difference_lgb10_preds__rdgv23_preds'),
#  (198, 'sums_mlp_preds__lgb20AA_preds'),
#  (197, 'sums_mlp_preds__lgb20C_preds'),
#  (196, 'difference_lgb09_preds__rnn12_preds'),
#  (194, 'difference_lgb20C_preds__rnn27_preds'),
#  (193, 'sums_mlp_preds__lgb19A_preds'),
#  (193, 'difference_lgb19A_preds__rnn27_preds'),
#  (192, 'difference_rnn_preds__lgb19A_preds'),
#  (192, 'sums_lgb20B_preds__lgb19A_preds'),
#  (191, 'difference_rnn_preds__lgb20B_preds'),
#  (191, 'difference_rnn_preds__lgb31_preds'),
#  (191, 'difference_lgb20C_preds__rdgv20_preds'),
#  (190, 'difference_rnn_preds__lgb10_preds'),
#  (189, 'difference_lgb20B_preds__rnn27_preds'),
#  (188, 'difference_lgb10_preds__rnn27_preds'),
#  (186, 'sums_mlp_preds__rdgv20_preds'),
#  (185, 'sums_lgb20AA_preds__rnn12_preds'),
#  (185, 'difference_rnn_preds__lgb02A_preds'),
#  (183, 'difference_lgb20_preds__rdgv20_preds'),
#  (182, 'difference_mlp_preds__lgb19A_preds'),
#  (181, 'rdgv23_preds'),
#  (181, 'difference_lgb10_preds__rdgv20_preds'),
#  (179, 'difference_rnn_preds__lgb20C_preds'),
#  (179, 'difference_rnn_preds__lgb09_preds'),
#  (178, 'difference_rnn_preds__lgb20_preds'),
#  (177, 'rnn12_preds'),
#  (175, 'sums_lgb19A_preds__rnn12_preds'),
#  (175, 'difference_lgb20AA_preds__rnn27_preds'),
#  (175, 'difference_lgb14_preds__rdgv20_preds'),
#  (175, 'difference_rnn_preds__lgb14_preds'),
#  (175, 'difference_lgb14_preds__rnn27_preds'),
#  (174, 'difference_lgb20AA_preds__rdgv20_preds'),
#  (173, 'difference_lgb20_preds__rnn27_preds'),
#  (173, 'sums_lgb20AA_preds__rnn27_preds'),
#  (172, 'rdgv20_preds'),
#  (171, 'user_id__city__entropy'),
#  (170, 'difference_lgb09_preds__rnn27_preds'),
#  (166, 'sums_mlp_preds__rdgv23_preds'),
#  (166, 'sums_lgb14_preds__lgb20B_preds'),
#  (165, 'sums_lgb20C_preds__rnn12_preds'),
#  (165, 'difference_lgb11D_preds__rnn12_preds'),
#  (159, 'sums_lgb19A_preds__rnn27_preds'),
#  (159, 'sums_lgb20C_preds__lgb20B_preds'),
#  (157, 'parent_category_name'),
#  (155, 'sums_lgb20B_preds__lgb20AA_preds'),
#  (155, 'rnn_preds'),
#  (154, 'lgb27_preds'),
#  (151, 'lgb20B_preds'),
#  (150, 'difference_lgb14_preds__rnn12_preds'),
#  (142, 'sums_rnn27_preds__rdgv20_preds'),
#  (142, 'sums_rdgv20_preds__rdgv23_preds'),
#  (142, 'lgb17_preds'),
#  (136, 'sums_lgb20C_preds__lgb20AA_preds'),
#  (129, 'sums_rnn27_preds__rnn12_preds'),
#  (129, 'sums_lgb14_preds__rnn27_preds'),
#  (127, 'sums_rnn_preds__rnn12_preds'),
#  (127, 'sums_rnn_preds__rnn27_preds'),
#  (125, 'lgb11A_preds'),
#  (125, 'sums_lgb20_preds__lgb20C_preds'),
#  (125, 'sums_rnn12_preds__rdgv20_preds'),
#  (123, 'sums_mlp_preds__lgb14_preds'),
#  (121, 'lgb20C_preds'),
#  (119, 'sums_rnn_preds__rdgv20_preds'),
#  (118, 'lgb20_preds'),
#  (117, 'sums_lgb20C_preds__lgb19A_preds'),
#  (112, 'sums_rnn12_preds__rdgv23_preds'),
#  (111, 'sums_mlp_preds__lgb31_preds'),
#  (106, 'sums_rnn_preds__rdgv23_preds'),
#  (106, 'sums_lgb14_preds__rnn12_preds'),
#  (101, 'sums_mlp_preds__lgb02A_preds'),
#  (99, 'sums_rnn_preds__mlp_preds'),
#  (98, 'lgb20AA_preds'),
#  (98, 'sums_lgb20AA_preds__rdgv20_preds'),
#  (97, 'lgb14_preds'),
#  (97, 'sums_lgb31_preds__rnn27_preds'),
#  (96, 'sums_lgb20C_preds__rdgv20_preds'),
#  (96, 'sums_lgb02A_preds__rdgv20_preds'),
#  (95, 'sums_lgb11D_preds__rnn12_preds'),
#  (94, 'sums_lgb31_preds__rdgv23_preds'),
#  (93, 'sums_lgb19A_preds__rdgv20_preds'),
#  (92, 'sums_lgb31_preds__rdgv20_preds'),
#  (92, 'lgb02_preds'),
#  (90, 'sums_mlp_preds__lgb11D_preds'),
#  (89, 'sums_rnn27_preds__rdgv23_preds'),
#  (89, 'sums_lgb20B_preds__rdgv20_preds'),
#  (89, 'sums_lgb20B_preds__rdgv23_preds'),
#  (88, 'sums_mlp_preds__lgb09_preds'),
#  (87, 'sums_mlp_preds__lgb10_preds'),
#  (86, 'sums_lgb20AA_preds__rdgv23_preds'),
#  (86, 'sums_lgb09_preds__rdgv20_preds'),
#  (86, 'sums_lgb10_preds__rdgv23_preds'),
#  (86, 'lgb19A_preds'),
#  (85, '_max_'),
#  (83, 'user_type'),
#  (82, 'sums_lgb10_preds__rdgv20_preds'),
#  (81, 'sums_lgb20C_preds__rdgv23_preds'),
#  (81, 'lgb31_preds'),
#  (81, 'sums_lgb10_preds__rnn12_preds'),
#  (80, 'sums_lgb10_preds__rnn27_preds'),
#  (80, 'sums_lgb31_preds__lgb20B_preds'),
#  (80, 'sums_lgb09_preds__rdgv23_preds'),
#  (80, 'sums_lgb14_preds__rdgv23_preds'),
#  (80, 'sums_lgb20_preds__lgb20AA_preds'),
#  (79, 'lgb09_preds'),
#  (79, 'sums_lgb09_preds__rnn12_preds'),
#  (79, 'lgb10_preds'),
#  (78, 'sums_lgb14_preds__rdgv20_preds'),
#  (78, 'sums_lgb31_preds__lgb02A_preds'),
#  (78, 'sums_rnn_preds__lgb10_preds'),
#  (77, 'lgb11D_preds'),
#  (77, 'sums_lgb19A_preds__rdgv23_preds'),
#  (77, 'sums_rnn_preds__lgb19A_preds'),
#  (76, 'sums_rnn_preds__lgb20C_preds'),
#  (76, 'sums_lgb11D_preds__rdgv20_preds'),
#  (75, 'sums_lgb14_preds__lgb20C_preds'),
#  (75, 'sums_lgb11D_preds__rdgv23_preds'),
#  (75, 'sums_lgb11D_preds__rnn27_preds'),
#  (74, 'sums_rnn_preds__lgb20AA_preds'),
#  (74, 'sums_lgb02A_preds__rdgv23_preds'),
#  (74, 'sums_lgb20_preds__rdgv23_preds'),
#  (74, 'sums_lgb09_preds__rnn27_preds'),
#  (74, 'sums_lgb31_preds__lgb20C_preds'),
#  (74, 'sums_rnn_preds__lgb20_preds'),
#  (74, 'sums_lgb14_preds__lgb19A_preds'),
#  (73, 'sums_lgb10_preds__lgb20B_preds'),
#  (73, 'sums_lgb31_preds__rnn12_preds'),
#  (73, 'sums_rnn_preds__lgb31_preds'),
#  (72, 'sums_lgb20AA_preds__lgb19A_preds'),
#  (71, 'sums_lgb14_preds__lgb20_preds'),
#  (71, 'lgb02A_preds'),
#  (70, 'sums_lgb20_preds__lgb19A_preds'),
#  (69, 'sums_rnn_preds__lgb02A_preds'),
#  (68, 'sums_rnn_preds__lgb20B_preds'),
#  (68, 'sums_lgb20B_preds__lgb02A_preds'),
#  (67, 'sums_lgb20_preds__rdgv20_preds'),
#  (66, 'sums_lgb02A_preds__rnn27_preds'),
#  (65, 'sums_lgb10_preds__lgb02A_preds'),
#  (65, 'sums_rnn_preds__lgb11D_preds'),
#  (64, 'sums_lgb14_preds__lgb20AA_preds'),
#  (63, 'sums_lgb31_preds__lgb09_preds'),
#  (62, 'sums_lgb11D_preds__lgb02A_preds'),
#  (61, 'sums_rnn_preds__lgb09_preds'),
#  (61, 'sums_lgb14_preds__lgb02A_preds'),
#  (61, 'sums_rnn_preds__lgb14_preds'),
#  (61, 'sums_lgb19A_preds__lgb02A_preds'),
#  (60, '_med_'),
#  (59, 'sums_lgb09_preds__lgb19A_preds'),
#  (59, 'sums_lgb09_preds__lgb20B_preds'),
#  (59, 'sums_lgb11D_preds__lgb20AA_preds'),
#  (59, 'sums_lgb11D_preds__lgb20B_preds'),
#  (59, 'sums_lgb20AA_preds__lgb02A_preds'),
#  (58, 'sums_lgb11D_preds__lgb20C_preds'),
#  (56, 'sums_lgb31_preds__lgb10_preds'),
#  (56, 'sums_lgb09_preds__lgb02A_preds'),
#  (56, 'sums_lgb09_preds__lgb10_preds'),
#  (56, 'sums_lgb31_preds__lgb20_preds'),
#  (55, 'sums_lgb02A_preds__rnn12_preds'),
#  (54, 'sums_lgb09_preds__lgb20C_preds'),
#  (53, 'sums_lgb31_preds__lgb19A_preds'),
#  (52, 'sums_lgb31_preds__lgb11D_preds'),
#  (51, 'sums_lgb31_preds__lgb20AA_preds'),
#  (51, 'sums_lgb09_preds__lgb14_preds'),
#  (50, 'sums_lgb11D_preds__lgb14_preds'),
#  (50, 'sums_lgb11D_preds__lgb20_preds'),
#  (50, 'sums_lgb10_preds__lgb20C_preds'),
#  (49, 'sums_lgb20C_preds__lgb02A_preds'),
#  (49, 'sums_lgb10_preds__lgb19A_preds'),
#  (48, 'sums_lgb11D_preds__lgb19A_preds'),
#  (47, 'sums_lgb09_preds__lgb11D_preds'),
#  (45, 'sums_lgb09_preds__lgb20_preds'),
#  (44, 'sums_lgb20_preds__lgb02A_preds'),
#  (42, 'sums_lgb10_preds__lgb14_preds'),
#  (42, 'sums_lgb10_preds__lgb20_preds'),
#  (39, 'sums_lgb10_preds__lgb11D_preds'),
#  (39, 'sums_lgb31_preds__lgb14_preds'),
#  (39, 'sums_lgb10_preds__lgb20AA_preds'),
#  (39, 'sums_lgb09_preds__lgb20AA_preds'),
#  (27, '_avg_')]

# %%
n_estimators = 2500
train_X = train_df[cols]
train_y = y
eval_set = [(train_X,train_y)]
len(train_X)
# Out:
# 1503424

# %%
# %%time
y_predls = []
for i in range(5):    
    del clf
    gc.collect()
    clf = LGBMRegressor(n_estimators=n_estimators, 
                    max_depth=-1, 
                    feature_fraction= 0.4,
                    num_leaves=32, 
                    seed = i, 
                    learning_rate=.01)#, device='gpu')
    clf.fit(train_X, train_y, early_stopping_rounds=80, 
        eval_set=eval_set, eval_metric='rmse', verbose=100, 
        categorical_feature=categories)
    y_predls.append(clf.predict(test_df[cols]))
    gc.collect()
# Out:
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.218783
# [200]	training's rmse: 0.212266
# [300]	training's rmse: 0.211121
# [400]	training's rmse: 0.210755
# [500]	training's rmse: 0.210525
# [600]	training's rmse: 0.210337
# [700]	training's rmse: 0.210172
# [800]	training's rmse: 0.210021
# [900]	training's rmse: 0.209879
# [1000]	training's rmse: 0.209744
# [1100]	training's rmse: 0.209614
# [1200]	training's rmse: 0.209484
# [1300]	training's rmse: 0.209357
# [1400]	training's rmse: 0.209236
# [1500]	training's rmse: 0.209114
# [1600]	training's rmse: 0.208996
# [1700]	training's rmse: 0.208874
# [1800]	training's rmse: 0.208755
# [1900]	training's rmse: 0.208639
# [2000]	training's rmse: 0.208524
# [2100]	training's rmse: 0.208406
# [2200]	training's rmse: 0.208291
# [2300]	training's rmse: 0.208174
# [2400]	training's rmse: 0.208061
# [2500]	training's rmse: 0.207946
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.207946
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.218786
# [200]	training's rmse: 0.212267
# [300]	training's rmse: 0.211121
# [400]	training's rmse: 0.210759
# [500]	training's rmse: 0.210527
# [600]	training's rmse: 0.210341
# [700]	training's rmse: 0.210175
# [800]	training's rmse: 0.210024
# [900]	training's rmse: 0.209882
# [1000]	training's rmse: 0.209748
# [1100]	training's rmse: 0.209614
# [1200]	training's rmse: 0.209485
# [1300]	training's rmse: 0.209357
# [1400]	training's rmse: 0.209233
# [1500]	training's rmse: 0.209111
# [1600]	training's rmse: 0.208988
# [1700]	training's rmse: 0.208872
# [1800]	training's rmse: 0.208754
# [1900]	training's rmse: 0.208638
# [2000]	training's rmse: 0.208518
# [2100]	training's rmse: 0.208405
# [2200]	training's rmse: 0.208289
# [2300]	training's rmse: 0.208177
# [2400]	training's rmse: 0.208063
# [2500]	training's rmse: 0.20795
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.20795
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.218784
# [200]	training's rmse: 0.21227
# [300]	training's rmse: 0.211122
# [400]	training's rmse: 0.210758
# [500]	training's rmse: 0.210527
# [600]	training's rmse: 0.210343
# [700]	training's rmse: 0.210178
# [800]	training's rmse: 0.210025
# [900]	training's rmse: 0.209882
# [1000]	training's rmse: 0.209747
# [1100]	training's rmse: 0.209616
# [1200]	training's rmse: 0.209486
# [1300]	training's rmse: 0.209361
# [1400]	training's rmse: 0.209238
# [1500]	training's rmse: 0.209117
# [1600]	training's rmse: 0.208999
# [1700]	training's rmse: 0.208881
# [1800]	training's rmse: 0.208762
# [1900]	training's rmse: 0.208645
# [2000]	training's rmse: 0.208529
# [2100]	training's rmse: 0.208412
# [2200]	training's rmse: 0.208298
# [2300]	training's rmse: 0.208183
# [2400]	training's rmse: 0.208071
# [2500]	training's rmse: 0.207958
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.207958
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.218785
# [200]	training's rmse: 0.212266
# [300]	training's rmse: 0.211125
# [400]	training's rmse: 0.210763
# [500]	training's rmse: 0.210532
# [600]	training's rmse: 0.210347
# [700]	training's rmse: 0.210178
# [800]	training's rmse: 0.210026
# [900]	training's rmse: 0.209882
# [1000]	training's rmse: 0.209746
# [1100]	training's rmse: 0.209617
# [1200]	training's rmse: 0.209491
# [1300]	training's rmse: 0.209366
# [1400]	training's rmse: 0.209242
# [1500]	training's rmse: 0.20912
# [1600]	training's rmse: 0.208996
# [1700]	training's rmse: 0.208877
# [1800]	training's rmse: 0.208762
# [1900]	training's rmse: 0.208644
# [2000]	training's rmse: 0.208528
# [2100]	training's rmse: 0.208412
# [2200]	training's rmse: 0.208295
# [2300]	training's rmse: 0.208181
# [2400]	training's rmse: 0.208066
# [2500]	training's rmse: 0.207954
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.207954
# Training until validation scores don't improve for 80 rounds.
# [100]	training's rmse: 0.218785
# [200]	training's rmse: 0.212263
# [300]	training's rmse: 0.211117
# [400]	training's rmse: 0.210757
# [500]	training's rmse: 0.21053
# [600]	training's rmse: 0.210342
# [700]	training's rmse: 0.210175
# [800]	training's rmse: 0.210022
# [900]	training's rmse: 0.209881
# [1000]	training's rmse: 0.209746
# [1100]	training's rmse: 0.209614
# [1200]	training's rmse: 0.209489
# [1300]	training's rmse: 0.209365
# [1400]	training's rmse: 0.209242
# [1500]	training's rmse: 0.209122
# [1600]	training's rmse: 0.209003
# [1700]	training's rmse: 0.208883
# [1800]	training's rmse: 0.208767
# [1900]	training's rmse: 0.208651
# [2000]	training's rmse: 0.208534
# [2100]	training's rmse: 0.208422
# [2200]	training's rmse: 0.208307
# [2300]	training's rmse: 0.208193
# [2400]	training's rmse: 0.208079
# [2500]	training's rmse: 0.207966
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.207966
# CPU times: user 10h 1min 29s, sys: 1min 43s, total: 10h 3min 12s
# Wall time: 1h 17min 26s

# %%
test_df['deal_probability'] = sum(y_predls)/len(y_predls)
test_df['deal_probability'] = np.clip(test_df['deal_probability'], .0001, .9999)
test_df[['item_id', 'deal_probability']].to_csv('../lgbbsub_2306L2.csv.gz', compression='gzip', index=False, header=True)
test_df[['item_id', 'deal_probability']].head()
# Out:
#               item_id  deal_probability
# 1503424  6544e41a8817          0.452292
# 1503425  65b9484d670f          0.119823
# 1503426  8bab230b2ecd          0.134726
# 1503427  8e348601fefc          0.103747
# 1503428  8bd2fe400b89          0.142648
